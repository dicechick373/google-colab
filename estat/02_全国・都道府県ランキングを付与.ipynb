# %% [markdown]
# # 実行環境の作成

# %% [markdown]
# ## Google Drive

# %% [markdown]
# Google Driveをマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## GCP認証

# %% [markdown]
# 下記コードでGCPに接続

# %%
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# # 地域設定

# %% [markdown]
# ## 関数

# %%
import json

def get_area(params={}):
  with open('drive/MyDrive/statistics-hyogo/resas/arealist.json') as j:
    areas = json.load(j)

    if not params:
      return areas

    else:
      for p in params.keys():
        areas = list(filter(lambda x: x[p] == params[p], areas))
      return areas

# %% [markdown]
# ## 都道府県コード一覧

# %%
def prefCodes():
  params = {
      'governmentType': 'prefecture',
  }
  
  area = get_area(params)
  return [d.get('areaCode') for d in area]

# %%
print(prefCodes())
# Out:
# ['01000', '02000', '03000', '04000', '05000', '06000', '07000', '08000', '09000', '10000', '11000', '12000', '13000', '14000', '15000', '16000', '17000', '18000', '19000', '20000', '21000', '22000', '23000', '24000', '25000', '26000', '27000', '28000', '29000', '30000', '31000', '32000', '33000', '34000', '35000', '36000', '37000', '38000', '39000', '40000', '41000', '42000', '43000', '44000', '45000', '46000', '47000']

# %% [markdown]
# ## 市区町村コード一覧

# %% [markdown]
# 政令指定都市の区は無視する

# %%
def cityCodes(prefCode=None):
  params = {'governmentType': 'city'}

  if prefCode is not None:
    params['prefCode'] = prefCode

  area = get_area(params)
  area = list(filter(lambda item : item['bigCityFlag'] != '1', area))
  return [d.get('areaCode') for d in area]

# %%
print(cityCodes())

# %%
print(cityCodes(28))

# %% [markdown]
# # GBQからデータ取得

# %% [markdown]
# ## テーブル一覧

# %%
from google.cloud import bigquery

def estat_origin_tables():
  project_id='primal-buttress-342908'
  dataset_id = 'estat_origin'
  client = bigquery.Client(project=project_id)
  
  res = []
  for table in client.list_tables(dataset=dataset_id):
    res.append(table.table_id)
  
  return res

# %%
print(estat_origin_tables())
# Out:
# ['0000010101_A1101', '0000010101_A110101', '0000010101_A110102', '0000010101_A1102', '0000010101_A110201', '0000010101_A110202', '0000010101_A1201', '0000010101_A120101', '0000010101_A120102', '0000010101_A1202', '0000010101_A120201', '0000010101_A120202', '0000010101_A1203', '0000010101_A120301', '0000010101_A120302', '0000010101_A1204', '0000010101_A120401', '0000010101_A120402', '0000010101_A1205', '0000010101_A120501', '0000010101_A120502', '0000010101_A1206', '0000010101_A120601', '0000010101_A120602', '0000010101_A1207', '0000010101_A120701', '0000010101_A120702', '0000010101_A1208', '0000010101_A120801', '0000010101_A120802', '0000010101_A1209', '0000010101_A120901', '0000010101_A120902', '0000010101_A1210', '0000010101_A121001', '0000010101_A121002', '0000010101_A1211', '0000010101_A121101', '0000010101_A121102', '0000010101_A1212', '0000010101_A121201', '0000010101_A121202', '0000010101_A1213', '0000010101_A121301', '0000010101_A121302', '0000010101_A1214', '0000010101_A121401', '0000010101_A121402', '0000010101_A1215', '0000010101_A121501', '0000010101_A121502', '0000010101_A1216', '0000010101_A121601', '0000010101_A121602', '0000010101_A1217', '0000010101_A121701', '0000010101_A121702', '0000010101_A1218', '0000010101_A121801', '0000010101_A121802', '0000010101_A1219', '0000010101_A121901', '0000010101_A121902', '0000010101_A1220', '0000010101_A122001', '0000010101_A122002', '0000010101_A1221', '0000010101_A122101', '0000010101_A122102', '0000010101_A1231', '0000010101_A1301', '0000010101_A130101', '0000010101_A130102', '0000010101_A1302', '0000010101_A130201', '0000010101_A130202', '0000010101_A1303', '0000010101_A130301', '0000010101_A130302', '0000010101_A1304', '0000010101_A130401', '0000010101_A130402', '0000010101_A1305', '0000010101_A130501', '0000010101_A130502', '0000010101_A1306', '0000010101_A130601', '0000010101_A130602', '0000010101_A1401', '0000010101_A140101', '0000010101_A140102', '0000010101_A1402', '0000010101_A140201', '0000010101_A140202', '0000010101_A1403', '0000010101_A140301', '0000010101_A140302', '0000010101_A1404', '0000010101_A140401', '0000010101_A140402', '0000010101_A1405', '0000010101_A140501', '0000010101_A140502', '0000010101_A1406', '0000010101_A140601', '0000010101_A140602', '0000010101_A1407', '0000010101_A140701', '0000010101_A140702', '0000010101_A1408', '0000010101_A140801', '0000010101_A140802', '0000010101_A1409', '0000010101_A140901', '0000010101_A140902', '0000010101_A1410', '0000010101_A141001', '0000010101_A141002', '0000010101_A1411', '0000010101_A141101', '0000010101_A141102', '0000010101_A1412', '0000010101_A141201', '0000010101_A141202', '0000010101_A1413', '0000010101_A141301', '0000010101_A141302', '0000010101_A1414', '0000010101_A141401', '0000010101_A141402', '0000010101_A1415', '0000010101_A141501', '0000010101_A141502', '0000010101_A1416', '0000010101_A141601', '0000010101_A141602', '0000010101_A1417', '0000010101_A141701', '0000010101_A141702', '0000010101_A1418', '0000010101_A141801', '0000010101_A141802', '0000010101_A1419', '0000010101_A141901', '0000010101_A141902', '0000010101_A1420', '0000010101_A142001', '0000010101_A142002', '0000010101_A1501', '0000010101_A1502', '0000010101_A150201', '0000010101_A150202', '0000010101_A1503', '0000010101_A150301', '0000010101_A150302', '0000010101_A1504', '0000010101_A150401', '0000010101_A150402', '0000010101_A1505', '0000010101_A150501', '0000010101_A150502', '0000010101_A1506', '0000010101_A150601', '0000010101_A150602', '0000010101_A1507', '0000010101_A150701', '0000010101_A150702', '0000010101_A1508', '0000010101_A150801', '0000010101_A150802', '0000010101_A1509', '0000010101_A150901', '0000010101_A150902', '0000010101_A1510', '0000010101_A151001', '0000010101_A151002', '0000010101_A1511', '0000010101_A151101', '0000010101_A151102', '0000010101_A1512', '0000010101_A151201', '0000010101_A151202', '0000010101_A1513', '0000010101_A151301', '0000010101_A151302', '0000010101_A1514', '0000010101_A151401', '0000010101_A ...

# %% [markdown]
# ## テーブルのデータ取得

# %%
from google.cloud import bigquery

def get_estat_origin(table_id):
  project_id='primal-buttress-342908'
  dataset_id = 'estat_origin'
  client = bigquery.Client(project=project_id)

  query_string = f'SELECT * FROM {dataset_id}.{table_id}'
  
  df = client.query(query_string).result().to_dataframe()

  return df

# %%
table_id = '0000010101_A1101'
get_estat_origin(table_id).head()
# Out:
#   categoryCode areaCode    timeCode        value unit categoryName areaName  \
# 0        A1101    00000  1975100000  111939643.0    人          総人口       全国
# 1        A1101    00000  1976100000  113094000.0    人          総人口       全国
# 2        A1101    00000  1977100000  114165000.0    人          総人口       全国
# 3        A1101    00000  1978100000  115190000.0    人          総人口       全国
# 4        A1101    00000  1979100000  116155000.0    人          総人口       全国
#
#   timeName
# 0   1975年度
# 1   1976年度
# 2   1977年度
# 3   1978年度
# 4   1979年度

# %% [markdown]
# ## ランキング付与

# %%
import pandas as pd

def df_rank(df):
  
  # 整数値の判定
  values = list(set(df['value'].tolist()))
  isInt = list(map(lambda x: x.is_integer(), values)).count(True) >= len(values)/2
  if isInt:
    df = df.astype({'value': int})
  
  # 返却するDataFrameの定義
  df_res = pd.DataFrame(index=[], columns=[])

  # 都道府県（国内順位）
  df_pref = df[df.copy()['areaCode'].isin(prefCodes())]
  if len(df_pref) != 0:
    df_pref = df_rank_time(df_pref, type='japan')
    df_res = pd.concat([df_res, df_pref])
  
  # 市区町村（国内順位）
  df_city = df[df.copy()['areaCode'].isin(cityCodes())]
  if len(df_city) != 0:
    df_city = df_rank_time(df_city, type='japan')
    df_res = pd.concat([df_res, df_city])

  # 市区町村（県内順位）
  df_city = df[df.copy()['areaCode'].isin(cityCodes())]
  if len(df_city) != 0:
    df_city = df_rank_pref(df_city)
    df_res = pd.merge(df_res, df_city, on=['categoryCode','areaCode','timeCode'], how = 'left')

  return df_res

"""
都道府県ごとに分割してRankを付与する関数

"""
def df_rank_pref(df):
  df_res = pd.DataFrame(index=[], columns=[])

  for p in prefCodes():
    df_city = df[df.copy()['areaCode'].isin(cityCodes(int(p[:2])))]
    df_city = df_rank_time(df_city, type='pref')[['categoryCode','areaCode','timeCode','rankPref']]
    df_res = pd.concat([df_res, df_city])

  return df_res

"""
年次ごとに分割してRankを付与する関数

"""
def df_rank_time(df, type='japan'):
  df_res = pd.DataFrame(index=[], columns=[])

  times = sorted(list(set(df['timeCode'].tolist())))
  for time in times:
      df_time = df.copy().query(f'timeCode == "{time}"').reset_index()
      
      if type == 'japan':
        df_time['rankJapan'] = df_time.rank(ascending=False)['value'].astype(int)
      else:
        df_time['rankPref'] = df_time.rank(ascending=False)['value'].astype(int) 

      df_res = pd.concat([df_res, df_time])

  return df_res

# %%
table_id = '0000020201_A1101'
df = get_estat_origin(table_id)
df_rank(df).head()
# Out:
#    index categoryCode areaCode    timeCode    value unit categoryName  \
# 0      0        A1101    01100  1980100000  1401757    人          総人口
# 1      8        A1101    01202  1980100000   345165    人          総人口
# 2      9        A1101    01203  1980100000   180728    人          総人口
# 3     10        A1101    01204  1980100000   352619    人          総人口
# 4     11        A1101    01205  1980100000   150199    人          総人口
#
#   areaName timeName  rankJapan  rankPref
# 0  北海道 札幌市   1980年度          5         1
# 1  北海道 函館市   1980年度         59         3
# 2  北海道 小樽市   1980年度        133         5
# 3  北海道 旭川市   1980年度         56         2
# 4  北海道 室蘭市   1980年度        169         8

# %% [markdown]
# # GBQへ保存

# %% [markdown]
# ## 単体テスト

# %%
from google.cloud import bigquery

def save_gbq(table_id):
  
  # 元データ
  df = get_estat_origin(table_id)
  
  # ランキング付与
  df = df_rank(df)

  # プロジェクト設定
  project_id='primal-buttress-342908'
  dataset_id = 'estat_ranking'
  
  # スキーマ
  job_config = bigquery.LoadJobConfig(write_disposition='WRITE_TRUNCATE')
  
  # bigqueryへ保存
  client = bigquery.Client(project=project_id)
  job = client.load_table_from_dataframe(df, f'{dataset_id}.{table_id}', job_config=job_config).result()

  # 確認メッセージ  
  table = client.get_table(f'{dataset_id}.{table_id}') 
  print("{} 件のデータを「{}」に保存しました。".format(table.num_rows, table_id))

  return

# %%
table_id = '0000020201_A1101'
save_gbq(table_id)
# Out:
# 13928 件のデータを「0000020201_A1101」に保存しました。

# %% [markdown]
# ## 一括処理

# %%
from google.cloud import bigquery
from google.cloud.exceptions import NotFound

# データセットestat-originのテーブル一覧を取得
tables = estat_origin_tables()

# データセットestat-runkingに保存
project_id='primal-buttress-342908'
dataset_id = 'estat_ranking'
client = bigquery.Client(project=project_id)

for table_id in tables:
  try:
    client.get_table(f'{dataset_id}.{table_id}')  
    print("Table {} already exists.".format(table_id))
  except NotFound:
    save_gbq(table_id)
# Out:
# 2115 件のデータを「0000010101_A1101」に保存しました。
# 2115 件のデータを「0000010101_A110101」に保存しました。
# 2115 件のデータを「0000010101_A110102」に保存しました。
# 2115 件のデータを「0000010101_A1102」に保存しました。
# 2115 件のデータを「0000010101_A110201」に保存しました。
# 2115 件のデータを「0000010101_A110202」に保存しました。
# 2115 件のデータを「0000010101_A1201」に保存しました。
# 2115 件のデータを「0000010101_A120101」に保存しました。
# 2115 件のデータを「0000010101_A120102」に保存しました。
# 2115 件のデータを「0000010101_A1202」に保存しました。
# 2115 件のデータを「0000010101_A120201」に保存しました。
# 2115 件のデータを「0000010101_A120202」に保存しました。
# 2115 件のデータを「0000010101_A1203」に保存しました。
# 2115 件のデータを「0000010101_A120301」に保存しました。
# 2115 件のデータを「0000010101_A120302」に保存しました。
# 2115 件のデータを「0000010101_A1204」に保存しました。
# 2115 件のデータを「0000010101_A120401」に保存しました。
# 2115 件のデータを「0000010101_A120402」に保存しました。
# 2115 件のデータを「0000010101_A1205」に保存しました。
# 2115 件のデータを「0000010101_A120501」に保存しました。
# 2115 件のデータを「0000010101_A120502」に保存しました。
# 2115 件のデータを「0000010101_A1206」に保存しました。
# 2115 件のデータを「0000010101_A120601」に保存しました。
# 2115 件のデータを「0000010101_A120602」に保存しました。
# 2115 件のデータを「0000010101_A1207」に保存しました。
# 2115 件のデータを「0000010101_A120701」に保存しました。
# 2115 件のデータを「0000010101_A120702」に保存しました。
# 2115 件のデータを「0000010101_A1208」に保存しました。
# 2115 件のデータを「0000010101_A120801」に保存しました。
# 2115 件のデータを「0000010101_A120802」に保存しました。
# 2115 件のデータを「0000010101_A1209」に保存しました。
# 2115 件のデータを「0000010101_A120901」に保存しました。
# 2115 件のデータを「0000010101_A120902」に保存しました。
# 2115 件のデータを「0000010101_A1210」に保存しました。
# 2115 件のデータを「0000010101_A121001」に保存しました。
# 2115 件のデータを「0000010101_A121002」に保存しました。
# 2115 件のデータを「0000010101_A1211」に保存しました。
# 2115 件のデータを「0000010101_A121101」に保存しました。
# 2115 件のデータを「0000010101_A121102」に保存しました。
# 2115 件のデータを「0000010101_A1212」に保存しました。
# 2115 件のデータを「0000010101_A121201」に保存しました。
# 2115 件のデータを「0000010101_A121202」に保存しました。
# 2115 件のデータを「0000010101_A1213」に保存しました。
# 2115 件のデータを「0000010101_A121301」に保存しました。
# 2115 件のデータを「0000010101_A121302」に保存しました。
# 1927 件のデータを「0000010101_A1214」に保存しました。
# 1927 件のデータを「0000010101_A121401」に保存しました。
# 1927 件のデータを「0000010101_A121402」に保存しました。
# 1927 件のデータを「0000010101_A1215」に保存しました。
# 1927 件のデータを「0000010101_A121501」に保存しました。
# 1927 件のデータを「0000010101_A121502」に保存しました。
# 1927 件のデータを「0000010101_A1216」に保存しました。
# 1927 件のデータを「0000010101_A121601」に保存しました。
# 1927 件のデータを「0000010101_A121602」に保存しました。
# 423 件のデータを「0000010101_A1217」に保存しました。
# 423 件のデータを「0000010101_A121701」に保存しました。
# 423 件のデータを「0000010101_A121702」に保存しました。
# 423 件のデータを「0000010101_A1218」に保存しました。
# 423 件のデータを「0000010101_A121801」に保存しました。
# 423 件のデータを「0000010101_A121802」に保存しました。
# 423 件のデータを「0000010101_A1219」に保存しました。
# 423 件のデータを「0000010101_A121901」に保存しました。
# 423 件のデータを「0000010101_A121902」に保存しました。
# 423 件のデータを「0000010101_A1220」に保存しました。
# 423 件のデータを「0000010101_A122001」に保存しました。
# 423 件のデータを「0000010101_A122002」に保存しました。
# 376 件のデータを「0000010101_A1221」に保存しました。
# 376 件のデータを「0000010101_A122101」に保存しました。
# 376 件のデータを「0000010101_A122102」に保存しました。
# 94 件のデータを「0000010101_A1231」に保存しました。
# 2115 件のデータを「0000010101_A1301」に保存しました。
# 2115 件のデータを「0000010101_A130101」に保存しました。
# 2115 件のデータを「0000010101_A130102」に保存しました。
# 2115 件のデータを「0000010101_A1302」に保存しました。
# 2115 件のデータを「0000010101_A130201」に保存しました。
# 2115 件のデータを「0000010101_A130202」に保存しました。
# 2115 件のデータを「0000010101_A1303」に保存しました。
# 2115 件のデータを「0000010101_A130301」に保存しました。
# 2115 件のデータを「0000010101_A130302」に保存しました。
# 705 件のデータを「0000010101_A1304」に保存しました。
# 705 件のデータを「0000010101_A130401」に保存しました。
# 705 件のデータを「0000010101_A130402」に保存しました。
# 705 件のデータを「0000010101_A1305」に保存しました。
# 705 件のデータを「0000010101_A130501」に保存しました。
# 705 件のデータを「0000010101_A130502」に保存しました。
# 705 件のデータを「0000010101_A1306」に保存しました。
# 705 件のデータを「0000010101_A130601」に保存しました。
# 705 件のデータを「0000010101_A130602」に保存しました。
# 423 件のデータを「0000010101_A1401」に保存しました。
# 376 件のデータを「0000010101_A140101」に保存しました。
# 376 件のデータを「0000010101_A140102」に保存しました。
# 376 件のデータを「0000010101_A1402」に保存しました。
# 376 件のデータを「0000010101_A140201」に保存しました。
# 376 件のデータを「0000010101_A140202」に保存しました。
# 376 件のデータを「0000010101_A1403」に保存しました。
# 376 件のデータを「0000010101_A140301」に保存しました。
# 376 件のデータを「0000010101_A140302」に保存しました。
# 423 件のデータを「0000010101_A1404」に保存しました。
# 376 件のデータを「0000010101_A140401」に保存しました。
# 376 件のデータを「0000010101_A140402」に保存しました。
# 423 件のデータを「0000010101_A1405」に保存しました。
# 376 件のデータを「0000010101_A140501」に保存しました。
# 376 件のデータを「0000010101_A140502」に保存しました。
# 376 件のデータを「0000010101_A1406」に保存しました。
# 376 件のデータを「0000010101_A140601」に保存しました。
# 376 件のデータを「0000010101_A140602」に保存しました。
# 423 件のデータを「0000010101_A1407」に保存しました。
# 376 件のデータを「0000010101_A140701」に保存しました。
# 376 件のデータを「0000010101_A140702」に保存しました。
# 423 件のデータを「0000010101_A1408」に保存しました。
# 376 件のデータを「0000010101_A140801」に保存しました。
# 376 件のデータを「0000010101_A140802」に保存しました。
# 423 件のデータを「0000010101_A1409」に保存しました。
# 376 件のデータを「0000010101_A140901」に保存しました。
# 376 件のデータを「0000010101_A140902」に保存しました。
# 423 件のデータを「0000010101_A1410」に保存しました。
# 376 件のデータを「0000010101_A141001」に保存しました。
# 376 件のデータを「0000010101_A141002」に保存しました。
# 423 件のデータを「0000010101_A1411」に保存しました。
# 376 件のデータを「0000010101_A141101」に保存しました。
# 376 件のデータを「0000010101_A141102」に保存しました。
# 423 件のデータを「0000010101_A1412」に保存しました。
# 376 件のデータを「0000010101_A141201」に保存しました。
# 376 件のデータを「0000010101_A141202」に保存しました。
# 423 件のデータを「0000010101_A1413」に保存しました。
# 376 件のデータを「0000010101_A141301」に保存しました。
# 376 件のデータを「0000010101_A141302」に保存しました。
# 2115 件のデータを「0000010101_A1414」に保存しました。
# 2115 件のデータを「0000010101_A141401」に保存しました。
# 2115 件のデータを「0000010101_A141402」に保存しました。
# 2115 件のデータを「0000010101_A1415」に保存しました。
# 2115 件のデータを「0000010101_A141501」に保存しました。
# 2115 件のデータを「0000010101_A141502」に保存しました。
# 2115 件のデータを「0000010101_A1416」に保存しました。
# 2115 件のデータを「0000010101_A141601」に保存しました。
# 2115 件のデータを「0000010101_A141602」に保存しました。
# 2115 件のデータを「0000010101_A1417」に保存しました。
# 940 件のデータを「0000010101_A141701」に保存しました。
# 940 件のデータを「0000010101_A141702」に保存しました。
# 940 件のデータを「0000010101_A1418」に保存しました。
# 940 件のデータを「0000010101_A141801」に保存しました。
# 940 件のデータを「0000010101_A141802」に保存しました。
# 282 件のデータを「0000010101_A1419」に保存しました。
# 282 件のデータを「0000010101_A141901」に保存しました。
# 282 件のデータを「0000010101_A141902」に保存しました。
# 235 件のデータを「0000010101_A1420」に保存しました。
# 235 件のデータを「0000010101_A142001」に保存しました。
# 235 件のデータを「0000010101_A142002」に保存しました。
# 282 件のデータを「0000010101_A1501」に保存しました。
# 376 件のデータを「0000010101_A1502」に保存しました。
# 376 件のデータを「0000010101_A150201」に保存しました。
# 376 件のデータを「0000010101_A150202」に保存しました。
# 376 件のデータを「0000010101_A1503」に保存しました。
# 376 件のデータを「0000010101_A150301」に保存しました。
# 376 件のデータを「0000010101_A150302」に保存しました。
# 376 件のデータを「0000010101_A1504」に保存しました。
# 376 件のデータを「0000010101_A150401」に保存しました。
# 376 件のデータを「0000010101_A150402」に保存しました。
# 376 件のデータを「0000010101_A1505」に保存しました。
# 376 件のデータを「0000010101_A150501」に保存しました。
# 376 件のデータを「0000010101_A150502」に保存しました。
# 376 件のデータを「0000010101_A1506」に保存しました。
# 376 件のデータを「0000010101_A150601」に保存しました。
# 376 件のデータを「0000010101_A150602」に保存しました。
# 376 件のデータを「0000010101_A1507」に保存しました。
# 376 件のデータを「0000010101_A150701」に保存しました。
# 376 件のデータを「0000010101_A150702」に保存しました。
# 376 件のデータを「0000010101_A1508」に保存しました。
# 376 件のデータを「0000010101_A150801」に保存しました。
# 376 件のデータを「0000010101_A150802」に保存しました。
# 376 件のデータを「0000010101_A1509」に保存しました。
# 376 件のデータを「0000010101_A150901」に保存しました。
# 376 件のデータを「0000010101_A150902」に保存しました。
# 376 件のデータを「0000010101_A1510」に保存しました。
# 376 件のデータを「0000010101_A151001」に保存しました。
# 376 件のデータを「0000010101_A151002」に保存しました。
# 376 件のデータを「0000010101_A1511」に保存しました。
# 376 件のデータを「0000010101_A151101」に保存しました。
# 376 件のデータを「0000010101_A151102」に保存しました。
# 376 件のデータを「0000010101_A1512」に保存しました。
# 376 件のデータを「0000010101_A151201」に保存しました。
# 376 件のデータを「0000010101_A151202」に保存しました。
# 376 件のデータを「0000010101_A1513」に保存しました。
# 376 件のデータを「0000010101_A151301」に保存しました。
# 376 件のデータを「0000010101_A151302」に保存しました。
# 376 件のデータを「0000010101_A1514」に保存しました。
# 376 件のデータを「0000010101_A151401」に保存しました。
# 376 件のデータを「0000010101_A151402」に保存しました。
# 376 件のデータを「0000010101_A1515」に保存しました。
# 376 件のデータを「0000010101_A151501」に保存しました。
# 376 件のデータを「0000010101_A151502」に保存しました。
# 376 件のデータを「0000010101_A1516」に保存しました。
# 376 件のデータを「0000010101_A151601」に保存しました。
# 376 件のデータを「0000010101_A151602」に保存しました。
# 376 件のデータを「0000010101_A1517」に保存しました。
# 376 件のデータを「0000010101_A151701」に保存しました。
# 376 件のデータを「0000010101_A151702」に保存しました。
# 376 件のデータを「0000010101_A1601001」に保存しました。
# 376 件のデータを「0000010101_A1601002」に保存しました。
# 376 件のデータを「0000010101_A1601011」に保存しました。
# 376 件のデータを「0000010101_A1601012」に保存しました。
# 376 件のデータを「0000010101_A1601021」に保存しました。
# 376 件のデータを「0000010101_A1601022」に保存しました。
# 376 件のデータを「0000010101_A1601031」に保存しました。
# 376 件のデータを「0000010101_A1601032」に保存しました。
# 376 件のデータを「0000010101_A1601041」に保存しました。
# 376 件のデータを「0000010101_A1601042」に保存しました。
# 376 件のデータを「0000010101_A1601051」に保存しました。
# 376 件のデータを「0000010101_A1601052」に保存しました。
# 376 件のデータを「0000010101_A1601061」に保存しました。
# 376 件のデータを「0000010101_A1601062」に保存しました。
# 376 件のデータを「0000010101_A1601071」に保存しました。
# 376 件のデータを「0000010101_A1601072」に保存しました。
# 376 件のデータを「0000010101_A1601081」に保存しました。
# 376 件のデータを「0000010101_A1601082」に保存しました。
# 376 件のデータを「0000010101_A1601091」に保存しました。
# 376 件のデータを「0000010101_A1601092」に保存しました。
# 376 件のデータを「0000010101_A1601101」に保存しました。
# 376 件のデータを「0000010101_A1601102」に保存しました。
# 376 件のデータを「0000010101_A1601111」に保存しました。
# 376 件のデータを「0000010101_A1601112」に保存しました。
# 376 件のデータを「0000010101_A1601121」に保存しました。
# 376 件のデータを「0000010101_A1601122」に保存しました。
# 376 件のデータを「0000010101_A1601131」に保存しました。
# 376 件のデータを「0000010101_A1601132」に保存しました。
# 376 件のデータを「0000010101_A1601141」に保存しました。
# 376 件のデータを「0000010101_A1601142」に保存しました。
# 376 件のデータを「0000010101_A1601151」に保存しました。
# 376 件のデータを「0000010101_A1601152」に保存しました。
# 376 件のデータを「0000010101_A1602001」に保存しました。
# 423 件のデータを「0000010101_A1602002」に保存しました。
# 423 件のデータを「0000010101_A1602021」に保存しました。
# 423 件のデータを「0000010101_A1602022」に保存しました。
# 423 件のデータを「0000010101_A1602031」に保存しました。
# 423 件のデータを「0000010101_A1602032」に保存しました。
# 423 件のデータを「0000010101_A1602041」に保存しました。
# 423 件のデータを「0000010101_A1602042」に保存しました。
# 423 件のデータを「0000010101_A1602051」に保存しました。
# 423 件のデータを「0000010101_A1602052」に保存しました。
# 376 件のデータを「0000010101_A1602061」に保存しました。
# 376 件のデータを「0000010101_A1602062」に保存しました。
# 376 件のデータを「0000010101_A1602071」に保存しました。
# 376 件のデータを「0000010101_A1602072」に保存しました。
# 376 件のデータを「0000010101_A1602081」に保存しました。
# 376 件のデータを「0000010101_A1602082」に保存しました。
# 376 件のデータを「0000010101_A1602091」に保存しました。
# 376 件のデータを「0000010101_A1602092」に保存しました。
# 376 件のデータを「0000010101_A1602101」に保存しました。
# 376 件のデータを「0000010101_A1602102」に保存しました。
# 376 件のデータを「0000010101_A1602111」に保存しました。
# 376 件のデータを「0000010101_A1602112」に保存しました。
# 376 件のデータを「0000010101_A1602121」に保存しました。
# 376 件のデータを「0000010101_A1602122」に保存しました。
# 376 件のデータを「0000010101_A1602131」に保存しました。
# 376 件のデータを「0000010101_A1602132」に保存しました。
# 376 件のデータを「0000010101_A1602141」に保存しました。
# 376 件のデータを「0000010101_A1602142」に保存しました。
# 376 件のデータを「0000010101_A1602151」に保存しました。
# 376 件のデータを「0000010101_A1602152」に保存しました。
# 376 件のデータを「0000010101_A1603001」に保存しました。
# 376 件のデータを「0000010101_A1603002」に保存しました。
# 376 件のデータを「0000010101_A1603031」に保存しました。
# 376 件のデータを「0000010101_A1603032」に保存しました。
# 376 件のデータを「0000010101_A1603041」に保存しました。
# 376 件のデータを「0000010101_A1603042」に保存しました。
# 376 件のデータを「0000010101_A1603051」に保存しました。
# 376 件のデータを「0000010101_A1603052」に保存しました。
# 376 件のデータを「0000010101_A1603061」に保存しました。
# 376 件のデータを「0000010101_A1603062」に保存しました。
# 376 件のデータを「0000010101_A1603071」に保存しました。
# 376 件のデータを「0000010101_A1603072」に保存しました。
# 376 件のデータを「0000010101_A1603081」に保存しました。
# 376 件のデータを「0000010101_A1603082」に保存しました。
# 376 件のデータを「0000010101_A1603091」に保存しました。
# 376 件のデータを「0000010101_A1603092」に保存しました。
# 423 件のデータを「0000010101_A1603101」に保存しました。
# 423 件のデータを「0000010101_A1603102」に保存しました。
# 423 件のデータを「0000010101_A1603111」に保存しました。
# 423 件のデータを「0000010101_A1603112」に保存しました。
# 423 件のデータを「0000010101_A1603121」に保存しました。
# 423 件のデータを「0000010101_A1603122」に保存しました。
# 423 件のデータを「0000010101_A1603131」に保存しました。
# 423 件のデータを「0000010101_A1603132」に保存しました。
# 423 件のデータを「0000010101_A1603141」に保存しました。
# 423 件のデータを「0000010101_A1603142」に保存しました。
# 423 件のデータを「0000010101_A1603151」に保存しました。
# 423 件のデータを「0000010101_A1603152」に保存しました。
# 423 件のデータを「0000010101_A1603201」に保存しました。
# 423 件のデータを「0000010101_A1603202」に保存しました。
# 376 件のデータを「0000010101_A1604001」に保存しました。
# 376 件のデータを「0000010101_A1604002」に保存しました。
# 376 件のデータを「0000010101_A1604011」に保存しました。
# 376 件のデータを「0000010101_A1604012」に保存しました。
# 376 件のデータを「0000010101_A1604021」に保存しました。
# 376 件のデータを「0000010101_A1604022」に保存しました。
# 376 件のデータを「0000010101_A1604031」に保存しました。
# 376 件のデータを「0000010101_A1604032」に保存しました。
# 376 件のデータを「0000010101_A1604041」に保存しました。
# 376 件のデータを「0000010101_A1604042」に保存しました。
# 376 件のデータを「0000010101_A1604051」に保存しました。
# 376 件のデータを「0000010101_A1604052」に保存しました。
# 423 件のデータを「0000010101_A1604061」に保存しました。
# 423 件のデータを「0000010101_A1604062」に保存しました。
# 423 件のデータを「0000010101_A1604071」に保存しました。
# 423 件のデータを「0000010101_A1604072」に保存しました。
# 423 件のデータを「0000010101_A1604081」に保存しました。
# 423 件のデータを「0000010101_A1604082」に保存しました。
# 423 件のデータを「0000010101_A1604091」に保存しました。
# 423 件のデータを「0000010101_A1604092」に保存しました。
# 376 件のデータを「0000010101_A1604101」に保存しました。
# 376 件のデータを「0000010101_A1604102」に保存しました。
# 376 件のデータを「0000010101_A1604111」に保存しました。
# 376 件のデータを「0000010101_A1604112」に保存しました。
# 376 件のデータを「0000010101_A1604121」に保存しました。
# 376 件のデータを「0000010101_A1604122」に保存しました。
# 376 件のデータを「0000010101_A1604131」に保存しました。
# 376 件のデータを「0000010101_A1604132」に保存しました。
# 376 件のデータを「0000010101_A1604141」に保存しました。
# 376 件のデータを「0000010101_A1604142」に保存しました。
# 376 件のデータを「0000010101_A1604151」に保存しました。
# 376 件のデータを「0000010101_A1604152」に保存しました。
# 423 件のデータを「0000010101_A1604201」に保存しました。
# 423 件のデータを「0000010101_A1604202」に保存しました。
# 423 件のデータを「0000010101_A1604301」に保存しました。
# 423 件のデータを「0000010101_A1604302」に保存しました。
# 47 件のデータを「0000010101_A161001」に保存しました。
# 376 件のデータを「0000010101_A1700」に保存しました。
# 282 件のデータを「0000010101_A170001」に保存しました。
# 282 件のデータを「0000010101_A170002」に保存しました。
# 376 件のデータを「0000010101_A1701」に保存しました。
# 282 件のデータを「0000010101_A170101」に保存しました。
# 282 件のデータを「0000010101_A170102」に保存しました。
# 376 件のデータを「0000010101_A1702」に保存しました。
# 282 件のデータを「0000010101_A170201」に保存しました。
# 282 件のデータを「0000010101_A170202」に保存しました。
# 376 件のデータを「0000010101_A1703」に保存しました。
# 282 件のデータを「0000010101_A170301」に保存しました。
# 282 件のデータを「0000010101_A170302」に保存しました。
# 47 件のデータを「0000010101_A1706」に保存しました。
# 47 件のデータを「0000010101_A170601」に保存しました。
# 47 件のデータを「0000010101_A170602」に保存しました。
# 47 件のデータを「0000010101_A1707」に保存しました。
# 47 件のデータを「0000010101_A170701」に保存しました。
# 47 件のデータを「0000010101_A170702」に保存しました。
# 423 件のデータを「0000010101_A1801」に保存しました。
# 376 件のデータを「0000010101_A180101」に保存しました。
# 376 件のデータを「0000010101_A180102」に保存しました。
# 423 件のデータを「0000010101_A1802」に保存しました。
# 47 件のデータを「0000010101_A191001」に保存しました。
# 47 件のデータを「0000010101_A191002」に保存しました。
# 47 件のデータを「0000010101_A191003」に保存しました。
# 47 件のデータを「0000010101_A191004」に保存しました。
# 47 件のデータを「0000010101_A191005」に保存しました。
# 47 件のデータを「0000010101_A191006」に保存しました。
# 2162 件のデータを「0000010101_A2101」に保存しました。
# 2162 件のデータを「0000010101_A210101」に保存しました。
# 2162 件のデータを「0000010101_A210102」に保存しました。
# 1175 件のデータを「0000010101_A2102」に保存しました。
# 376 件のデータを「0000010101_A2201」に保存しました。
# 423 件のデータを「0000010101_A2301」に保存しました。
# 987 件のデータを「0000010101_A3100」に保存しました。
# 987 件のデータを「0000010101_A3101」に保存しました。
# 987 件のデータを「0000010101_A310101」に保存しました。
# 987 件のデータを「0000010101_A310102」に保存しました。
# 846 件のデータを「0000010101_A310103」に保存しました。
# 893 件のデータを「0000010101_A310105」に保存しました。
# 987 件のデータを「0000010101_A3102」に保存しました。
# 846 件のデータを「0000010101_A310201」に保存しました。
# 987 件のデータを「0000010101_A3103」に保存しました。
# 846 件のデータを「0000010101_A310301」に保存しました。
# 987 件のデータを「0000010101_A3104」に保存しました。
# 846 件のデータを「0000010101_A310401」に保存しました。
# 846 件のデータを「0000010101_A310402」に保存しました。
# 423 件のデータを「0000010101_A3200」に保存しました。
# 423 件のデータを「0000010101_A3201」に保存しました。
# 141 件のデータを「0000010101_A320101」に保存しました。
# 423 件のデータを「0000010101_A320102」に保存しました。
# 282 件のデータを「0000010101_A320103」に保存しました。
# 282 件のデータを「0000010101_A320104」に保存しました。
# 423 件のデータを「0000010101_A3202」に保存しました。
# 423 件のデータを「0000010101_A3203」に保存しました。
# 423 件のデータを「0000010101_A3204」に保存しました。
# 1927 件のデータを「0000010101_A4101」に保存しました。
# 1927 件のデータを「0000010101_A410101」に保存しました。
# 1927 件のデータを「0000010101_A410102」に保存しました。
# 1551 件のデータを「0000010101_A410201」に保存しました。
# 1551 件のデータを「0000010101_A410202」に保存しました。
# 1551 件のデータを「0000010101_A410203」に保存しました。
# 1551 件のデータを「0000010101_A410204」に保存しました。
# 1551 件のデータを「0000010101_A410205」に保存しました。
# 1551 件のデータを「0000010101_A410206」に保存しました。
# 1551 件のデータを「0000010101_A410207」に保存しました。
# 1551 件のデータを「0000010101_A410208」に保存しました。
# 1551 件のデータを「0000010101_A410209」に保存しました。
# 1692 件のデータを「0000010101_A4103」に保存しました。
# 2162 件のデータを「0000010101_A4200」に保存しました。
# 2162 件のデータを「0000010101_A420001」に保存しました。
# 2162 件のデータを「0000010101_A420002」に保存しました。
# 2162 件のデータを「0000010101_A4201」に保存しました。
# 1551 件のデータを「0000010101_A420101」に保存しました。
# 1551 件のデータを「0000010101_A420102」に保存しました。
# 1551 件のデータを「0000010101_A4202」に保存しました。
# 1551 件のデータを「0000010101_A420201」に保存しました。
# 1551 件のデータを「0000010101_A420202」に保存しました。
# 1551 件のデータを「0000010101_A4203」に保存しました。
# 1551 件のデータを「0000010101_A420301」に保存しました。
# 1551 件のデータを「0000010101_A420302」に保存しました。
# 1551 件のデータを「0000010101_A4204」に保存しました。
# 1551 件のデータを「0000010101_A420401」に保存しました。
# 1551 件のデータを「0000010101_A420402」に保存しました。
# 1551 件のデータを「0000010101_A4205」に保存しました。
# 1551 件のデータを「0000010101_A420501」に保存しました。
# 1551 件のデータを「0000010101_A420502」に保存しました。
# 1551 件のデータを「0000010101_A4206」に保存しました。
# 1551 件のデータを「0000010101_A420601」に保存しました。
# 1551 件のデータを「0000010101_A420602」に保存しました。
# 1551 件のデータを「0000010101_A4207」に保存しました。
# 1551 件のデータを「0000010101_A420701」に保存しました。
# 1551 件のデータを「0000010101_A420702」に保存しました。
# 1551 件のデータを「0000010101_A4208」に保存しました。
# 1551 件のデータを「0000010101_A420801」に保存しました。
# 1551 件のデータを「0000010101_A420802」に保存しました。
# 1551 件のデータを「0000010101_A4209」に保存しました。
# 1551 件のデータを「0000010101_A420901」に保存しました。
# 1551 件のデータを「0000010101_A420902」に保存しました。
# 1551 件のデータを「0000010101_A4210」に保存しました。
# 1551 件のデータを「0000010101_A421001」に保存しました。
# 1551 件のデータを「0000010101_A421002」に保存しました。
# 1551 件のデータを「0000010101_A4211」に保存しました。
# 1551 件のデータを「0000010101_A421101」に保存しました。
# 1551 件のデータを「0000010101_A421102」に保存しました。
# 1551 件のデータを「0000010101_A4212」に保存しました。
# 1551 件のデータを「0000010101_A421201」に保存しました。
# 1551 件のデータを「0000010101_A421202」に保存しました。
# 1551 件のデータを「0000010101_A4213」に保存しました。
# 1551 件のデータを「0000010101_A421301」に保存しました。
# 1551 件のデータを「0000010101_A421302」に保存しました。
# 1551 件のデータを「0000010101_A4214」に保存しました。
# 1551 件のデータを「0000010101_A421401」に保存しました。
# 1551 件のデータを「0000010101_A421402」に保存しました。
# 1551 件のデータを「0000010101_A4215」に保存しました。
# 1551 件のデータを「0000010101_A421501」に保存しました。
# 1551 件のデータを「0000010101_A421502」に保存しました。
# 1551 件のデータを「0000010101_A4216」に保存しました。
# 1551 件のデータを「0000010101_A421601」に保存しました。
# 1551 件のデータを「0000010101_A421602」に保存しました。
# 1551 件のデータを「0000010101_A4217」に保存しました。
# 1551 件のデータを「0000010101_A421701」に保存しました。
# 1551 件のデータを「0000010101_A421702」に保存しました。
# 1551 件のデータを「0000010101_A4218」に保存しました。
# 1551 件のデータを「0000010101_A421801」に保存しました。
# 1551 件のデータを「0000010101_A421802」に保存しました。
# 1551 件のデータを「0000010101_A4219」に保存しました。
# 1551 件のデータを「0000010101_A421901」に保存しました。
# 1551 件のデータを「0000010101_A421902」に保存しました。
# 1551 件のデータを「0000010101_A4220」に保存しました。
# 1551 件のデータを「0000010101_A422001」に保存しました。
# 1551 件のデータを「0000010101_A422002」に保存しました。
# 1551 件のデータを「0000010101_A4221」に保存しました。
# 1551 件のデータを「0000010101_A422101」に保存しました。
# 1551 件のデータを「0000010101_A422102」に保存しました。
# 2162 件のデータを「0000010101_A4231」に保存しました。
# 2162 件のデータを「0000010101_A423101」に保存しました。
# 2162 件のデータを「0000010101_A423102」に保存しました。
# 423 件のデータを「0000010101_A424001」に保存しました。
# 423 件のデータを「0000010101_A424002」に保存しました。
# 2162 件のデータを「0000010101_A4270」に保存しました。
# 1551 件のデータを「0000010101_A427001」に保存しました。
# 1222 件のデータを「0000010101_A4271」に保存しました。
# 1222 件のデータを「0000010101_A4272」に保存しました。
# 2162 件のデータを「0000010101_A4280」に保存しました。
# 2162 件のデータを「0000010101_A4281」に保存しました。
# 423 件のデータを「0000010101_A4301」に保存しました。
# 2162 件のデータを「0000010101_A5101」に保存しました。
# 2162 件のデータを「0000010101_A510101」に保存しました。
# 2162 件のデータを「0000010101_A510102」に保存しました。
# 2162 件のデータを「0000010101_A5102」に保存しました。
# 2162 件のデータを「0000010101_A510201」に保存しました。
# 2162 件のデータを「0000010101_A510202」に保存しました。
# 329 件のデータを「0000010101_A5103」に保存しました。
# 329 件のデータを「0000010101_A510301」に保存しました。
# 329 件のデータを「0000010101_A510302」に保存しました。
# 329 件のデータを「0000010101_A5104」に保存しました。
# 329 件のデータを「0000010101_A510401」に保存しました。
# 329 件のデータを「0000010101_A510402」に保存しました。
# 1880 件のデータを「0000010101_A5201」に保存しました。
# 1880 件のデータを「0000010101_A520101」に保存しました。
# 1880 件のデータを「0000010101_A520102」に保存しました。
# 1880 件のデータを「0000010101_A5202」に保存しました。
# 1880 件のデータを「0000010101_A520201」に保存しました。
# 1880 件のデータを「0000010101_A520202」に保存しました。
# 94 件のデータを「0000010101_A5301」に保存しました。
# 376 件のデータを「0000010101_A6101」に保存しました。
# 282 件のデータを「0000010101_A610101」に保存しました。
# 282 件のデータを「0000010101_A610102」に保存しました。
# 376 件のデータを「0000010101_A6102」に保存しました。
# 282 件のデータを「0000010101_A610201」に保存しました。
# 282 件のデータを「0000010101_A610202」に保存しました。
# 376 件のデータを「0000010101_A6103」に保存しました。
# 282 件のデータを「0000010101_A610301」に保存しました。
# 282 件のデータを「0000010101_A610302」に保存しました。
# 423 件のデータを「0000010101_A6104」に保存しました。
# 282 件のデータを「0000010101_A610401」に保存しました。
# 282 件のデータを「0000010101_A610402」に保存しました。
# 423 件のデータを「0000010101_A6105」に保存しました。
# 282 件のデータを「0000010101_A610501」に保存しました。
# 282 件のデータを「0000010101_A610502」に保存しました。
# 423 件のデータを「0000010101_A6106」に保存しました。
# 282 件のデータを「0000010101_A610601」に保存しました。
# 282 件のデータを「0000010101_A610602」に保存しました。
# 376 件のデータを「0000010101_A6107」に保存しました。
# 282 件のデータを「0000010101_A610701」に保存しました。
# 282 件のデータを「0000010101_A610702」に保存しました。
# 188 件のデータを「0000010101_A6108」に保存しました。
# 423 件のデータを「0000010101_A7101」に保存しました。
# 376 件のデータを「0000010101_A710101」に保存しました。
# 376 件のデータを「0000010101_A710102」に保存しました。
# 376 件のデータを「0000010101_A710201」に保存しました。
# 376 件のデータを「0000010101_A710202」に保存しました。
# 376 件のデータを「0000010101_A710211」に保存しました。
# 2162 件のデータを「0000010101_A7103」に保存しました。
# 376 件のデータを「0000010101_A810101」に保存しました。
# 423 件のデータを「0000010101_A810102」に保存しました。
# 376 件のデータを「0000010101_A810103」に保存しました。
# 376 件のデータを「0000010101_A810104」に保存しました。
# 423 件のデータを「0000010101_A810105」に保存しました。
# 423 件のデータを「0000010101_A8111」に保存しました。
# 376 件のデータを「0000010101_A811101」に保存しました。
# 188 件のデータを「0000010101_A811102」に保存しました。
# 282 件のデータを「0000010101_A811103」に保存しました。
# 282 件のデータを「0000010101_A811104」に保存しました。
# 376 件のデータを「0000010101_A811105」に保存しました。
# 376 件のデータを「0000010101_A8112」に保存しました。
# 376 件のデータを「0000010101_A811201」に保存しました。
# 376 件のデータを「0000010101_A811202」に保存しました。
# 282 件のデータを「0000010101_A811203」に保存しました。
# 282 件のデータを「0000010101_A811204」に保存しました。
# 282 件のデータを「0000010101_A811205」に保存しました。
# 329 件のデータを「0000010101_A8201」に保存しました。
# 235 件のデータを「0000010101_A8202」に保存しました。
# 376 件のデータを「0000010101_A8301」に保存しました。
# 376 件のデータを「0000010101_A830101」に保存しました。
# 376 件のデータを「0000010101_A830102」に保存しました。
# 282 件のデータを「0000010101_A8303」に保存しました。
# 282 件のデータを「0000010101_A830301」に保存しました。
# 282 件のデータを「0000010101_A830302」に保存しました。
# 376 件のデータを「0000010101_A8401」に保存しました。
# 376 件のデータを「0000010101_A840101」に保存しました。
# 376 件のデータを「0000010101_A840102」に保存しました。
# 376 件のデータを「0000010101_A840103」に保存しました。
# 376 件のデータを「0000010101_A840201」に保存しました。
# 376 件のデータを「0000010101_A840202」に保存しました。
# 376 件のデータを「0000010101_A840203」に保存しました。
# 376 件のデータを「0000010101_A840204」に保存しました。
# 376 件のデータを「0000010101_A840205」に保存しました。
# 376 件のデータを「0000010101_A8501」に保存しました。
# 376 件のデータを「0000010101_A850101」に保存しました。
# 376 件のデータを「0000010101_A850102」に保存しました。
# 376 件のデータを「0000010101_A850103」に保存しました。
# 376 件のデータを「0000010101_A850201」に保存しました。
# 376 件のデータを「0000010101_A850202」に保存しました。
# 376 件のデータを「0000010101_A850203」に保存しました。
# 376 件のデータを「0000010101_A850204」に保存しました。
# 376 件のデータを「0000010101_A850205」に保存しました。
# 2162 件のデータを「0000010101_A9101」に保存しました。
# 2162 件のデータを「0000010101_A9111」に保存しました。
# 2162 件のデータを「0000010101_A9112」に保存しました。
# 2162 件のデータを「0000010101_A9201」に保存しました。
# 2162 件のデータを「0000010102_B1101」に保存しました。
# 2162 件のデータを「0000010102_B1102」に保存しました。
# 2162 件のデータを「0000010102_B1103」に保存しました。
# 1457 件のデータを「0000010102_B1104」に保存しました。
# 329 件のデータを「0000010102_B1105」に保存しました。
# 329 件のデータを「0000010102_B1106」に保存しました。
# 329 件のデータを「0000010102_B1107」に保存しました。
# 2162 件のデータを「0000010102_B1108」に保存しました。
# 2115 件のデータを「0000010102_B1201」に保存しました。
# 2115 件のデータを「0000010102_B120101」に保存しました。
# 2115 件のデータを「0000010102_B120102」に保存しました。
# 2115 件のデータを「0000010102_B120103」に保存しました。
# 1551 件のデータを「0000010102_B120104」に保存しました。
# 1551 件のデータを「0000010102_B120105」に保存しました。
# 1551 件のデータを「0000010102_B120106」に保存しました。
# 1551 件のデータを「0000010102_B120107」に保存しました。
# 376 件のデータを「0000010102_B1303」に保存しました。
# 2162 件のデータを「0000010102_B2101」に保存しました。
# 2162 件のデータを「0000010102_B2102」に保存しました。
# 2162 件のデータを「0000010102_B2103」に保存しました。
# 2162 件のデータを「0000010102_B2104」に保存しました。
# 2162 件のデータを「0000010102_B2105」に保存しました。
# 141 件のデータを「0000010102_B3101」に保存しました。
# 141 件のデータを「0000010102_B3102」に保存しました。
# 141 件のデータを「0000010102_B3103」に保存しました。
# 141 件のデータを「0000010102_B3104」に保存しました。
# 141 件のデータを「0000010102_B3105」に保存しました。
# 141 件のデータを「0000010102_B3106」に保存しました。
# 141 件のデータを「0000010102_B3107」に保存しました。
# 141 件のデータを「0000010102_B3108」に保存しました。
# 141 件のデータを「0000010102_B3109」に保存しました。
# 141 件のデータを「0000010102_B3110」に保存しました。
# 2162 件のデータを「0000010102_B4101」に保存しました。
# 2162 件のデータを「0000010102_B4102」に保存しました。
# 2162 件のデータを「0000010102_B4103」に保存しました。
# 2162 件のデータを「0000010102_B4104」に保存しました。
# 1551 件のデータを「0000010102_B4105」に保存しました。
# 2162 件のデータを「0000010102_B4106」に保存しました。
# 2162 件のデータを「0000010102_B4107」に保存しました。
# 2162 件のデータを「0000010102_B4108」に保存しました。
# 2162 件のデータを「0000010102_B4109」に保存しました。
# 1551 件のデータを「0000010102_B4110」に保存しました。
# 2162 件のデータを「0000010102_B4111」に保存しました。
# 1551 件のデータを「0000010102_B4112」に保存しました。
# 658 件のデータを「0000010103_C1101」に保存しました。
# 658 件のデータを「0000010103_C1102」に保存しました。
# 658 件のデータを「0000010103_C110201」に保存しました。
# 658 件のデータを「0000010103_C110202」に保存しました。
# 658 件のデータを「0000010103_C110203」に保存しました。
# 658 件のデータを「0000010103_C110204」に保存しました。
# 658 件のデータを「0000010103_C110205」に保存しました。
# 658 件のデータを「0000010103_C110206」に保存しました。
# 658 件のデータを「0000010103_C110207」に保存しました。
# 658 件のデータを「0000010103_C110208」に保存しました。
# 658 件のデータを「0000010103_C110209」に保存しました。
# 658 件のデータを「0000010103_C110210」に保存しました。
# 658 件のデータを「0000010103_C110211」に保存しました。
# 658 件のデータを「0000010103_C1102121」に保存しました。
# 658 件のデータを「0000010103_C1102122」に保存しました。
# 658 件のデータを「0000010103_C110213」に保存しました。
# 658 件のデータを「0000010103_C1103」に保存しました。
# 658 件のデータを「0000010103_C110301」に保存しました。
# 658 件のデータを「0000010103_C110302」に保存しました。
# 658 件のデータを「0000010103_C110303」に保存しました。
# 658 件のデータを「0000010103_C1104」に保存しました。
# 94 件のデータを「0000010103_C1105」に保存しました。
# 94 件のデータを「0000010103_C1106」に保存しました。
# 94 件のデータを「0000010103_C1107」に保存しました。
# 564 件のデータを「0000010103_C1111」に保存しました。
# 564 件のデータを「0000010103_C111201」に保存しました。
# 564 件のデータを「0000010103_C111202」に保存しました。
# 564 件のデータを「0000010103_C111203」に保存しました。
# 564 件のデータを「0000010103_C111204」に保存しました。
# 564 件のデータを「0000010103_C111205」に保存しました。
# 564 件のデータを「0000010103_C111206」に保存しました。
# 564 件のデータを「0000010103_C111207」に保存しました。
# 564 件のデータを「0000010103_C111208」に保存しました。
# 564 件のデータを「0000010103_C111209」に保存しました。
# 564 件のデータを「0000010103_C111210」に保存しました。
# 564 件のデータを「0000010103_C111211」に保存しました。
# 564 件のデータを「0000010103_C1112121」に保存しました。
# 564 件のデータを「0000010103_C1112122」に保存しました。
# 564 件のデータを「0000010103_C111213」に保存しました。
# 564 件のデータを「0000010103_C111214」に保存しました。
# 564 件のデータを「0000010103_C111215」に保存しました。
# 564 件のデータを「0000010103_C111216」に保存しました。
# 564 件のデータを「0000010103_C111217」に保存しました。
# 564 件のデータを「0000010103_C111218」に保存しました。
# 564 件のデータを「0000010103_C1115」に保存しました。
# 564 件のデータを「0000010103_C1116」に保存しました。
# 564 件のデータを「0000010103_C1117」に保存しました。
# 658 件のデータを「0000010103_C1201」に保存しました。
# 658 件のデータを「0000010103_C120101」に保存しました。
# 1692 件のデータを「0000010103_C120110」に保存しました。
# 1692 件のデータを「0000010103_C120120」に保存しました。
# 517 件のデータを「0000010103_C120130」に保存しました。
# 658 件のデータを「0000010103_C1202」に保存しました。
# 658 件のデータを「0000010103_C120201」に保存しました。
# 658 件のデータを「0000010103_C1203」に保存しました。
# 658 件のデータを「0000010103_C1204」に保存しました。
# 564 件のデータを「0000010103_C1211」に保存しました。
# 564 件のデータを「0000010103_C121101」に保存しました。
# 564 件のデータを「0000010103_C1212」に保存しました。
# 564 件のデータを「0000010103_C121201」に保存しました。
# 564 件のデータを「0000010103_C1213」に保存しました。
# 564 件のデータを「0000010103_C1214」に保存しました。
# 658 件のデータを「0000010103_C1301」に保存しました。
# 658 件のデータを「0000010103_C1302」に保存しました。
# 658 件のデータを「0000010103_C1303」に保存しました。
# 658 件のデータを「0000010103_C130301」に保存しました。
# 658 件のデータを「0000010103_C130302」に保存しました。
# 658 件のデータを「0000010103_C1304」に保存しました。
# 658 件のデータを「0000010103_C1305」に保存しました。
# 658 件のデータを「0000010103_C1306」に保存しました。
# 658 件のデータを「0000010103_C1307」に保存しました。
# 658 件のデータを「0000010103_C1308」に保存しました。
# 564 件のデータを「0000010103_C1311」に保存しました。
# 564 件のデータを「0000010103_C1312」に保存しました。
# 564 件のデータを「0000010103_C1313」に保存しました。
# 564 件のデータを「0000010103_C131301」に保存しました。
# 564 件のデータを「0000010103_C131302」に保存しました。
# 564 件のデータを「0000010103_C1314」に保存しました。
# 564 件のデータを「0000010103_C1315」に保存しました。
# 564 件のデータを「0000010103_C1316」に保存しました。
# 564 件のデータを「0000010103_C1317」に保存しました。
# 564 件のデータを「0000010103_C1318」に保存しました。
# 658 件のデータを「0000010103_C1401」に保存しました。
# 658 件のデータを「0000010103_C1402」に保存しました。
# 658 件のデータを「0000010103_C1403」に保存しました。
# 658 件のデータを「0000010103_C140301」に保存しました。
# 658 件のデータを「0000010103_C140302」に保存しました。
# 658 件のデータを「0000010103_C1404」に保存しました。
# 658 件のデータを「0000010103_C1405」に保存しました。
# 658 件のデータを「0000010103_C1406」に保存しました。
# 658 件のデータを「0000010103_C1407」に保存しました。
# 658 件のデータを「0000010103_C1408」に保存しました。
# 564 件のデータを「0000010103_C1411」に保存しました。
# 564 件のデータを「0000010103_C1412」に保存しました。
# 564 件のデータを「0000010103_C1413」に保存しました。
# 564 件のデータを「0000010103_C141301」に保存しました。
# 564 件のデータを「0000010103_C141302」に保存しました。
# 564 件のデータを「0000010103_C1416」に保存しました。
# 564 件のデータを「0000010103_C1417」に保存しました。
# 376 件のデータを「0000010103_C2101」に保存しました。
# 470 件のデータを「0000010103_C2102」に保存しました。
# 282 件のデータを「0000010103_C210220」に保存しました。
# 282 件のデータを「0000010103_C210230」に保存しました。
# 282 件のデータを「0000010103_C210231」に保存しました。
# 47 件のデータを「0000010103_C210232」に保存しました。
# 376 件のデータを「0000010103_C2103」に保存しました。
# 188 件のデータを「0000010103_C210301」に保存しました。
# 188 件のデータを「0000010103_C210302」に保存しました。
# 188 件のデータを「0000010103_C210303」に保存しました。
# 376 件のデータを「0000010103_C2104」に保存しました。
# 376 件のデータを「0000010103_C2105」に保存しました。
# 94 件のデータを「0000010103_C2106」に保存しました。
# 141 件のデータを「0000010103_C2107」に保存しました。
# 94 件のデータを「0000010103_C210701」に保存しました。
# 94 件のデータを「0000010103_C210702」に保存しました。
# 94 件のデータを「0000010103_C210703」に保存しました。
# 94 件のデータを「0000010103_C210704」に保存しました。
# 94 件のデータを「0000010103_C210705」に保存しました。
# 94 件のデータを「0000010103_C210706」に保存しました。
# 94 件のデータを「0000010103_C210707」に保存しました。
# 94 件のデータを「0000010103_C210708」に保存しました。
# 94 件のデータを「0000010103_C210709」に保存しました。
# 94 件のデータを「0000010103_C210710」に保存しました。
# 94 件のデータを「0000010103_C210711」に保存しました。
# 94 件のデータを「0000010103_C210712」に保存しました。
# 94 件のデータを「0000010103_C210713」に保存しました。
# 94 件のデータを「0000010103_C210714」に保存しました。
# 94 件のデータを「0000010103_C210715」に保存しました。
# 94 件のデータを「0000010103_C210716」に保存しました。
# 94 件のデータを「0000010103_C210717」に保存しました。
# 94 件のデータを「0000010103_C210718」に保存しました。
# 94 件のデータを「0000010103_C210719」に保存しました。
# 94 件のデータを「0000010103_C210720」に保存しました。
# 94 件のデータを「0000010103_C210721」に保存しました。
# 94 件のデータを「0000010103_C210722」に保存しました。
# 94 件のデータを「0000010103_C210723」に保存しました。
# 94 件のデータを「0000010103_C210724」に保存しました。
# 94 件のデータを「0000010103_C210725」に保存しました。
# 188 件のデータを「0000010103_C2108」に保存しました。
# 188 件のデータを「0000010103_C210801」に保存しました。
# 188 件のデータを「0000010103_C210802」に保存しました。
# 188 件のデータを「0000010103_C210803」に保存しました。
# 188 件のデータを「0000010103_C210804」に保存しました。
# 188 件のデータを「0000010103_C210805」に保存しました。
# 188 件のデータを「0000010103_C210806」に保存しました。
# 188 件のデータを「0000010103_C210807」に保存しました。
# 188 件のデータを「0000010103_C210820」に保存しました。
# 188 件のデータを「0000010103_C210821」に保存しました。
# 188 件のデータを「0000010103_C210822」に保存しました。
# 188 件のデータを「0000010103_C210823」に保存しました。
# 141 件のデータを「0000010103_C210831」に保存しました。
# 141 件のデータを「0000010103_C210832」に保存しました。
# 141 件のデータを「0000010103_C210833」に保存しました。
# 141 件のデータを「0000010103_C210834」に保存しました。
# 141 件のデータを「0000010103_C210835」に保存しました。
# 141 件のデータを「0000010103_C210836」に保存しました。
# 141 件のデータを「0000010103_C210837」に保存しました。
# 141 件のデータを「0000010103_C210838」に保存しました。
# 141 件のデータを「0000010103_C210839」に保存しました。
# 141 件のデータを「0000010103_C210840」に保存しました。
# 141 件のデータを「0000010103_C210841」に保存しました。
# 141 件のデータを「0000010103_C210842」に保存しました。
# 141 件のデータを「0000010103_C210843」に保存しました。
# 141 件のデータを「0000010103_C210844」に保存しました。
# 141 件のデータを「0000010103_C210845」に保存しました。
# 141 件のデータを「0000010103_C210846」に保存しました。
# 141 件のデータを「0000010103_C210847」に保存しました。
# 141 件のデータを「0000010103_C210848」に保存しました。
# 141 件のデータを「0000010103_C210849」に保存しました。
# 141 件のデータを「0000010103_C210850」に保存しました。
# 141 件のデータを「0000010103_C210851」に保存しました。
# 141 件のデータを「0000010103_C210852」に保存しました。
# 141 件のデータを「0000010103_C2109」に保存しました。
# 94 件のデータを「0000010103_C210901」に保存しました。
# 94 件のデータを「0000010103_C210902」に保存しました。
# 94 件のデータを「0000010103_C210903」に保存しました。
# 94 件のデータを「0000010103_C210904」に保存しました。
# 94 件のデータを「0000010103_C2110」に保存しました。
# 94 件のデータを「0000010103_C2111」に保存しました。
# 94 件のデータを「0000010103_C2112」に保存しました。
# 376 件のデータを「0000010103_C2201」に保存しました。
# 470 件のデータを「0000010103_C2202」に保存しました。
# 282 件のデータを「0000010103_C220220」に保存しました。
# 282 件のデータを「0000010103_C220230」に保存しました。
# 282 件のデータを「0000010103_C220231」に保存しました。
# 47 件のデータを「0000010103_C220232」に保存しました。
# 376 件のデータを「0000010103_C2203」に保存しました。
# 188 件のデータを「0000010103_C220301」に保存しました。
# 188 件のデータを「0000010103_C220302」に保存しました。
# 188 件のデータを「0000010103_C220303」に保存しました。
# 376 件のデータを「0000010103_C2204」に保存しました。
# 376 件のデータを「0000010103_C2205」に保存しました。
# 94 件のデータを「0000010103_C2206」に保存しました。
# 94 件のデータを「0000010103_C2207」に保存しました。
# 94 件のデータを「0000010103_C220701」に保存しました。
# 94 件のデータを「0000010103_C220702」に保存しました。
# 94 件のデータを「0000010103_C220703」に保存しました。
# 94 件のデータを「0000010103_C220704」に保存しました。
# 94 件のデータを「0000010103_C220705」に保存しました。
# 94 件のデータを「0000010103_C220706」に保存しました。
# 94 件のデータを「0000010103_C220707」に保存しました。
# 94 件のデータを「0000010103_C220708」に保存しました。
# 94 件のデータを「0000010103_C220709」に保存しました。
# 94 件のデータを「0000010103_C220710」に保存しました。
# 94 件のデータを「0000010103_C220711」に保存しました。
# 94 件のデータを「0000010103_C220712」に保存しました。
# 94 件のデータを「0000010103_C220713」に保存しました。
# 94 件のデータを「0000010103_C220714」に保存しました。
# 94 件のデータを「0000010103_C220715」に保存しました。
# 94 件のデータを「0000010103_C220716」に保存しました。
# 94 件のデータを「0000010103_C220717」に保存しました。
# 94 件のデータを「0000010103_C220718」に保存しました。
# 94 件のデータを「0000010103_C220719」に保存しました。
# 94 件のデータを「0000010103_C220720」に保存しました。
# 94 件のデータを「0000010103_C220721」に保存しました。
# 94 件のデータを「0000010103_C220722」に保存しました。
# 94 件のデータを「0000010103_C220723」に保存しました。
# 94 件のデータを「0000010103_C220724」に保存しました。
# 94 件のデータを「0000010103_C220725」に保存しました。
# 188 件のデータを「0000010103_C2208」に保存しました。
# 188 件のデータを「0000010103_C220801」に保存しました。
# 188 件のデータを「0000010103_C220802」に保存しました。
# 188 件のデータを「0000010103_C220803」に保存しました。
# 188 件のデータを「0000010103_C220804」に保存しました。
# 188 件のデータを「0000010103_C220805」に保存しました。
# 188 件のデータを「0000010103_C220806」に保存しました。
# 188 件のデータを「0000010103_C220807」に保存しました。
# 188 件のデータを「0000010103_C220820」に保存しました。
# 188 件のデータを「0000010103_C220821」に保存しました。
# 188 件のデータを「0000010103_C220822」に保存しました。
# 188 件のデータを「0000010103_C220823」に保存しました。
# 141 件のデータを「0000010103_C220831」に保存しました。
# 141 件のデータを「0000010103_C220832」に保存しました。
# 141 件のデータを「0000010103_C220833」に保存しました。
# 141 件のデータを「0000010103_C220834」に保存しました。
# 141 件のデータを「0000010103_C220835」に保存しました。
# 141 件のデータを「0000010103_C220836」に保存しました。
# 141 件のデータを「0000010103_C220837」に保存しました。
# 141 件のデータを「0000010103_C220838」に保存しました。
# 141 件のデータを「0000010103_C220839」に保存しました。
# 141 件のデータを「0000010103_C220840」に保存しました。
# 141 件のデータを「0000010103_C220841」に保存しました。
# 141 件のデータを「0000010103_C220842」に保存しました。
# 141 件のデータを「0000010103_C220843」に保存しました。
# 141 件のデータを「0000010103_C220844」に保存しました。
# 141 件のデータを「0000010103_C220845」に保存しました。
# 141 件のデータを「0000010103_C220846」に保存しました。
# 141 件のデータを「0000010103_C220847」に保存しました。
# 141 件のデータを「0000010103_C220848」に保存しました。
# 141 件のデータを「0000010103_C220849」に保存しました。
# 141 件のデータを「0000010103_C220850」に保存しました。
# 141 件のデータを「0000010103_C220851」に保存しました。
# 141 件のデータを「0000010103_C220852」に保存しました。
# 94 件のデータを「0000010103_C2209」に保存しました。
# 94 件のデータを「0000010103_C220901」に保存しました。
# 94 件のデータを「0000010103_C220902」に保存しました。
# 94 件のデータを「0000010103_C220903」に保存しました。
# 94 件のデータを「0000010103_C220904」に保存しました。
# 94 件のデータを「0000010103_C2210」に保存しました。
# 94 件のデータを「0000010103_C2211」に保存しました。
# 94 件のデータを「0000010103_C2212」に保存しました。
# 2115 件のデータを「0000010103_C3101」に保存しました。
# 1551 件のデータを「0000010103_C3102」に保存しました。
# 235 件のデータを「0000010103_C310201」に保存しました。
# 235 件のデータを「0000010103_C310202」に保存しました。
# 188 件のデータを「0000010103_C310211」に保存しました。
# 188 件のデータを「0000010103_C310212」に保存しました。
# 47 件のデータを「0000010103_C310234」に保存しました。
# 47 件のデータを「0000010103_C310235」に保存しました。
# 47 件のデータを「0000010103_C310236」に保存しました。
# 47 件のデータを「0000010103_C310237」に保存しました。
# 47 件のデータを「0000010103_C310238」に保存しました。
# 47 件のデータを「0000010103_C310239」に保存しました。
# 47 件のデータを「0000010103_C310240」に保存しました。
# 47 件のデータを「0000010103_C310241」に保存しました。
# 47 件のデータを「0000010103_C310242」に保存しました。
# 470 件のデータを「0000010103_C310410」に保存しました。
# 470 件のデータを「0000010103_C310411」に保存しました。
# 470 件のデータを「0000010103_C310412」に保存しました。
# 470 件のデータを「0000010103_C310510」に保存しました。
# 94 件のデータを「0000010103_C310511」に保存しました。
# 376 件のデータを「0000010103_C310610」に保存しました。
# 376 件のデータを「0000010103_C310611」に保存しました。
# 188 件のデータを「0000010103_C310612」に保存しました。
# 376 件のデータを「0000010103_C310614」に保存しました。
# 2162 件のデータを「0000010103_C3107」に保存しました。
# 2162 件のデータを「0000010103_C310701」に保存しました。
# 2162 件のデータを「0000010103_C310702」に保存しました。
# 1598 件のデータを「0000010103_C310703」に保存しました。
# 1598 件のデータを「0000010103_C310704」に保存しました。
# 1598 件のデータを「0000010103_C310705」に保存しました。
# 893 件のデータを「0000010103_C3108」に保存しました。
# 94 件のデータを「0000010103_C3109」に保存しました。
# 1551 件のデータを「0000010103_C3110」に保存しました。
# 1551 件のデータを「0000010103_C3111」に保存しました。
# 1551 件のデータを「0000010103_C3112」に保存しました。
# 1833 件のデータを「0000010103_C3114」に保存しました。
# 1974 件のデータを「0000010103_C3120」に保存しました。
# 2115 件のデータを「0000010103_C312001」に保存しました。
# 1974 件のデータを「0000010103_C312002」に保存しました。
# 141 件のデータを「0000010103_C312003」に保存しました。
# 141 件のデータを「0000010103_C31201」に保存しました。
# 2115 件のデータを「0000010103_C3121」に保存しました。
# 2115 件のデータを「0000010103_C312101」に保存しました。
# 940 件のデータを「0000010103_C312102」に保存しました。
# 940 件のデータを「0000010103_C3122」に保存しました。
# 940 件のデータを「0000010103_C312201」に保存しました。
# 940 件のデータを「0000010103_C312202」に保存しました。
# 1363 件のデータを「0000010103_C312301」に保存しました。
# 1504 件のデータを「0000010103_C3125」に保存しました。
# 376 件のデータを「0000010103_C312601」に保存しました。
# 376 件のデータを「0000010103_C312602」に保存しました。
# 376 件のデータを「0000010103_C312701」に保存しました。
# 376 件のデータを「0000010103_C312702」に保存しました。
# 2162 件のデータを「0000010103_C3301」に保存しました。
# 2162 件のデータを「0000010103_C3302」に保存しました。
# 2162 件のデータを「0000010103_C3303」に保存しました。
# 2115 件のデータを「0000010103_C3304」に保存しました。
# 1551 件のデータを「0000010103_C330401」に保存しました。
# 1551 件のデータを「0000010103_C330402」に保存しました。
# 1551 件のデータを「0000010103_C330403」に保存しました。
# 1551 件のデータを「0000010103_C330410」に保存しました。
# 1551 件のデータを「0000010103_C330411」に保存しました。
# 1551 件のデータを「0000010103_C330412」に保存しました。
# 1551 件のデータを「0000010103_C330413」に保存しました。
# 1551 件のデータを「0000010103_C330420」に保存しました。
# 1551 件のデータを「0000010103_C330421」に保存しました。
# 1551 件のデータを「0000010103_C330422」に保存しました。
# 1551 件のデータを「0000010103_C330423」に保存しました。
# 2115 件のデータを「0000010103_C3305」に保存しました。
# 1551 件のデータを「0000010103_C330501」に保存しました。
# 1551 件のデータを「0000010103_C330502」に保存しました。
# 1551 件のデータを「0000010103_C330503」に保存しました。
# 940 件のデータを「0000010103_C3306」に保存しました。
# 329 件のデータを「0000010103_C3307」に保存しました。
# 329 件のデータを「0000010103_C3308」に保存しました。
# 2115 件のデータを「0000010103_C3401」に保存しました。
# 940 件のデータを「0000010103_C3402」に保存しました。
# 2115 件のデータを「0000010103_C3403」に保存しました。
# 2115 件のデータを「0000010103_C3404」に保存しました。
# 2115 件のデータを「0000010103_C3405」に保存しました。
# 1927 件のデータを「0000010103_C3406」に保存しました。
# 1927 件のデータを「0000010103_C340601」に保存しました。
# 1927 件のデータを「0000010103_C340602」に保存しました。
# 752 件のデータを「0000010103_C3501」に保存しました。
# 752 件のデータを「0000010103_C350101」に保存しました。
# 752 件のデータを「0000010103_C350102」に保存しました。
# 705 件のデータを「0000010103_C3502」に保存しました。
# 705 件のデータを「0000010103_C350201」に保存しました。
# 705 件のデータを「0000010103_C350202」に保存しました。
# 705 件のデータを「0000010103_C3503」に保存しました。
# 705 件のデータを「0000010103_C350301」に保存しました。
# 705 件のデータを「0000010103_C350302」に保存しました。
# 517 件のデータを「0000010103_C3505」に保存しました。
# 517 件のデータを「0000010103_C350501」に保存しました。
# 517 件のデータを「0000010103_C350502」に保存しました。
# 1410 件のデータを「0000010103_C3601」に保存しました。
# 2162 件のデータを「0000010103_C360111」に保存しました。
# 2162 件のデータを「0000010103_C360120」に保存しました。
# 1974 件のデータを「0000010103_C360211」に保存しました。
# 2162 件のデータを「0000010103_C360311」に保存しました。
# 705 件のデータを「0000010103_C3702」に保存しました。
# 705 件のデータを「0000010103_C370201」に保存しました。
# 705 件のデータを「0000010103_C3704」に保存しました。
# 705 件のデータを「0000010103_C3705」に保存しました。
# 2115 件のデータを「0000010103_C3706」に保存しました。
# 1645 件のデータを「0000010103_C370601」に保存しました。
# 2115 件のデータを「0000010103_C3707」に保存しました。
# 705 件のデータを「0000010103_C370701」に保存しました。
# 1833 件のデータを「0000010103_C3708」に保存しました。
# 2115 件のデータを「0000010103_C3709」に保存しました。
# 1833 件のデータを「0000010103_C3710」に保存しました。
# 1786 件のデータを「0000010103_C3711」に保存しました。
# 1598 件のデータを「0000010103_C3712」に保存しました。
# 282 件のデータを「0000010103_C3713」に保存しました。
# 282 件のデータを「0000010103_C3714」に保存しました。
# 235 件のデータを「0000010103_C3715」に保存しました。
# 2115 件のデータを「0000010103_C3801」に保存しました。
# 2115 件のデータを「0000010103_C3802」に保存しました。
# 987 件のデータを「0000010103_C3803」に保存しました。
# 987 件のデータを「0000010103_C3804」に保存しました。
# 1081 件のデータを「0000010103_C3805」に保存しました。
# 1598 件のデータを「0000010103_C5101」に保存しました。
# 1598 件のデータを「0000010103_C5102」に保存しました。
# 1598 件のデータを「0000010103_C5103」に保存しました。
# 1598 件のデータを「0000010103_C5104」に保存しました。
# 1598 件のデータを「0000010103_C5105」に保存しました。
# 1598 件のデータを「0000010103_C5106」に保存しました。
# 1598 件のデータを「0000010103_C5107」に保存しました。
# 1598 件のデータを「0000010103_C5108」に保存しました。
# 1598 件のデータを「0000010103_C5109」に保存しました。
# 1598 件のデータを「0000010103_C5110」に保存しました。
# 1598 件のデータを「0000010103_C5111」に保存しました。
# 1598 件のデータを「0000010103_C5112」に保存しました。
# 1598 件のデータを「0000010103_C5113」に保存しました。
# 2162 件のデータを「0000010103_C5114」に保存しました。
# 2162 件のデータを「0000010103_C5115」に保存しました。
# 752 件のデータを「0000010103_C5116」に保存しました。
# 2162 件のデータを「0000010103_C5117」に保存しました。
# 2162 件のデータを「0000010103_C5118」に保存しました。
# 2162 件のデータを「0000010103_C5119」に保存しました。
# 2162 件のデータを「0000010103_C5120」に保存しました。
# 2162 件のデータを「0000010103_C5121」に保存しました。
# 2162 件のデータを「0000010103_C5122」に保存しました。
# 2162 件のデータを「0000010103_C5123」に保存しました。
# 2162 件のデータを「0000010103_C5124」に保存しました。
# 2162 件のデータを「0000010103_C5125」に保存しました。
# 2162 件のデータを「0000010103_C5126」に保存しました。
# 282 件のデータを「0000010103_C5127」に保存しました。
# 235 件のデータを「0000010103_C5128」に保存しました。
# 329 件のデータを「0000010103_C5201」に保存しました。
# 329 件のデータを「0000010103_C5202」に保存しました。
# 329 件のデータを「0000010103_C5203」に保存しました。
# 282 件のデータを「0000010103_C5205」に保存しました。
# 282 件のデータを「0000010103_C5206」に保存しました。
# 282 件のデータを「0000010103_C5207」に保存しました。
# 282 件のデータを「0000010103_C5208」に保存しました。
# 282 件のデータを「0000010103_C5209」に保存しました。
# 282 件のデータを「0000010103_C5210」に保存しました。
# 282 件のデータを「0000010103_C5211」に保存しました。
# 282 件のデータを「0000010103_C5212」に保存しました。
# 282 件のデータを「0000010103_C5213」に保存しました。
# 282 件のデータを「0000010103_C5214」に保存しました。
# 1645 件のデータを「0000010103_C5301」に保存しました。
# 1598 件のデータを「0000010103_C5302」に保存しました。
# 1645 件のデータを「0000010103_C5303」に保存しました。
# 2115 件のデータを「0000010103_C5401」に保存しました。
# 2115 件のデータを「0000010103_C5403」に保存しました。
# 2115 件のデータを「0000010103_C5405」に保存しました。
# 2115 件のデータを「0000010103_C5501」に保存しました。
# 2115 件のデータを「0000010103_C5503」に保存しました。
# 2115 件のデータを「0000010103_C5505」に保存しました。
# 188 件のデータを「0000010103_C5601」に保存しました。
# 188 件のデータを「0000010103_C5602」に保存しました。
# 188 件のデータを「0000010103_C5603」に保存しました。
# 376 件のデータを「0000010103_C5701」に保存しました。
# 376 件のデータを「0000010103_C5702」に保存しました。
# 376 件のデータを「0000010103_C5703」に保存しました。
# 376 件のデータを「0000010103_C5704」に保存しました。
# 376 件のデータを「0000010103_C5705」に保存しました。
# 376 件のデータを「0000010103_C5706」に保存しました。
# 376 件のデータを「0000010103_C5707」に保存しました。
# 376 件のデータを「0000010103_C5708」に保存しました。
# 376 件のデータを「0000010103_C5709」に保存しました。
# 376 件のデータを「0000010103_C5710」に保存しました。
# 376 件のデータを「0000010103_C5711」に保存しました。
# 376 件のデータを「0000010103_C5712」に保存しました。
# 141 件のデータを「0000010103_C6101」に保存しました。
# 141 件のデータを「0000010103_C610101」に保存しました。
# 141 件のデータを「0000010103_C610102」に保存しました。
# 141 件のデータを「0000010103_C610103」に保存しました。
# 141 件のデータを「0000010103_C610104」に保存しました。
# 141 件のデータを「0000010103_C610105」に保存しました。
# 141 件のデータを「0000010103_C610106」に保存しました。
# 141 件のデータを「0000010103_C610107」に保存しました。
# 141 件のデータを「0000010103_C610108」に保存しました。
# 141 件のデータを「0000010103_C610109」に保存しました。
# 141 件のデータを「0000010103_C610110」に保存しました。
# 141 件のデータを「0000010103_C610111」に保存しました。
# 141 件のデータを「0000010103_C610112」に保存しました。
# 141 件のデータを「0000010103_C610113」に保存しました。
# 141 件のデータを「0000010103_C610114」に保存しました。
# 141 件のデータを「0000010103_C610115」に保存しました。
# 141 件のデータを「0000010103_C610116」に保存しました。
# 141 件のデータを「0000010103_C610117」に保存しました。
# 141 件のデータを「0000010103_C610118」に保存しました。
# 141 件のデータを「0000010103_C610119」に保存しました。
# 141 件のデータを「0000010103_C610120」に保存しました。
# 141 件のデータを「0000010103_C610121」に保存しました。
# 141 件のデータを「0000010103_C610122」に保存しました。
# 94 件のデータを「0000010103_C6201」に保存しました。
# 94 件のデータを「0000010103_C620101」に保存しました。
# 94 件のデータを「0000010103_C620102」に保存しました。
# 94 件のデータを「0000010103_C620103」に保存しました。
# 94 件のデータを「0000010103_C620104」に保存しました。
# 94 件のデータを「0000010103_C620105」に保存しました。
# 94 件のデータを「0000010103_C620106」に保存しました。
# 94 件のデータを「0000010103_C620107」に保存しました。
# 94 件のデータを「0000010103_C620108」に保存しました。
# 94 件のデータを「0000010103_C620109」に保存しました。
# 94 件のデータを「0000010103_C620110」に保存しました。
# 94 件のデータを「0000010103_C620111」に保存しました。
# 94 件のデータを「0000010103_C620112」に保存しました。
# 94 件のデータを「0000010103_C620113」に保存しました。
# 94 件のデータを「0000010103_C620114」に保存しました。
# 94 件のデータを「0000010103_C620115」に保存しました。
# 94 件のデータを「0000010103_C620116」に保存しました。
# 94 件のデータを「0000010103_C620117」に保存しました。
# 94 件のデータを「0000010103_C620118」に保存しました。
# 94 件のデータを「0000010103_C620119」に保存しました。
# 94 件のデータを「0000010103_C620120」に保存しました。
# 94 件のデータを「0000010103_C620121」に保存しました。
# 94 件のデータを「0000010103_C620122」に保存しました。
# 282 件のデータを「0000010103_C6301」に保存しました。
# 282 件のデータを「0000010103_C630101」に保存しました。
# 282 件のデータを「0000010103_C630102」に保存しました。
# 282 件のデータを「0000010103_C630103」に保存しました。
# 282 件のデータを「0000010103_C630104」に保存しました。
# 282 件のデータを「0000010103_C630105」に保存しました。
# 282 件のデータを「0000010103_C630106」に保存しました。
# 282 件のデータを「0000010103_C630107」に保存しました。
# 282 件のデータを「0000010103_C630108」に保存しました。
# 1081 件のデータを「0000010104_D110101」に保存しました。
# 2162 件のデータを「0000010104_D110102」に保存しました。
# 2162 件のデータを「0000010104_D110103」に保存しました。
# 1081 件のデータを「0000010104_D1201」に保存しました。
# 1081 件のデータを「0000010104_D1202」に保存しました。
# 1081 件のデータを「0000010104_D1203」に保存しました。
# 1081 件のデータを「0000010104_D1204」に保存しました。
# 1081 件のデータを「0000010104_D1205」に保存しました。
# 1034 件のデータを「0000010104_D1206」に保存しました。
# 940 件のデータを「0000010104_D1210」に保存しました。
# 940 件のデータを「0000010104_D1211」に保存しました。
# 940 件のデータを「0000010104_D1212」に保存しました。
# 2115 件のデータを「0000010104_D2101」に保存しました。
# 2115 件のデータを「0000010104_D2102」に保存しました。
# 2115 件のデータを「0000010104_D2103」に保存しました。
# 2115 件のデータを「0000010104_D2105」に保存しました。
# 2115 件のデータを「0000010104_D2106」に保存しました。
# 2115 件のデータを「0000010104_D2109」に保存しました。
# 2115 件のデータを「0000010104_D2110」に保存しました。
# 564 件のデータを「0000010104_D2111」に保存しました。
# 423 件のデータを「0000010104_D2112」に保存しました。
# 2115 件のデータを「0000010104_D2205」に保存しました。
# 2115 件のデータを「0000010104_D2206」に保存しました。
# 1081 件のデータを「0000010104_D2209」に保存しました。
# 1081 件のデータを「0000010104_D2210」に保存しました。
# 2115 件のデータを「0000010104_D3101」に保存しました。
# 2115 件のデータを「0000010104_D310101」に保存しました。
# 705 件のデータを「0000010104_D310102」に保存しました。
# 2115 件のデータを「0000010104_D310103」に保存しました。
# 1081 件のデータを「0000010104_D310104」に保存しました。
# 2115 件のデータを「0000010104_D310105」に保存しました。
# 2115 件のデータを「0000010104_D310106」に保存しました。
# 2115 件のデータを「0000010104_D310107」に保存しました。
# 2115 件のデータを「0000010104_D310108」に保存しました。
# 2115 件のデータを「0000010104_D310110」に保存しました。
# 705 件のデータを「0000010104_D310111」に保存しました。
# 705 件のデータを「0000010104_D310112」に保存しました。
# 705 件のデータを「0000010104_D310113」に保存しました。
# 705 件のデータを「0000010104_D310114」に保存しました。
# 2115 件のデータを「0000010104_D310115」に保存しました。
# 987 件のデータを「0000010104_D310116」に保存しました。
# 2115 件のデータを「0000010104_D3102」に保存しました。
# 2115 件のデータを「0000010104_D3103」に保存しました。
# 470 件のデータを「0000010104_D310301」に保存しました。
# 470 件のデータを「0000010104_D310302」に保存しました。
# 2115 件のデータを「0000010104_D310303」に保存しました。
# 2115 件のデータを「0000010104_D3103031」に保存しました。
# 2115 件のデータを「0000010104_D3103032」に保存しました。
# 2115 件のデータを「0000010104_D3103033」に保存しました。
# 2115 件のデータを「0000010104_D3103034」に保存しました。
# 2115 件のデータを「0000010104_D3103035」に保存しました。
# 2115 件のデータを「0000010104_D310304」に保存しました。
# 470 件のデータを「0000010104_D3103041」に保存しました。
# 1081 件のデータを「0000010104_D3103043」に保存しました。
# 705 件のデータを「0000010104_D3103044」に保存しました。
# 2115 件のデータを「0000010104_D3103045」に保存しました。
# 705 件のデータを「0000010104_D3103046」に保存しました。
# 2115 件のデータを「0000010104_D310305」に保存しました。
# 2115 件のデータを「0000010104_D3103051」に保存しました。
# 2115 件のデータを「0000010104_D3103052」に保存しました。
# 2115 件のデータを「0000010104_D3103053」に保存しました。
# 2115 件のデータを「0000010104_D310306」に保存しました。
# 2115 件のデータを「0000010104_D310307」に保存しました。
# 2115 件のデータを「0000010104_D310308」に保存しました。
# 2115 件のデータを「0000010104_D3103082」に保存しました。
# 2115 件のデータを「0000010104_D3103085」に保存しました。
# 2115 件のデータを「0000010104_D3103086」に保存しました。
# 2115 件のデータを「0000010104_D310309」に保存しました。
# 470 件のデータを「0000010104_D310310」に保存しました。
# 2115 件のデータを「0000010104_D310311」に保存しました。
# 2115 件のデータを「0000010104_D3103112」に保存しました。
# 2115 件のデータを「0000010104_D3103113」に保存しました。
# 2115 件のデータを「0000010104_D3103114」に保存しました。
# 2115 件のデータを「0000010104_D3103115」に保存しました。
# 2115 件のデータを「0000010104_D3103116」に保存しました。
# 2115 件のデータを「0000010104_D3103117」に保存しました。
# 470 件のデータを「0000010104_D3103118」に保存しました。
# 2115 件のデータを「0000010104_D310312」に保存しました。
# 2115 件のデータを「0000010104_D310313」に保存しました。
# 2115 件のデータを「0000010104_D310401」に保存しました。
# 1081 件のデータを「0000010104_D310402」に保存しました。
# 1081 件のデータを「0000010104_D310403」に保存しました。
# 2115 件のデータを「0000010104_D310404」に保存しました。
# 1081 件のデータを「0000010104_D310405」に保存しました。
# 2115 件のデータを「0000010104_D310406」に保存しました。
# 2115 件のデータを「0000010104_D310407」に保存しました。
# 2115 件のデータを「0000010104_D310408」に保存しました。
# 705 件のデータを「0000010104_D310409」に保存しました。
# 1081 件のデータを「0000010104_D310410」に保存しました。
# 1081 件のデータを「0000010104_D310411」に保存しました。
# 1081 件のデータを「0000010104_D310412」に保存しました。
# 2115 件のデータを「0000010104_D3105」に保存しました。
# 2115 件のデータを「0000010104_D3201」に保存しました。
# 2115 件のデータを「0000010104_D320101」に保存しました。
# 2115 件のデータを「0000010104_D320102」に保存しました。
# 1081 件のデータを「0000010104_D320103」に保存しました。
# 1081 件のデータを「0000010104_D320104」に保存しました。
# 1081 件のデータを「0000010104_D320105」に保存しました。
# 1081 件のデータを「0000010104_D320106」に保存しました。
# 470 件のデータを「0000010104_D320107」に保存しました。
# 2115 件のデータを「0000010104_D320108」に保存しました。
# 1081 件のデータを「0000010104_D320109」に保存しました。
# 2115 件のデータを「0000010104_D320110」に保存しました。
# 2115 件のデータを「0000010104_D320111」に保存しました。
# 2115 件のデータを「0000010104_D320113」に保存しました。
# 2115 件のデータを「0000010104_D320115」に保存しました。
# 705 件のデータを「0000010104_D320116」に保存しました。
# 705 件のデータを「0000010104_D320117」に保存しました。
# 2115 件のデータを「0000010104_D320118」に保存しました。
# 2115 件のデータを「0000010104_D320119」に保存しました。
# 2115 件のデータを「0000010104_D320120」に保存しました。
# 2115 件のデータを「0000010104_D320121」に保存しました。
# 987 件のデータを「0000010104_D320122」に保存しました。
# 2115 件のデータを「0000010104_D3202」に保存しました。
# 2115 件のデータを「0000010104_D3203」に保存しました。
# 470 件のデータを「0000010104_D3203001」に保存しました。
# 1081 件のデータを「0000010104_D320301」に保存しました。
# 1081 件のデータを「0000010104_D320302」に保存しました。
# 2115 件のデータを「0000010104_D320303」に保存しました。
# 2115 件のデータを「0000010104_D3203031」に保存しました。
# 2115 件のデータを「0000010104_D3203032」に保存しました。
# 2115 件のデータを「0000010104_D3203033」に保存しました。
# 2115 件のデータを「0000010104_D3203034」に保存しました。
# 2115 件のデータを「0000010104_D3203035」に保存しました。
# 2115 件のデータを「0000010104_D320304」に保存しました。
# 2115 件のデータを「0000010104_D3203042」に保存しました。
# ...
# 658 件のデータを「0000010105_E580101」に保存しました。
# 658 件のデータを「0000010105_E580102」に保存しました。
# 658 件のデータを「0000010105_E580103」に保存しました。
# 658 件のデータを「0000010105_E580104」に保存しました。
# 2162 件のデータを「0000010105_E6101」に保存しました。
# 1598 件のデータを「0000010105_E610101」に保存しました。
# 1598 件のデータを「0000010105_E610102」に保存しました。
# 1598 件のデータを「0000010105_E610103」に保存しました。
# 2162 件のデータを「0000010105_E6102」に保存しました。
# 1598 件のデータを「0000010105_E610201」に保存しました。
# 1598 件のデータを「0000010105_E610202」に保存しました。
# 1598 件のデータを「0000010105_E610203」に保存しました。
# 2162 件のデータを「0000010105_E6201」に保存しました。
# 1598 件のデータを「0000010105_E620101」に保存しました。
# 1598 件のデータを「0000010105_E620102」に保存しました。
# 1598 件のデータを「0000010105_E620110」に保存しました。
# 1598 件のデータを「0000010105_E620120」に保存しました。
# 1598 件のデータを「0000010105_E620130」に保存しました。
# 2162 件のデータを「0000010105_E6202」に保存しました。
# 1598 件のデータを「0000010105_E620201」に保存しました。
# 1598 件のデータを「0000010105_E620202」に保存しました。
# 1598 件のデータを「0000010105_E620210」に保存しました。
# 1598 件のデータを「0000010105_E620220」に保存しました。
# 1598 件のデータを「0000010105_E620230」に保存しました。
# 2162 件のデータを「0000010105_E6301」に保存しました。
# 2162 件のデータを「0000010105_E630101」に保存しました。
# 2162 件のデータを「0000010105_E630102」に保存しました。
# 1598 件のデータを「0000010105_E630110」に保存しました。
# 1598 件のデータを「0000010105_E630111」に保存しました。
# 1598 件のデータを「0000010105_E630112」に保存しました。
# 1598 件のデータを「0000010105_E630120」に保存しました。
# 1598 件のデータを「0000010105_E630121」に保存しました。
# 1598 件のデータを「0000010105_E630122」に保存しました。
# 1598 件のデータを「0000010105_E630130」に保存しました。
# 1598 件のデータを「0000010105_E630131」に保存しました。
# 1598 件のデータを「0000010105_E630132」に保存しました。
# 2162 件のデータを「0000010105_E6302」に保存しました。
# 2162 件のデータを「0000010105_E630201」に保存しました。
# 2162 件のデータを「0000010105_E630202」に保存しました。
# 2162 件のデータを「0000010105_E630210」に保存しました。
# 1598 件のデータを「0000010105_E630211」に保存しました。
# 1598 件のデータを「0000010105_E630212」に保存しました。
# 2162 件のデータを「0000010105_E630220」に保存しました。
# 1598 件のデータを「0000010105_E630221」に保存しました。
# 1598 件のデータを「0000010105_E630222」に保存しました。
# 2162 件のデータを「0000010105_E630230」に保存しました。
# 1598 件のデータを「0000010105_E630231」に保存しました。
# 1598 件のデータを「0000010105_E630232」に保存しました。
# 2162 件のデータを「0000010105_E6401」に保存しました。
# 1598 件のデータを「0000010105_E640101」に保存しました。
# 1598 件のデータを「0000010105_E640102」に保存しました。
# 2162 件のデータを「0000010105_E6402」に保存しました。
# 1598 件のデータを「0000010105_E640201」に保存しました。
# 1598 件のデータを「0000010105_E640202」に保存しました。
# 2162 件のデータを「0000010105_E6403」に保存しました。
# 1598 件のデータを「0000010105_E640301」に保存しました。
# 1598 件のデータを「0000010105_E640302」に保存しました。
# 2115 件のデータを「0000010105_E6501」に保存しました。
# 1551 件のデータを「0000010105_E650101」に保存しました。
# 1551 件のデータを「0000010105_E650102」に保存しました。
# 2115 件のデータを「0000010105_E650110」に保存しました。
# 1551 件のデータを「0000010105_E650111」に保存しました。
# 1551 件のデータを「0000010105_E650112」に保存しました。
# 2115 件のデータを「0000010105_E650120」に保存しました。
# 1551 件のデータを「0000010105_E650121」に保存しました。
# 1551 件のデータを「0000010105_E650122」に保存しました。
# 2115 件のデータを「0000010105_E650130」に保存しました。
# 1551 件のデータを「0000010105_E650131」に保存しました。
# 1551 件のデータを「0000010105_E650132」に保存しました。
# 2115 件のデータを「0000010105_E6502」に保存しました。
# 1551 件のデータを「0000010105_E650201」に保存しました。
# 1551 件のデータを「0000010105_E650202」に保存しました。
# 2115 件のデータを「0000010105_E650210」に保存しました。
# 1551 件のデータを「0000010105_E650211」に保存しました。
# 1551 件のデータを「0000010105_E650212」に保存しました。
# 2115 件のデータを「0000010105_E650220」に保存しました。
# 1551 件のデータを「0000010105_E650221」に保存しました。
# 1551 件のデータを「0000010105_E650222」に保存しました。
# 2115 件のデータを「0000010105_E650230」に保存しました。
# 1551 件のデータを「0000010105_E650231」に保存しました。
# 1551 件のデータを「0000010105_E650232」に保存しました。
# 2115 件のデータを「0000010105_E7101」に保存しました。
# 2115 件のデータを「0000010105_E7102」に保存しました。
# 2115 件のデータを「0000010105_E7201」に保存しました。
# 141 件のデータを「0000010105_E720101」に保存しました。
# 141 件のデータを「0000010105_E720102」に保存しました。
# 141 件のデータを「0000010105_E720103」に保存しました。
# 141 件のデータを「0000010105_E720104」に保存しました。
# 141 件のデータを「0000010105_E720105」に保存しました。
# 141 件のデータを「0000010105_E720106」に保存しました。
# 141 件のデータを「0000010105_E720107」に保存しました。
# 141 件のデータを「0000010105_E720108」に保存しました。
# 2115 件のデータを「0000010105_E720110」に保存しました。
# 2115 件のデータを「0000010105_E720111」に保存しました。
# 2115 件のデータを「0000010105_E720112」に保存しました。
# 2115 件のデータを「0000010105_E7202」に保存しました。
# 141 件のデータを「0000010105_E720201」に保存しました。
# 141 件のデータを「0000010105_E720202」に保存しました。
# 141 件のデータを「0000010105_E720203」に保存しました。
# 141 件のデータを「0000010105_E720204」に保存しました。
# 141 件のデータを「0000010105_E720205」に保存しました。
# 141 件のデータを「0000010105_E720206」に保存しました。
# 141 件のデータを「0000010105_E720207」に保存しました。
# 141 件のデータを「0000010105_E720208」に保存しました。
# 2068 件のデータを「0000010105_E8101」に保存しました。
# 188 件のデータを「0000010105_E810101」に保存しました。
# 2068 件のデータを「0000010105_E8102」に保存しました。
# 2068 件のデータを「0000010105_E8103」に保存しました。
# 2068 件のデータを「0000010105_E8104」に保存しました。
# 2068 件のデータを「0000010105_E8105」に保存しました。
# 2068 件のデータを「0000010105_E8106」に保存しました。
# 1034 件のデータを「0000010105_E8107」に保存しました。
# 1034 件のデータを「0000010105_E8108」に保存しました。
# 1034 件のデータを「0000010105_E8109」に保存しました。
# 1034 件のデータを「0000010105_E8110」に保存しました。
# 188 件のデータを「0000010105_E9101」に保存しました。
# 141 件のデータを「0000010105_E910101」に保存しました。
# 141 件のデータを「0000010105_E910102」に保存しました。
# 141 件のデータを「0000010105_E910110」に保存しました。
# 141 件のデータを「0000010105_E910111」に保存しました。
# 141 件のデータを「0000010105_E910112」に保存しました。
# 141 件のデータを「0000010105_E910120」に保存しました。
# 141 件のデータを「0000010105_E910121」に保存しました。
# 141 件のデータを「0000010105_E910122」に保存しました。
# 141 件のデータを「0000010105_E910130」に保存しました。
# 141 件のデータを「0000010105_E910131」に保存しました。
# 141 件のデータを「0000010105_E910133」に保存しました。
# 141 件のデータを「0000010105_E910140」に保存しました。
# 141 件のデータを「0000010105_E910141」に保存しました。
# 141 件のデータを「0000010105_E910142」に保存しました。
# 141 件のデータを「0000010105_E910150」に保存しました。
# 141 件のデータを「0000010105_E910151」に保存しました。
# 141 件のデータを「0000010105_E910153」に保存しました。
# 141 件のデータを「0000010105_E910160」に保存しました。
# 141 件のデータを「0000010105_E910161」に保存しました。
# 141 件のデータを「0000010105_E910162」に保存しました。
# 188 件のデータを「0000010105_E9102」に保存しました。
# 141 件のデータを「0000010105_E910201」に保存しました。
# 141 件のデータを「0000010105_E910202」に保存しました。
# 141 件のデータを「0000010105_E910210」に保存しました。
# 141 件のデータを「0000010105_E910211」に保存しました。
# 141 件のデータを「0000010105_E910212」に保存しました。
# 141 件のデータを「0000010105_E910220」に保存しました。
# 141 件のデータを「0000010105_E910221」に保存しました。
# 141 件のデータを「0000010105_E910222」に保存しました。
# 141 件のデータを「0000010105_E910230」に保存しました。
# 141 件のデータを「0000010105_E910231」に保存しました。
# 141 件のデータを「0000010105_E910233」に保存しました。
# 141 件のデータを「0000010105_E910240」に保存しました。
# 141 件のデータを「0000010105_E910241」に保存しました。
# 141 件のデータを「0000010105_E910242」に保存しました。
# 141 件のデータを「0000010105_E910250」に保存しました。
# 141 件のデータを「0000010105_E910251」に保存しました。
# 141 件のデータを「0000010105_E910253」に保存しました。
# 141 件のデータを「0000010105_E910260」に保存しました。
# 141 件のデータを「0000010105_E910261」に保存しました。
# 141 件のデータを「0000010105_E910262」に保存しました。
# 188 件のデータを「0000010105_E9103」に保存しました。
# 141 件のデータを「0000010105_E910301」に保存しました。
# 141 件のデータを「0000010105_E910302」に保存しました。
# 141 件のデータを「0000010105_E910310」に保存しました。
# 141 件のデータを「0000010105_E910311」に保存しました。
# 141 件のデータを「0000010105_E910312」に保存しました。
# 141 件のデータを「0000010105_E910320」に保存しました。
# 141 件のデータを「0000010105_E910321」に保存しました。
# 141 件のデータを「0000010105_E910322」に保存しました。
# 141 件のデータを「0000010105_E910330」に保存しました。
# 141 件のデータを「0000010105_E910331」に保存しました。
# 141 件のデータを「0000010105_E910333」に保存しました。
# 141 件のデータを「0000010105_E910340」に保存しました。
# 141 件のデータを「0000010105_E910341」に保存しました。
# 141 件のデータを「0000010105_E910342」に保存しました。
# 141 件のデータを「0000010105_E910350」に保存しました。
# 141 件のデータを「0000010105_E910351」に保存しました。
# 141 件のデータを「0000010105_E910353」に保存しました。
# 141 件のデータを「0000010105_E910460」に保存しました。
# 141 件のデータを「0000010105_E910461」に保存しました。
# 141 件のデータを「0000010105_E910462」に保存しました。
# 188 件のデータを「0000010105_E9105」に保存しました。
# 141 件のデータを「0000010105_E910501」に保存しました。
# 141 件のデータを「0000010105_E910502」に保存しました。
# 141 件のデータを「0000010105_E910520」に保存しました。
# 141 件のデータを「0000010105_E910521」に保存しました。
# 141 件のデータを「0000010105_E910522」に保存しました。
# 141 件のデータを「0000010105_E910530」に保存しました。
# 141 件のデータを「0000010105_E910531」に保存しました。
# 141 件のデータを「0000010105_E910533」に保存しました。
# 141 件のデータを「0000010105_E910540」に保存しました。
# 141 件のデータを「0000010105_E910541」に保存しました。
# 141 件のデータを「0000010105_E910542」に保存しました。
# 141 件のデータを「0000010105_E910550」に保存しました。
# 141 件のデータを「0000010105_E910551」に保存しました。
# 141 件のデータを「0000010105_E910553」に保存しました。
# 141 件のデータを「0000010105_E910560」に保存しました。
# 141 件のデータを「0000010105_E910561」に保存しました。
# 141 件のデータを「0000010105_E910562」に保存しました。
# 188 件のデータを「0000010105_E9106」に保存しました。
# 141 件のデータを「0000010105_E910601」に保存しました。
# 141 件のデータを「0000010105_E910602」に保存しました。
# 141 件のデータを「0000010105_E910620」に保存しました。
# 141 件のデータを「0000010105_E910621」に保存しました。
# 141 件のデータを「0000010105_E910622」に保存しました。
# 141 件のデータを「0000010105_E910630」に保存しました。
# 141 件のデータを「0000010105_E910631」に保存しました。
# 141 件のデータを「0000010105_E910633」に保存しました。
# 141 件のデータを「0000010105_E910640」に保存しました。
# 141 件のデータを「0000010105_E910641」に保存しました。
# 141 件のデータを「0000010105_E910642」に保存しました。
# 141 件のデータを「0000010105_E910650」に保存しました。
# 141 件のデータを「0000010105_E910651」に保存しました。
# 141 件のデータを「0000010105_E910653」に保存しました。
# 141 件のデータを「0000010105_E910660」に保存しました。
# 141 件のデータを「0000010105_E910661」に保存しました。
# 141 件のデータを「0000010105_E910662」に保存しました。
# 141 件のデータを「0000010105_E9201」に保存しました。
# 141 件のデータを「0000010105_E920101」に保存しました。
# 141 件のデータを「0000010105_E920102」に保存しました。
# 141 件のデータを「0000010105_E9202」に保存しました。
# 141 件のデータを「0000010105_E920201」に保存しました。
# 141 件のデータを「0000010105_E920202」に保存しました。
# 141 件のデータを「0000010105_E9203」に保存しました。
# 141 件のデータを「0000010105_E920301」に保存しました。
# 141 件のデータを「0000010105_E920302」に保存しました。
# 141 件のデータを「0000010105_E9204」に保存しました。
# 141 件のデータを「0000010105_E920401」に保存しました。
# 141 件のデータを「0000010105_E920402」に保存しました。
# 141 件のデータを「0000010105_E9205」に保存しました。
# 141 件のデータを「0000010105_E920501」に保存しました。
# 141 件のデータを「0000010105_E920502」に保存しました。
# 141 件のデータを「0000010105_E9301」に保存しました。
# 141 件のデータを「0000010105_E930101」に保存しました。
# 141 件のデータを「0000010105_E930102」に保存しました。
# 141 件のデータを「0000010105_E9302」に保存しました。
# 141 件のデータを「0000010105_E930201」に保存しました。
# 141 件のデータを「0000010105_E930202」に保存しました。
# 141 件のデータを「0000010105_E9303」に保存しました。
# 141 件のデータを「0000010105_E930301」に保存しました。
# 141 件のデータを「0000010105_E930302」に保存しました。
# 141 件のデータを「0000010105_E9304」に保存しました。
# 141 件のデータを「0000010105_E930401」に保存しました。
# 141 件のデータを「0000010105_E930402」に保存しました。
# 329 件のデータを「0000010105_E9401」に保存しました。
# 329 件のデータを「0000010105_E9402」に保存しました。
# 329 件のデータを「0000010105_E9403」に保存しました。
# 188 件のデータを「0000010105_E9411」に保存しました。
# 188 件のデータを「0000010105_E9412」に保存しました。
# 188 件のデータを「0000010105_E9413」に保存しました。
# 47 件のデータを「0000010105_E9414」に保存しました。
# 47 件のデータを「0000010105_E9415」に保存しました。
# 47 件のデータを「0000010105_E9416」に保存しました。
# 94 件のデータを「0000010105_E9417」に保存しました。
# 94 件のデータを「0000010105_E9418」に保存しました。
# 94 件のデータを「0000010105_E9419」に保存しました。
# 329 件のデータを「0000010105_E9421」に保存しました。
# 329 件のデータを「0000010105_E9422」に保存しました。
# 329 件のデータを「0000010105_E9423」に保存しました。
# 329 件のデータを「0000010105_E9501」に保存しました。
# 329 件のデータを「0000010105_E9502」に保存しました。
# 329 件のデータを「0000010105_E9503」に保存しました。
# 423 件のデータを「0000010106_F1101」に保存しました。
# 423 件のデータを「0000010106_F110101」に保存しました。
# 423 件のデータを「0000010106_F110102」に保存しました。
# 423 件のデータを「0000010106_F1102」に保存しました。
# 376 件のデータを「0000010106_F110201」に保存しました。
# 376 件のデータを「0000010106_F110202」に保存しました。
# 376 件のデータを「0000010106_F1103」に保存しました。
# 282 件のデータを「0000010106_F110301」に保存しました。
# 282 件のデータを「0000010106_F110302」に保存しました。
# 376 件のデータを「0000010106_F1104」に保存しました。
# 282 件のデータを「0000010106_F110401」に保存しました。
# 282 件のデータを「0000010106_F110402」に保存しました。
# 376 件のデータを「0000010106_F1105」に保存しました。
# 282 件のデータを「0000010106_F110501」に保存しました。
# 282 件のデータを「0000010106_F110502」に保存しました。
# 376 件のデータを「0000010106_F1106」に保存しました。
# 282 件のデータを「0000010106_F110601」に保存しました。
# 282 件のデータを「0000010106_F110602」に保存しました。
# 423 件のデータを「0000010106_F1107」に保存しました。
# 423 件のデータを「0000010106_F110701」に保存しました。
# 423 件のデータを「0000010106_F110702」に保存しました。
# 423 件のデータを「0000010106_F1108」に保存しました。
# 423 件のデータを「0000010106_F110801」に保存しました。
# 423 件のデータを「0000010106_F110802」に保存しました。
# 376 件のデータを「0000010106_F1109」に保存しました。
# 282 件のデータを「0000010106_F110901」に保存しました。
# 282 件のデータを「0000010106_F110902」に保存しました。
# 376 件のデータを「0000010106_F1110」に保存しました。
# 282 件のデータを「0000010106_F111001」に保存しました。
# 282 件のデータを「0000010106_F111002」に保存しました。
# 376 件のデータを「0000010106_F1111」に保存しました。
# 282 件のデータを「0000010106_F111101」に保存しました。
# 282 件のデータを「0000010106_F111102」に保存しました。
# 470 件のデータを「0000010106_F1201」に保存しました。
# 470 件のデータを「0000010106_F120101」に保存しました。
# 470 件のデータを「0000010106_F120102」に保存しました。
# 470 件のデータを「0000010106_F1202」に保存しました。
# 470 件のデータを「0000010106_F120201」に保存しました。
# 470 件のデータを「0000010106_F120202」に保存しました。
# 470 件のデータを「0000010106_F1203」に保存しました。
# 376 件のデータを「0000010106_F120301」に保存しました。
# 376 件のデータを「0000010106_F120302」に保存しました。
# 470 件のデータを「0000010106_F1204」に保存しました。
# 376 件のデータを「0000010106_F120401」に保存しました。
# 376 件のデータを「0000010106_F120402」に保存しました。
# 470 件のデータを「0000010106_F1205」に保存しました。
# 470 件のデータを「0000010106_F120501」に保存しました。
# 470 件のデータを「0000010106_F120502」に保存しました。
# 470 件のデータを「0000010106_F1206」に保存しました。
# 376 件のデータを「0000010106_F120601」に保存しました。
# 376 件のデータを「0000010106_F120602」に保存しました。
# 470 件のデータを「0000010106_F1207」に保存しました。
# 376 件のデータを「0000010106_F120701」に保存しました。
# 376 件のデータを「0000010106_F120702」に保存しました。
# 470 件のデータを「0000010106_F1208」に保存しました。
# 376 件のデータを「0000010106_F120801」に保存しました。
# 376 件のデータを「0000010106_F120802」に保存しました。
# 376 件のデータを「0000010106_F1301」に保存しました。
# 282 件のデータを「0000010106_F130101」に保存しました。
# 282 件のデータを「0000010106_F130102」に保存しました。
# 376 件のデータを「0000010106_F1302」に保存しました。
# 282 件のデータを「0000010106_F130201」に保存しました。
# 282 件のデータを「0000010106_F130202」に保存しました。
# 376 件のデータを「0000010106_F1303」に保存しました。
# 282 件のデータを「0000010106_F130301」に保存しました。
# 282 件のデータを「0000010106_F130302」に保存しました。
# 376 件のデータを「0000010106_F1304」に保存しました。
# 282 件のデータを「0000010106_F130401」に保存しました。
# 282 件のデータを「0000010106_F130402」に保存しました。
# 376 件のデータを「0000010106_F1305」に保存しました。
# 282 件のデータを「0000010106_F130501」に保存しました。
# 282 件のデータを「0000010106_F130502」に保存しました。
# 376 件のデータを「0000010106_F1306」に保存しました。
# 282 件のデータを「0000010106_F130601」に保存しました。
# 282 件のデータを「0000010106_F130602」に保存しました。
# 376 件のデータを「0000010106_F1307」に保存しました。
# 282 件のデータを「0000010106_F130701」に保存しました。
# 282 件のデータを「0000010106_F130702」に保存しました。
# 376 件のデータを「0000010106_F1308」に保存しました。
# 282 件のデータを「0000010106_F130801」に保存しました。
# 282 件のデータを「0000010106_F130802」に保存しました。
# 376 件のデータを「0000010106_F1309」に保存しました。
# 282 件のデータを「0000010106_F130901」に保存しました。
# 282 件のデータを「0000010106_F130902」に保存しました。
# 376 件のデータを「0000010106_F1310」に保存しました。
# 282 件のデータを「0000010106_F131001」に保存しました。
# 282 件のデータを「0000010106_F131002」に保存しました。
# 376 件のデータを「0000010106_F1311」に保存しました。
# 282 件のデータを「0000010106_F131101」に保存しました。
# 282 件のデータを「0000010106_F131102」に保存しました。
# 376 件のデータを「0000010106_F1312」に保存しました。
# 282 件のデータを「0000010106_F131201」に保存しました。
# 282 件のデータを「0000010106_F131202」に保存しました。
# 376 件のデータを「0000010106_F1313」に保存しました。
# 282 件のデータを「0000010106_F131301」に保存しました。
# 282 件のデータを「0000010106_F131302」に保存しました。
# 376 件のデータを「0000010106_F1314」に保存しました。
# 282 件のデータを「0000010106_F131401」に保存しました。
# 282 件のデータを「0000010106_F131402」に保存しました。
# 376 件のデータを「0000010106_F1315」に保存しました。
# 282 件のデータを「0000010106_F131501」に保存しました。
# 282 件のデータを「0000010106_F131502」に保存しました。
# 376 件のデータを「0000010106_F1316」に保存しました。
# 282 件のデータを「0000010106_F131601」に保存しました。
# 282 件のデータを「0000010106_F131602」に保存しました。
# 376 件のデータを「0000010106_F1317」に保存しました。
# 282 件のデータを「0000010106_F131701」に保存しました。
# 282 件のデータを「0000010106_F131702」に保存しました。
# 376 件のデータを「0000010106_F1318」に保存しました。
# 376 件のデータを「0000010106_F140111」に保存しました。
# 376 件のデータを「0000010106_F140112」に保存しました。
# 376 件のデータを「0000010106_F140121」に保存しました。
# 376 件のデータを「0000010106_F140122」に保存しました。
# 376 件のデータを「0000010106_F140301」に保存しました。
# 376 件のデータを「0000010106_F140302」に保存しました。
# 376 件のデータを「0000010106_F1501」に保存しました。
# 282 件のデータを「0000010106_F150101」に保存しました。
# 282 件のデータを「0000010106_F150102」に保存しました。
# 282 件のデータを「0000010106_F150103」に保存しました。
# 376 件のデータを「0000010106_F2101」に保存しました。
# 376 件のデータを「0000010106_F210101」に保存しました。
# 376 件のデータを「0000010106_F210102」に保存しました。
# 376 件のデータを「0000010106_F2102」に保存しました。
# 376 件のデータを「0000010106_F210201」に保存しました。
# 376 件のデータを「0000010106_F210202」に保存しました。
# 376 件のデータを「0000010106_F2103」に保存しました。
# 376 件のデータを「0000010106_F210301」に保存しました。
# 376 件のデータを「0000010106_F210302」に保存しました。
# 376 件のデータを「0000010106_F2104」に保存しました。
# 376 件のデータを「0000010106_F210401」に保存しました。
# 376 件のデータを「0000010106_F210402」に保存しました。
# 376 件のデータを「0000010106_F2105」に保存しました。
# 376 件のデータを「0000010106_F210501」に保存しました。
# 376 件のデータを「0000010106_F210502」に保存しました。
# 376 件のデータを「0000010106_F2106」に保存しました。
# 376 件のデータを「0000010106_F210601」に保存しました。
# 376 件のデータを「0000010106_F210602」に保存しました。
# 376 件のデータを「0000010106_F2107」に保存しました。
# 376 件のデータを「0000010106_F210701」に保存しました。
# 376 件のデータを「0000010106_F210702」に保存しました。
# 376 件のデータを「0000010106_F2108」に保存しました。
# 376 件のデータを「0000010106_F210801」に保存しました。
# 376 件のデータを「0000010106_F210802」に保存しました。
# 376 件のデータを「0000010106_F2109」に保存しました。
# 376 件のデータを「0000010106_F210901」に保存しました。
# 376 件のデータを「0000010106_F210902」に保存しました。
# 376 件のデータを「0000010106_F2110」に保存しました。
# 376 件のデータを「0000010106_F211001」に保存しました。
# 376 件のデータを「0000010106_F211002」に保存しました。
# 376 件のデータを「0000010106_F2111」に保存しました。
# 376 件のデータを「0000010106_F211101」に保存しました。
# 376 件のデータを「0000010106_F211102」に保存しました。
# 376 件のデータを「0000010106_F2112」に保存しました。
# 376 件のデータを「0000010106_F211201」に保存しました。
