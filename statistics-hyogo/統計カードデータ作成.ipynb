# %% [markdown]
# # 実行環境の作成

# %% [markdown]
# ## Google Drive

# %% [markdown]
# Google Driveをマウント

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Google Sheets

# %% [markdown]
# ライブラリのインストール

# %%
# !pip install --upgrade -q gspread

# %% [markdown]
# Google Sheetsの認証

# %%
from google.colab import auth
from google.auth import default
import gspread

auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# %% [markdown]
# ## Google Cloud Storage

# %% [markdown]
# 下記コードでGCPに接続

# %%
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# 認証に成功したらgcsfuseをインストール

# %%
# !echo "deb http://packages.cloud.google.com/apt gcsfuse-`lsb_release -c -s` main" | sudo tee /etc/apt/sources.list.d/gcsfuse.list
# !curl https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo apt-key add -
# !apt-get -y -q update
# !apt-get -y -q install gcsfuse

# %% [markdown]
# バケット「statistics-hyogo」をディレクトリ「statistics-hyogo」にマウント

# %%
! mkdir -p statistics-hyogo
! gcsfuse --implicit-dirs --limit-bytes-per-sec -1 --limit-ops-per-sec -1 statistics-hyogo statistics-hyogo

# %% [markdown]
# # estatレスポンスをDataFrameに格納

# %% [markdown]
# DataFrameを整形する関数

# %%
ESTAT_APPID = '724e5b90772a3e9289f41a253e4e7e32438f4fff'

import urllib.parse
import urllib.request
import json
import pandas as pd

"""
estat-APIのレスポンスを整形してDataFrameに変換
"""

def get_estat_dataframe(params):
  res = get_estat_response(params)
  df_res = conv_estat_response_to_dataframe(res)
  df_res = format_estat_dataframe(df_res)

  return df_res

"""
estat-APIのレスポンスを取得する関数
"""

def get_estat_response(params):
  p = params.copy()

  # appId
  p['appId'] = ESTAT_APPID
  
  # url生成
  url = 'http://api.e-stat.go.jp/rest/2.1/app/json/getStatsData?'
  url += urllib.parse.urlencode(p)

  with urllib.request.urlopen(url) as response:
    return json.loads(response.read().decode('utf-8'))


"""
estat-APIのレスポンスをDataFrameに変換する
"""

def conv_estat_response_to_dataframe(response):

  # VALUEをDataFrameに変換
  VALUE = response['GET_STATS_DATA']['STATISTICAL_DATA']['DATA_INF']['VALUE']
  df = pd.json_normalize(VALUE)

  # CLASS_OBJのDataFrameを結合
  CLASS_OBJ = response['GET_STATS_DATA']['STATISTICAL_DATA']['CLASS_INF']['CLASS_OBJ']
  for d in CLASS_OBJ :
    # DataFrameに変換 '@code','@name'だけ抽出
    df_class = pd.json_normalize(d['CLASS']) 
    df_class = df_class.copy()[['@code','@name']]

    # @codeをキー名に変更 @nameをキー名＋'_name'に変更
    key_name = '@{}'.format(d['@id'])
    df_class = df_class.rename(columns={'@code':key_name,'@name': key_name+'_name'})

    # DataFrameを結合
    df = pd.merge(df, df_class, on=key_name, how='outer')

  # 統計情報を追加
  TABLE_INF = response['GET_STATS_DATA']['STATISTICAL_DATA']['TABLE_INF']
  df['statsDataId'] = TABLE_INF['@id']
  df['statsDataName'] = TABLE_INF['STAT_NAME']['$']
  
  return df

"""
DataFrameを整形する
"""

def  format_estat_dataframe(df_arg):

  # 列を抽出して名前変更
  df =  df_arg[['statsDataId','statsDataName','@cat01','@cat01_name','@time','@time_name','@area','$','@unit']]
  df = df.rename(columns = {'@cat01':'categoryCode','@cat01_name':'categoryName','@time':'timeCode','@time_name':'timeName','@area':'areaCode','$':'value','@unit':'unit'})

  # 欠損データ削除
  df = df.dropna(subset=['categoryCode'])

  # categoryNameから不要な情報（categoryCode）を削除
  df['categoryName'] = df.apply(lambda x: x['categoryName'].replace(x['categoryCode']+'_', ''), 1)

  # timeCodeを文字列4桁に置換
  df['timeCode'] = df['timeCode'].astype(str)
  df['timeCode'] = df.apply(lambda x: x['timeCode'][:4], 1)
  
  # 地域情報をマージ
  with open('drive/MyDrive/statistics-hyogo/resas/arealist.json') as j:
    arealist = json.load(j)
    df_arealist = pd.json_normalize(arealist)  
  df = pd.merge(df, df_arealist, on='areaCode', how='right')


  df = df.dropna(subset=['categoryCode'])

  # '-'を'0'に置換
  df = df.replace({'value': {'-': '0'}})
  df = df.replace({'value': {'X': '0'}})

  return df

# %% [markdown]
# # 全国・都道府県ランキングを付与

# %% [markdown]
# ## 都道府県データ
#
# 全国ランキングを付与

# %%
"""
都道府県のランキングを付与する関数
"""
def withrank_prefecture(df_arg):

  # 年度リスト、カテゴリリストの作成
  times = list(set(df_arg['timeCode'].tolist()))
  categories = list(set(df_arg['categoryCode'].tolist()))

  # 返却するDataFrameの定義
  df_res = pd.DataFrame(index=[], columns=[])

  for time in times:
    for category in categories:
      df = df_arg.copy()
      df = df[df['timeCode'] == time][df['categoryCode'] == category]
      
      # valueを数値に変換して、'rank'を付与
      df = df.astype({'value': float})
      df['rankJapan'] = df.rank(ascending=False)['value'].astype(int).astype(str)
      
      # 結合
      df_res = pd.concat([df_res, df])
  
  return df_res

# %% [markdown]
# ## 市区町村データ

# %% [markdown]
# 全国ランキングと都道府県内ランキングを付与
#
# 対象は政令指定都市（join）

# %%
"""
市区町村のランキングを付与する関数
"""
def withrank_city(df_arg):
  print(f'基のDataDrameは{len(df_arg)}行')

  # 年度リスト、カテゴリリストの作成
  times = list(set(df_arg['timeCode'].tolist()))
  categories = list(set(df_arg['categoryCode'].tolist()))
  prefs = list(set(df_arg['prefCode'].tolist()))
  print(prefs)

  # ランキングDataFrameを作成
  df_rank = pd.DataFrame(index=[], columns=[])
  for time in times:
    for category in categories:

      # DataFrameの抽出
      df = df_arg.copy()
      df = df[df['timeCode'] == time][df['categoryCode'] == category]
      df = df[df['bigCityFlag'] != '1']

      # valueを数値に変換して、'rank'を付与
      df = df.astype({'value': float})
      df['rankJapan'] = df.rank(ascending=False)['value'].astype(int).astype(str)
      
      # 必要な列だけ結合
      df = df[['timeCode','categoryCode','areaCode','rankJapan']]
      df_rank = pd.concat([df_rank, df])
  
  # 基のDataFrameにマージ
  df_res = df_arg.copy()
  df_res = pd.merge(df_res, df_rank, on=['timeCode','categoryCode','areaCode'], how='left')


  # ランキングDataFrameを作成
  df_rank = pd.DataFrame(index=[], columns=[])
  for time in times:
    for category in categories:
      for pref in prefs:
        # DataFrameの抽出
        df = df_arg.copy()
        df = df[df['timeCode'] == time][df['categoryCode'] == category]
        df = df[df['bigCityFlag'] != '1']
        df = df[df['prefCode'] == pref]

        # valueを数値に変換して、'rank'を付与
        df = df.astype({'value': float})
        df['rankPref'] = df.rank(ascending=False)['value'].astype(int).astype(str)
      
        # 必要な列だけ結合
        df = df[['timeCode','categoryCode','areaCode','rankPref']]
        df_rank = pd.concat([df_rank, df])

  df_res = pd.merge(df_res, df_rank, on=['timeCode','categoryCode','areaCode'], how='left')
  return df_res

# %% [markdown]
# # BigQueryに格納

# %% [markdown]
# pandas-gbqのインストール

# %%
# !pip install pandas-gbq

# %% [markdown]
# 統計カード一覧を取得

# %%
def get_statistics_cardlist():
  with open('/content/drive/MyDrive/statistics-hyogo/contents/statistics-cards.json') as j:
    cardlist = json.load(j)

  return cardlist

# %%
cardlist = get_statistics_cardlist()
print(cardlist)
# Out:
# [{'index': 0, 'cardId': 'total-population-prefecture', 'cardTitle': '都道府県の総人口', 'cardIndex': 1, 'governmentType': 'prefecture', 'menuId': 'population', 'menuTitle': '人口', 'fieldId': 'population', 'fieldTitle': '人口・世帯', 'chartComponent': 'TimeChart', 'categories': [{'categoryCode': 'A1101', 'categoryName': '総人口', 'isSelect': 'TRUE', 'type': 'column', 'yAxis': 0}, {'categoryCode': 'A110101', 'categoryName': '総人口（男）', 'isSelect': '', 'type': 'column', 'yAxis': 0}, {'categoryCode': 'A110102', 'categoryName': '総人口（女）', 'isSelect': '', 'type': 'column', 'yAxis': 0}], 'estatParams': {'statsDataId': '0000010101', 'cdCat01': 'A1101,A110101,A110102'}}, {'index': 1, 'cardId': 'japanese-population-prefecture', 'cardTitle': '都道府県の日本人人口', 'cardIndex': '', 'governmentType': 'prefecture', 'menuId': 'population', 'menuTitle': '人口', 'fieldId': 'population', 'fieldTitle': '人口・世帯', 'chartComponent': 'TimeChart', 'categories': [{'categoryCode': 'A1102', 'categoryName': '日本人人口', 'isSelect': 'TRUE', 'type': 'column', 'yAxis': 0}, {'categoryCode': 'A110201', 'categoryName': '日本人人口（男）', 'isSelect': '', 'type': 'column', 'yAxis': 0}, {'categoryCode': 'A110202', 'categoryName': '日本人人口（女）', 'isSelect': '', 'type': 'column', 'yAxis': 0}], 'estatParams': {'statsDataId': '0000010101', 'cdCat01': 'A1102,A110201,A110202'}}, {'index': 2, 'cardId': 'population-pyramid-prefecture', 'cardTitle': '都道府県の人口ピラミッド', 'cardIndex': '', 'governmentType': 'prefecture', 'menuId': 'population', 'menuTitle': '人口', 'fieldId': 'population', 'fieldTitle': '人口・世帯', 'chartComponent': 'PyramidChart', 'categories': [{'categoryCode': 'A120101', 'categoryName': '0～4歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120102', 'categoryName': '0～4歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120201', 'categoryName': '5～9歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120202', 'categoryName': '5～9歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120301', 'categoryName': '10～14歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120302', 'categoryName': '10～14歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120401', 'categoryName': '15～19歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120402', 'categoryName': '15～19歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120501', 'categoryName': '20～24歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120502', 'categoryName': '20～24歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120601', 'categoryName': '25～29歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120602', 'categoryName': '25～29歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120701', 'categoryName': '30～34歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120702', 'categoryName': '30～34歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120801', 'categoryName': '35～39歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120802', 'categoryName': '35～39歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120901', 'categoryName': '40～44歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120902', 'categoryName': '40～44歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A121001', 'categoryName': '45～49歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A121002', 'categoryName': '45～49歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A121101', 'categoryName': '50～54歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A121102', 'categoryName': '50～54歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A121201', 'categoryName': '55～59歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'cate ...

# %% [markdown]
# 統計カードのデータをBigQueryに保存

# %%
from google.cloud import bigquery
from google.cloud.exceptions import NotFound

def save_statistics_card_to_gbq(cardlist):
  for card in cardlist:
    # BigQueryのテーブル定義
    project_id='primal-buttress-342908'
    dataset_id = 'contents'
    table_id= card['cardId']
    client = bigquery.Client()
    
    try:
      client.get_table(f'{project_id}.{dataset_id}.{table_id}')  
      print("Table {} already exists.".format(table_id))
      
    except NotFound:
      estatParams = card['estatParams']
      governmentType = card['governmentType']
      df = get_estat_dataframe(estatParams)
      
      # ランキングを付与
      if governmentType == 'prefecture':
        df = withrank_prefecture(df)
      else:
        df = withrank_city(df)
      
      # BigQueryに保存
      df.to_gbq(f'{dataset_id}.{table_id}', project_id=project_id, if_exists="replace")
      print(f'{table_id}を保存しました')

# %%
save_statistics_card_to_gbq(cardlist)

# %% [markdown]
# # JSONに保存

# %% [markdown]
# ## BigQueryからデータ取得

# %%
import pandas as pd

def get_gbq(table_id):
  project_id='primal-buttress-342908'
  dataset_id = 'contents'  
  query = f'SELECT * FROM `{project_id}.{dataset_id}.{table_id}`'
  
  return pd.read_gbq(query, project_id, dialect='standard')

# %%
df_test = get_gbq('total-population-city')
df_test
# Out:
#       statsDataId statsDataName categoryCode categoryName timeCode timeName  \
# 0      0000020201     社会・人口統計体系        A1101          総人口     1980   1980年度
# 1      0000020201     社会・人口統計体系        A1101          総人口     1985   1985年度
# 2      0000020201     社会・人口統計体系        A1101          総人口     1990   1990年度
# 3      0000020201     社会・人口統計体系        A1101          総人口     1995   1995年度
# 4      0000020201     社会・人口統計体系        A1101          総人口     2000   2000年度
# ...           ...           ...          ...          ...      ...      ...
# 30628  0000020201     社会・人口統計体系      A110101       総人口（男）     2015   2015年度
# 30629  0000020201     社会・人口統計体系      A110102       総人口（女）     2000   2000年度
# 30630  0000020201     社会・人口統計体系      A110102       総人口（女）     2005   2005年度
# 30631  0000020201     社会・人口統計体系      A110102       総人口（女）     2010   2010年度
# 30632  0000020201     社会・人口統計体系      A110102       総人口（女）     2015   2015年度
#
#       areaCode    value unit  index  prefCode prefName cityCode cityName  \
# 0        01100  1401757    人      0         1      北海道    01100      札幌市
# 1        01100  1542979    人      0         1      北海道    01100      札幌市
# 2        01100  1671742    人      0         1      北海道    01100      札幌市
# 3        01100  1757025    人      0         1      北海道    01100      札幌市
# 4        01100  1822368    人      0         1      北海道    01100      札幌市
# ...        ...      ...  ...    ...       ...      ...      ...      ...
# 30628    47382     1147    人   1921        47      沖縄県    47382     与那国町
# 30629    47382      895    人   1921        47      沖縄県    47382     与那国町
# 30630    47382      857    人   1921        47      沖縄県    47382     与那国町
# 30631    47382      816    人   1921        47      沖縄県    47382     与那国町
# 30632    47382      696    人   1921        47      沖縄県    47382     与那国町
#
#       bigCityFlag areaName governmentType rankJapan rankPref
# 0               2      札幌市           city         5        1
# 1               2      札幌市           city         4        1
# 2               2      札幌市           city         4        1
# 3               2      札幌市           city         4        1
# 4               2      札幌市           city         4        1
# ...           ...      ...            ...       ...      ...
# 30628           0     与那国町           city      1638       31
# 30629           0     与那国町           city      1694       32
# 30630           0     与那国町           city      1690       31
# 30631           0     与那国町           city      1689       31
# 30632           0     与那国町           city      1686       32
#
# [30633 rows x 19 columns]

# %% [markdown]
# ## 統計カード一覧

# %%
def get_statistics_cardlist():
  with open('/content/drive/MyDrive/statistics-hyogo/contents/statistics-cards.json') as j:
    cardlist = json.load(j)

  return cardlist

# %%
cardlist = get_statistics_cardlist()
print(cardlist)
# Out:
# [{'index': 0, 'cardId': 'total-population-prefecture', 'cardTitle': '都道府県の総人口', 'cardIndex': 1, 'governmentType': 'prefecture', 'menuId': 'population', 'menuTitle': '人口', 'fieldId': 'population', 'fieldTitle': '人口・世帯', 'chartComponent': 'TimeChart', 'categories': [{'categoryCode': 'A1101', 'categoryName': '総人口', 'isSelect': 'TRUE', 'type': 'column', 'yAxis': 0}, {'categoryCode': 'A110101', 'categoryName': '総人口（男）', 'isSelect': '', 'type': 'column', 'yAxis': 0}, {'categoryCode': 'A110102', 'categoryName': '総人口（女）', 'isSelect': '', 'type': 'column', 'yAxis': 0}], 'estatParams': {'statsDataId': '0000010101', 'cdCat01': 'A1101,A110101,A110102'}}, {'index': 1, 'cardId': 'japanese-population-prefecture', 'cardTitle': '都道府県の日本人人口', 'cardIndex': '', 'governmentType': 'prefecture', 'menuId': 'population', 'menuTitle': '人口', 'fieldId': 'population', 'fieldTitle': '人口・世帯', 'chartComponent': 'TimeChart', 'categories': [{'categoryCode': 'A1102', 'categoryName': '日本人人口', 'isSelect': 'TRUE', 'type': 'column', 'yAxis': 0}, {'categoryCode': 'A110201', 'categoryName': '日本人人口（男）', 'isSelect': '', 'type': 'column', 'yAxis': 0}, {'categoryCode': 'A110202', 'categoryName': '日本人人口（女）', 'isSelect': '', 'type': 'column', 'yAxis': 0}], 'estatParams': {'statsDataId': '0000010101', 'cdCat01': 'A1102,A110201,A110202'}}, {'index': 2, 'cardId': 'population-pyramid-prefecture', 'cardTitle': '都道府県の人口ピラミッド', 'cardIndex': '', 'governmentType': 'prefecture', 'menuId': 'population', 'menuTitle': '人口', 'fieldId': 'population', 'fieldTitle': '人口・世帯', 'chartComponent': 'PyramidChart', 'categories': [{'categoryCode': 'A120101', 'categoryName': '0～4歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120102', 'categoryName': '0～4歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120201', 'categoryName': '5～9歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120202', 'categoryName': '5～9歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120301', 'categoryName': '10～14歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120302', 'categoryName': '10～14歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120401', 'categoryName': '15～19歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120402', 'categoryName': '15～19歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120501', 'categoryName': '20～24歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120502', 'categoryName': '20～24歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120601', 'categoryName': '25～29歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120602', 'categoryName': '25～29歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120701', 'categoryName': '30～34歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120702', 'categoryName': '30～34歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120801', 'categoryName': '35～39歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120802', 'categoryName': '35～39歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120901', 'categoryName': '40～44歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120902', 'categoryName': '40～44歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A121001', 'categoryName': '45～49歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A121002', 'categoryName': '45～49歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A121101', 'categoryName': '50～54歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A121102', 'categoryName': '50～54歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A121201', 'categoryName': '55～59歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'cate ...

# %% [markdown]
# ## 地域一覧

# %%
def get_arealist():
  with open('drive/MyDrive/statistics-hyogo/resas/arealist.json') as j:
    arealist = json.load(j)
    
  return arealist

# %%
arealist = get_arealist()
preflist = list(filter(lambda x: x['governmentType'] == 'prefecture', arealist))
print(preflist)
# Out:
# [{'index': 0, 'prefCode': 1, 'prefName': '北海道', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '01000', 'areaName': '北海道', 'governmentType': 'prefecture'}, {'index': 1, 'prefCode': 2, 'prefName': '青森県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '02000', 'areaName': '青森県', 'governmentType': 'prefecture'}, {'index': 2, 'prefCode': 3, 'prefName': '岩手県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '03000', 'areaName': '岩手県', 'governmentType': 'prefecture'}, {'index': 3, 'prefCode': 4, 'prefName': '宮城県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '04000', 'areaName': '宮城県', 'governmentType': 'prefecture'}, {'index': 4, 'prefCode': 5, 'prefName': '秋田県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '05000', 'areaName': '秋田県', 'governmentType': 'prefecture'}, {'index': 5, 'prefCode': 6, 'prefName': '山形県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '06000', 'areaName': '山形県', 'governmentType': 'prefecture'}, {'index': 6, 'prefCode': 7, 'prefName': '福島県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '07000', 'areaName': '福島県', 'governmentType': 'prefecture'}, {'index': 7, 'prefCode': 8, 'prefName': '茨城県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '08000', 'areaName': '茨城県', 'governmentType': 'prefecture'}, {'index': 8, 'prefCode': 9, 'prefName': '栃木県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '09000', 'areaName': '栃木県', 'governmentType': 'prefecture'}, {'index': 9, 'prefCode': 10, 'prefName': '群馬県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '10000', 'areaName': '群馬県', 'governmentType': 'prefecture'}, {'index': 10, 'prefCode': 11, 'prefName': '埼玉県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '11000', 'areaName': '埼玉県', 'governmentType': 'prefecture'}, {'index': 11, 'prefCode': 12, 'prefName': '千葉県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '12000', 'areaName': '千葉県', 'governmentType': 'prefecture'}, {'index': 12, 'prefCode': 13, 'prefName': '東京都', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '13000', 'areaName': '東京都', 'governmentType': 'prefecture'}, {'index': 13, 'prefCode': 14, 'prefName': '神奈川県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '14000', 'areaName': '神奈川県', 'governmentType': 'prefecture'}, {'index': 14, 'prefCode': 15, 'prefName': '新潟県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '15000', 'areaName': '新潟県', 'governmentType': 'prefecture'}, {'index': 15, 'prefCode': 16, 'prefName': '富山県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '16000', 'areaName': '富山県', 'governmentType': 'prefecture'}, {'index': 16, 'prefCode': 17, 'prefName': '石川県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '17000', 'areaName': '石川県', 'governmentType': 'prefecture'}, {'index': 17, 'prefCode': 18, 'prefName': '福井県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '18000', 'areaName': '福井県', 'governmentType': 'prefecture'}, {'index': 18, 'prefCode': 19, 'prefName': '山梨県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '19000', 'areaName': '山梨県', 'governmentType': 'prefecture'}, {'index': 19, 'prefCode': 20, 'prefName': '長野県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '20000', 'areaName': '長野県', 'governmentType': 'prefecture'}, {'index': 20, 'prefCode': 21, 'prefName': '岐阜県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '21000', 'areaName': '岐阜県', 'governmentType': 'prefecture'}, {'index': 21, 'prefCode': 22, 'prefName': '静岡県', 'cityCode': None, 'cityName': None, 'bigCityFlag': None, 'areaCode': '22000', 'areaName': '静岡県', 'governmentType': 'prefecture'}, {'index': 22, 'prefCode': 23, 'prefName': '愛知県', 'cityCode': None, 'cityName': ...

# %% [markdown]
# ## jsonに保存

# %%
for card in cardlist:
  cardId = card['cardId']
  governmentType = card['governmentType']

  df = get_gbq(cardId)

  if governmentType == 'prefecture':

    # GCSへ保存
    gcs_path = "statistics-hyogo/card-data/{}.json".format(cardId)
    df.to_json(gcs_path, orient='records', force_ascii=False)

    print(f'{gcs_path}を保存しました')

  else:
    for pref in preflist:
      df_city = df.copy()
      df_city = df_city[df_city['prefCode'] == str(pref['prefCode'])]

      areacode = pref['areaCode']
      gcs_path = f'statistics-hyogo/card-data/{cardId}_{areacode}.json'
      df.to_json(gcs_path, orient='records', force_ascii=False)
      print(f'{gcs_path}を保存しました')

    # print(areacodes)
    # df = get_gbq(cardId)
    # # df_prefs = df[df['governmentType'] == 'prefecture']
    # print(df)
    # prefs = list(set(df_prefs['areaCode'].tolist()))
    # print(prefs)
# Out:
# statistics-hyogo/card-data/total-population-prefecture.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-prefecture.jsonを保存しました
# statistics-hyogo/card-data/population-pyramid-prefecture.jsonを保存しました
# statistics-hyogo/card-data/median-age-prefecture.jsonを保存しました
# statistics-hyogo/card-data/population-age-prefecture .jsonを保存しました
# statistics-hyogo/card-data/unmarried-prefecture.jsonを保存しました
# statistics-hyogo/card-data/spouse-prefecture.jsonを保存しました
# statistics-hyogo/card-data/bereavement-prefecture.jsonを保存しました
# statistics-hyogo/card-data/separated-prefecture.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-pretecture.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-prefecture.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-prefecture.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-prefecture.jsonを保存しました
# statistics-hyogo/card-data/foreigner-prefecture.jsonを保存しました
# statistics-hyogo/card-data/foreign-resident-prefecture.jsonを保存しました
# statistics-hyogo/card-data/birth-prefecture.jsonを保存しました
# statistics-hyogo/card-data/total-fertility-rate-prefecture.jsonを保存しました
# statistics-hyogo/card-data/death-prefecture.jsonを保存しました
# statistics-hyogo/card-data/death-pyramid-prefecture.jsonを保存しました
# statistics-hyogo/card-data/age-adjusted-mortality-prefecture.jsonを保存しました
# statistics-hyogo/card-data/stillbirth-prefecture.jsonを保存しました
# statistics-hyogo/card-data/standardized-mortality-prefecture.jsonを保存しました
# statistics-hyogo/card-data/movein-prefecture.jsonを保存しました
# statistics-hyogo/card-data/moveout-prefecture.jsonを保存しました
# statistics-hyogo/card-data/Immigrant-prefecture.jsonを保存しました
# statistics-hyogo/card-data/outofthecountry-prefecture.jsonを保存しました
# statistics-hyogo/card-data/social-change-rate-prefecture.jsonを保存しました
# statistics-hyogo/card-data/outflow-inside-prefecture.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-prefecture.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-prefecture.jsonを保存しました
# statistics-hyogo/card-data/inflow-outside-prefecture.jsonを保存しました
# statistics-hyogo/card-data/daytime-population-prefecture.jsonを保存しました
# statistics-hyogo/card-data/household-prefecture.jsonを保存しました
# statistics-hyogo/card-data/nuclear-family-household-prefecture.jsonを保存しました
# statistics-hyogo/card-data/single-household-prefecture.jsonを保存しました
# statistics-hyogo/card-data/senior-household-prefecture.jsonを保存しました
# statistics-hyogo/card-data/single-mother-household-prefecture.jsonを保存しました
# statistics-hyogo/card-data/single-father-household-prefecture.jsonを保存しました
# statistics-hyogo/card-data/marriage-prefecture.jsonを保存しました
# statistics-hyogo/card-data/first-marriage-age-prefecture.jsonを保存しました
# statistics-hyogo/card-data/divorce-prefecture.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_01000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_02000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_03000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_04000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_05000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_06000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_07000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_08000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_09000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_10000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_11000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_12000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_13000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_14000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_15000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_16000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_17000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_18000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_19000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_20000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_21000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_22000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_23000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_24000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_25000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_26000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_27000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_28000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_29000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_30000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_31000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_32000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_33000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_34000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_35000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_36000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_37000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_38000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_39000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_40000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_41000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_42000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_43000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_44000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_45000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_46000.jsonを保存しました
# statistics-hyogo/card-data/total-population-city_47000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_01000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_02000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_03000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_04000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_05000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_06000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_07000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_08000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_09000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_10000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_11000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_12000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_13000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_14000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_15000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_16000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_17000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_18000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_19000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_20000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_21000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_22000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_23000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_24000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_25000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_26000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_27000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_28000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_29000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_30000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_31000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_32000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_33000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_34000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_35000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_36000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_37000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_38000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_39000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_40000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_41000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_42000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_43000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_44000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_45000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_46000.jsonを保存しました
# statistics-hyogo/card-data/japanese-population-city_47000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_01000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_02000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_03000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_04000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_05000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_06000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_07000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_08000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_09000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_10000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_11000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_12000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_13000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_14000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_15000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_16000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_17000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_18000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_19000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_20000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_21000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_22000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_23000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_24000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_25000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_26000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_27000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_28000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_29000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_30000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_31000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_32000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_33000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_34000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_35000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_36000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_37000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_38000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_39000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_40000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_41000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_42000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_43000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_44000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_45000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_46000.jsonを保存しました
# statistics-hyogo/card-data/median-age-city_47000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_01000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_02000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_03000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_04000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_05000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_06000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_07000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_08000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_09000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_10000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_11000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_12000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_13000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_14000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_15000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_16000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_17000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_18000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_19000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_20000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_21000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_22000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_23000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_24000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_25000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_26000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_27000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_28000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_29000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_30000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_31000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_32000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_33000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_34000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_35000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_36000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_37000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_38000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_39000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_40000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_41000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_42000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_43000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_44000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_45000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_46000.jsonを保存しました
# statistics-hyogo/card-data/population-age-city_47000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_01000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_02000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_03000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_04000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_05000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_06000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_07000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_08000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_09000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_10000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_11000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_12000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_13000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_14000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_15000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_16000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_17000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_18000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_19000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_20000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_21000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_22000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_23000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_24000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_25000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_26000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_27000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_28000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_29000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_30000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_31000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_32000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_33000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_34000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_35000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_36000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_37000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_38000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_39000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_40000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_41000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_42000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_43000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_44000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_45000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_46000.jsonを保存しました
# statistics-hyogo/card-data/unmarried-rate-city_47000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_01000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_02000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_03000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_04000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_05000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_06000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_07000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_08000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_09000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_10000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_11000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_12000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_13000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_14000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_15000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_16000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_17000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_18000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_19000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_20000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_21000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_22000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_23000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_24000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_25000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_26000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_27000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_28000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_29000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_30000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_31000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_32000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_33000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_34000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_35000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_36000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_37000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_38000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_39000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_40000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_41000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_42000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_43000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_44000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_45000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_46000.jsonを保存しました
# statistics-hyogo/card-data/foreigner-population-city_47000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_01000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_02000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_03000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_04000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_05000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_06000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_07000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_08000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_09000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_10000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_11000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_12000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_13000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_14000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_15000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_16000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_17000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_18000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_19000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_20000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_21000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_22000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_23000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_24000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_25000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_26000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_27000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_28000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_29000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_30000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_31000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_32000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_33000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_34000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_35000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_36000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_37000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_38000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_39000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_40000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_41000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_42000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_43000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_44000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_45000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_46000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-population-city_47000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_01000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_02000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_03000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_04000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_05000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_06000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_07000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_08000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_09000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_10000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_11000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_12000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_13000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_14000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_15000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_16000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_17000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_18000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_19000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_20000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_21000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_22000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_23000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_24000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_25000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_26000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_27000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_28000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_29000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_30000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_31000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_32000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_33000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_34000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_35000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_36000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_37000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_38000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_39000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_40000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_41000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_42000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_43000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_44000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_45000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_46000.jsonを保存しました
# statistics-hyogo/card-data/densely-populated-area-city_47000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_01000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_02000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_03000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_04000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_05000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_06000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_07000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_08000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_09000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_10000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_11000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_12000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_13000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_14000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_15000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_16000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_17000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_18000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_19000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_20000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_21000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_22000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_23000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_24000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_25000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_26000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_27000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_28000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_29000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_30000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_31000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_32000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_33000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_34000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_35000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_36000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_37000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_38000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_39000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_40000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_41000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_42000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_43000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_44000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_45000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_46000.jsonを保存しました
# statistics-hyogo/card-data/birth-city_47000.jsonを保存しました
# statistics-hyogo/card-data/death-city_01000.jsonを保存しました
# statistics-hyogo/card-data/death-city_02000.jsonを保存しました
# statistics-hyogo/card-data/death-city_03000.jsonを保存しました
# statistics-hyogo/card-data/death-city_04000.jsonを保存しました
# statistics-hyogo/card-data/death-city_05000.jsonを保存しました
# statistics-hyogo/card-data/death-city_06000.jsonを保存しました
# statistics-hyogo/card-data/death-city_07000.jsonを保存しました
# statistics-hyogo/card-data/death-city_08000.jsonを保存しました
# statistics-hyogo/card-data/death-city_09000.jsonを保存しました
# statistics-hyogo/card-data/death-city_10000.jsonを保存しました
# statistics-hyogo/card-data/death-city_11000.jsonを保存しました
# statistics-hyogo/card-data/death-city_12000.jsonを保存しました
# statistics-hyogo/card-data/death-city_13000.jsonを保存しました
# statistics-hyogo/card-data/death-city_14000.jsonを保存しました
# statistics-hyogo/card-data/death-city_15000.jsonを保存しました
# statistics-hyogo/card-data/death-city_16000.jsonを保存しました
# statistics-hyogo/card-data/death-city_17000.jsonを保存しました
# statistics-hyogo/card-data/death-city_18000.jsonを保存しました
# statistics-hyogo/card-data/death-city_19000.jsonを保存しました
# statistics-hyogo/card-data/death-city_20000.jsonを保存しました
# statistics-hyogo/card-data/death-city_21000.jsonを保存しました
# statistics-hyogo/card-data/death-city_22000.jsonを保存しました
# statistics-hyogo/card-data/death-city_23000.jsonを保存しました
# statistics-hyogo/card-data/death-city_24000.jsonを保存しました
# statistics-hyogo/card-data/death-city_25000.jsonを保存しました
# statistics-hyogo/card-data/death-city_26000.jsonを保存しました
# statistics-hyogo/card-data/death-city_27000.jsonを保存しました
# statistics-hyogo/card-data/death-city_28000.jsonを保存しました
# statistics-hyogo/card-data/death-city_29000.jsonを保存しました
# statistics-hyogo/card-data/death-city_30000.jsonを保存しました
# statistics-hyogo/card-data/death-city_31000.jsonを保存しました
# statistics-hyogo/card-data/death-city_32000.jsonを保存しました
# statistics-hyogo/card-data/death-city_33000.jsonを保存しました
# statistics-hyogo/card-data/death-city_34000.jsonを保存しました
# statistics-hyogo/card-data/death-city_35000.jsonを保存しました
# statistics-hyogo/card-data/death-city_36000.jsonを保存しました
# statistics-hyogo/card-data/death-city_37000.jsonを保存しました
# statistics-hyogo/card-data/death-city_38000.jsonを保存しました
# statistics-hyogo/card-data/death-city_39000.jsonを保存しました
# statistics-hyogo/card-data/death-city_40000.jsonを保存しました
# statistics-hyogo/card-data/death-city_41000.jsonを保存しました
# statistics-hyogo/card-data/death-city_42000.jsonを保存しました
# statistics-hyogo/card-data/death-city_43000.jsonを保存しました
# statistics-hyogo/card-data/death-city_44000.jsonを保存しました
# statistics-hyogo/card-data/death-city_45000.jsonを保存しました
# statistics-hyogo/card-data/death-city_46000.jsonを保存しました
# statistics-hyogo/card-data/death-city_47000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_01000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_02000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_03000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_04000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_05000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_06000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_07000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_08000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_09000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_10000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_11000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_12000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_13000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_14000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_15000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_16000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_17000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_18000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_19000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_20000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_21000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_22000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_23000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_24000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_25000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_26000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_27000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_28000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_29000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_30000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_31000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_32000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_33000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_34000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_35000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_36000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_37000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_38000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_39000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_40000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_41000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_42000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_43000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_44000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_45000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_46000.jsonを保存しました
# statistics-hyogo/card-data/movein-city_47000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_01000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_02000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_03000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_04000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_05000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_06000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_07000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_08000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_09000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_10000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_11000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_12000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_13000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_14000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_15000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_16000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_17000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_18000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_19000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_20000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_21000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_22000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_23000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_24000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_25000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_26000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_27000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_28000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_29000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_30000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_31000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_32000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_33000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_34000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_35000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_36000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_37000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_38000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_39000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_40000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_41000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_42000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_43000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_44000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_45000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_46000.jsonを保存しました
# statistics-hyogo/card-data/moveout-city_47000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_01000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_02000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_03000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_04000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_05000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_06000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_07000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_08000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_09000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_10000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_11000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_12000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_13000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_14000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_15000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_16000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_17000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_18000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_19000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_20000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_21000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_22000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_23000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_24000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_25000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_26000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_27000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_28000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_29000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_30000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_31000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_32000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_33000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_34000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_35000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_36000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_37000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_38000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_39000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_40000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_41000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_42000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_43000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_44000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_45000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_46000.jsonを保存しました
# statistics-hyogo/card-data/outflow-outside-city_47000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_01000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_02000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_03000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_04000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_05000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_06000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_07000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_08000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_09000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_10000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_11000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_12000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_13000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_14000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_15000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_16000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_17000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_18000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_19000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_20000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_21000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_22000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_23000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_24000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_25000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_26000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_27000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_28000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_29000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_30000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_31000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_32000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_33000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_34000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_35000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_36000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_37000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_38000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_39000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_40000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_41000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_42000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_43000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_44000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_45000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_46000.jsonを保存しました
# statistics-hyogo/card-data/inflow-inside-city_47000.jsonを保存しました
# statistics-hyogo/card-data/household-city_01000.jsonを保存しました
# statistics-hyogo/card-data/household-city_02000.jsonを保存しました
# statistics-hyogo/card-data/household-city_03000.jsonを保存しました
# statistics-hyogo/card-data/household-city_04000.jsonを保存しました
# statistics-hyogo/card-data/household-city_05000.jsonを保存しました
# statistics-hyogo/card-data/household-city_06000.jsonを保存しました
# statistics-hyogo/card-data/household-city_07000.jsonを保存しました
# statistics-hyogo/card-data/household-city_08000.jsonを保存しました
# statistics-hyogo/card-data/household-city_09000.jsonを保存しました
# statistics-hyogo/card-data/household-city_10000.jsonを保存しました
# statistics-hyogo/card-data/household-city_11000.jsonを保存しました
# statistics-hyogo/card-data/household-city_12000.jsonを保存しました
# statistics-hyogo/card-data/household-city_13000.jsonを保存しました
# statistics-hyogo/card-data/household-city_14000.jsonを保存しました
# statistics-hyogo/card-data/household-city_15000.jsonを保存しました
# statistics-hyogo/card-data/household-city_16000.jsonを保存しました
# statistics-hyogo/card-data/household-city_17000.jsonを保存しました
# statistics-hyogo/card-data/household-city_18000.jsonを保存しました
# statistics-hyogo/card-data/household-city_19000.jsonを保存しました
# statistics-hyogo/card-data/household-city_20000.jsonを保存しました
# statistics-hyogo/card-data/household-city_21000.jsonを保存しました
# statistics-hyogo/card-data/household-city_22000.jsonを保存しました
# statistics-hyogo/card-data/household-city_23000.jsonを保存しました
# statistics-hyogo/card-data/household-city_24000.jsonを保存しました
# statistics-hyogo/card-data/household-city_25000.jsonを保存しました
# statistics-hyogo/card-data/household-city_26000.jsonを保存しました
# statistics-hyogo/card-data/household-city_27000.jsonを保存しました
# statistics-hyogo/card-data/household-city_28000.jsonを保存しました
# statistics-hyogo/card-data/household-city_29000.jsonを保存しました
# statistics-hyogo/card-data/household-city_30000.jsonを保存しました
# statistics-hyogo/card-data/household-city_31000.jsonを保存しました
# statistics-hyogo/card-data/household-city_32000.jsonを保存しました
# statistics-hyogo/card-data/household-city_33000.jsonを保存しました
# statistics-hyogo/card-data/household-city_34000.jsonを保存しました
# statistics-hyogo/card-data/household-city_35000.jsonを保存しました
# statistics-hyogo/card-data/household-city_36000.jsonを保存しました
# statistics-hyogo/card-data/household-city_37000.jsonを保存しました
# statistics-hyogo/card-data/household-city_38000.jsonを保存しました
# statistics-hyogo/card-data/household-city_39000.jsonを保存しました
# statistics-hyogo/card-data/household-city_40000.jsonを保存しました
# ...
# statistics-hyogo/card-data/product-sales-amount-city_24000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_25000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_26000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_27000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_28000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_29000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_30000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_31000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_32000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_33000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_34000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_35000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_36000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_37000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_38000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_39000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_40000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_41000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_42000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_43000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_44000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_45000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_46000.jsonを保存しました
# statistics-hyogo/card-data/product-sales-amount-city_47000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_01000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_02000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_03000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_04000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_05000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_06000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_07000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_08000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_09000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_10000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_11000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_12000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_13000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_14000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_15000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_16000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_17000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_18000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_19000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_20000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_21000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_22000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_23000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_24000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_25000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_26000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_27000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_28000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_29000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_30000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_31000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_32000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_33000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_34000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_35000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_36000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_37000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_38000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_39000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_40000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_41000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_42000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_43000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_44000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_45000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_46000.jsonを保存しました
# statistics-hyogo/card-data/commercial-establishments-city_47000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_01000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_02000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_03000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_04000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_05000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_06000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_07000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_08000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_09000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_10000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_11000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_12000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_13000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_14000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_15000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_16000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_17000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_18000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_19000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_20000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_21000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_22000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_23000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_24000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_25000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_26000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_27000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_28000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_29000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_30000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_31000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_32000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_33000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_34000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_35000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_36000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_37000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_38000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_39000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_40000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_41000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_42000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_43000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_44000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_45000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_46000.jsonを保存しました
# statistics-hyogo/card-data/standard-price-city_47000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_01000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_02000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_03000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_04000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_05000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_06000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_07000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_08000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_09000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_10000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_11000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_12000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_13000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_14000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_15000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_16000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_17000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_18000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_19000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_20000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_21000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_22000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_23000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_24000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_25000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_26000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_27000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_28000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_29000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_30000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_31000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_32000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_33000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_34000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_35000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_36000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_37000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_38000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_39000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_40000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_41000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_42000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_43000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_44000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_45000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_46000.jsonを保存しました
# statistics-hyogo/card-data/administrative-staff-city_47000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_01000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_02000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_03000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_04000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_05000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_06000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_07000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_08000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_09000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_10000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_11000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_12000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_13000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_14000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_15000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_16000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_17000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_18000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_19000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_20000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_21000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_22000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_23000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_24000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_25000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_26000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_27000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_28000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_29000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_30000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_31000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_32000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_33000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_34000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_35000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_36000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_37000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_38000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_39000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_40000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_41000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_42000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_43000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_44000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_45000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_46000.jsonを保存しました
# statistics-hyogo/card-data/financial-strength-index-city_47000.jsonを保存しました
# statistics-hyogo/card-data/real-balance-ratio-city_01000.jsonを保存しました
# statistics-hyogo/card-data/real-balance-ratio-city_02000.jsonを保存しました
# statistics-hyogo/card-data/real-balance-ratio-city_03000.jsonを保存しました
# statistics-hyogo/card-data/real-balance-ratio-city_04000.jsonを保存しました
# statistics-hyogo/card-data/real-balance-ratio-city_05000.jsonを保存しました
# statistics-hyogo/card-data/real-balance-ratio-city_06000.jsonを保存しました
# statistics-hyogo/card-data/real-balance-ratio-city_07000.jsonを保存しました
# statistics-hyogo/card-data/real-balance-ratio-city_08000.jsonを保存しました
# statistics-hyogo/card-data/real-balance-ratio-city_09000.jsonを保存しました
# statistics-hyogo/card-data/real-balance-ratio-city_10000.jsonを保存しました
# statistics-hyogo/card-data/real-balance-ratio-city_11000.jsonを保存しました
