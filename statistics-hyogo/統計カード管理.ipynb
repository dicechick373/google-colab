# %% [markdown]
# # 実行環境の作成

# %% [markdown]
# ## Google Drive

# %% [markdown]
# Google Driveをマウント

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Google Cloud Storage

# %% [markdown]
# 下記コードでGCPに接続

# %%
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# 認証に成功したらgcsfuseをインストール

# %%
# !echo "deb http://packages.cloud.google.com/apt gcsfuse-`lsb_release -c -s` main" | sudo tee /etc/apt/sources.list.d/gcsfuse.list
# !curl https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo apt-key add -
# !apt-get -y -q update
# !apt-get -y -q install gcsfuse

# %% [markdown]
# バケット「statistics-hyogo」をディレクトリ「statistics-hyogo」にマウント

# %%
! mkdir -p statistics-hyogo
! gcsfuse --implicit-dirs --limit-bytes-per-sec -1 --limit-ops-per-sec -1 statistics-hyogo statistics-hyogo

# %% [markdown]
# ## Google Sheets

# %% [markdown]
# ライブラリのインストール

# %%
# !pip install --upgrade -q gspread

# %% [markdown]
# GoogleSheetsの認証

# %%
from google.colab import auth
from google.auth import default
import gspread

auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# %% [markdown]
# ## ESTAT_APP_ID

# %%
ESTAT_APPID = '724e5b90772a3e9289f41a253e4e7e32438f4fff'

# %% [markdown]
# ## pythonのライブラリ追加

# %%
import urllib.parse
import urllib.request
import json
import pandas as pd

# %% [markdown]
# # estatの統計情報を取得

# %% [markdown]
# 'statsDataId'に統計表コードを指定

# %%
statsDataId = '0000020211'

# %% [markdown]
# メタ情報を取得する関数を作成

# %%
def get_estat_meta(statsDataId):
  # リクエストパラメータ
  p={}
  p['statsDataId'] = statsDataId
  p['appId'] = ESTAT_APPID

  url = 'http://api.e-stat.go.jp/rest/3.0/app/json/getMetaInfo?'
  url += urllib.parse.urlencode(p)

  with urllib.request.urlopen(url) as response:
    return json.loads(response.read().decode('utf-8'))

meta = get_estat_meta(statsDataId)
# print(meta)

# %% [markdown]
# ## DataFrameの作成

# %% [markdown]
# メタ情報をDataFrameに整形する

# %%
def get_cards_dataframe(statsDataId):
  # メタ情報の取得
  meta= get_estat_meta(statsDataId)
 
  # STAT_NAME
  STAT_NAME = meta['GET_META_INFO']['METADATA_INF']['TABLE_INF']['STAT_NAME']['$']

  # CLASS_OBJ
  CLASS_OBJ = meta['GET_META_INFO']['METADATA_INF']['CLASS_INF']['CLASS_OBJ']

  # cat01
  cat01 = next((d for d in CLASS_OBJ if d['@id'] == 'cat01'), None)['CLASS']

  # DataFrame
  df = pd.json_normalize(cat01)[['@code','@name']]
  
  # 統計表情報の追加
  df['statsDataId'] = statsDataId
  df['statsDataName'] = STAT_NAME

  # 列名の変更
  columns = {'@code':'categoryCode','@name':'categoryName'}
  df= df.rename(columns=columns)

  # categoryNameから不要な情報（categoryCode）を削除
  df['categoryName'] = df.apply(lambda x: x['categoryName'].replace(x['categoryCode']+'_', ''), 1)
  
  
  # 並べ替え
  df = df.reindex(columns=['statsDataId', 'statsDataName', 'categoryCode','categoryName'])
  
  return df


# print(len(category_codes))

# %%
df = get_cards_dataframe(statsDataId)
df
# Out:
#   statsDataId statsDataName categoryCode categoryName
# 0  0000020211     社会・人口統計体系        K3101     交通事故発生件数
# 1  0000020211     社会・人口統計体系        K4201      刑法犯認知件数

# %% [markdown]
# ## 統計カード管理情報をSpreadSheetで加工

# %% [markdown]
# 統計カードの管理情報を SpreadSheetで管理する
#
# 前セルで作業したDataFrameをcsvでコピーするなどして作業すること
#
#
# [statistics-hyogo/統計カード管理](https://docs.google.com/spreadsheets/d/1mAv2gx9khNOty_ILu3aJjJz0uoRkARzwoaG4VBUSNG4/edit#gid=0)

# %% [markdown]
# # コンテンツ作成

# %% [markdown]
# ## 統計分野一覧

# %% [markdown]
# GoogleSheetsから統計分野一覧を取得

# %%
def get_statistics_fields():

  # シート情報の設定
  id = "1mAv2gx9khNOty_ILu3aJjJz0uoRkARzwoaG4VBUSNG4"
  sheet_name = 'statisticsFields'
  worksheet = gc.open_by_key(id).worksheet(sheet_name)
  
  return worksheet.get_all_records()

# %%
statistics_fields = get_statistics_fields()
print(statistics_fields)
# Out:
# [{'index': 1, 'fieldId': 'landweather', 'fieldTitle': '国土・気象'}, {'index': 2, 'fieldId': 'population', 'fieldTitle': '人口・世帯'}, {'index': 3, 'fieldId': 'laborwage', 'fieldTitle': '労働・賃金'}, {'index': 4, 'fieldId': 'agriculture', 'fieldTitle': '農林水産業'}, {'index': 5, 'fieldId': 'miningindustry', 'fieldTitle': '鉱工業'}, {'index': 6, 'fieldId': 'commercial', 'fieldTitle': '商業・サービス業'}, {'index': 7, 'fieldId': 'economy', 'fieldTitle': '企業・家計・経済'}, {'index': 8, 'fieldId': 'construction', 'fieldTitle': '住宅・土地・建設'}, {'index': 9, 'fieldId': 'energy', 'fieldTitle': 'エネルギー・水'}, {'index': 10, 'fieldId': 'tourism', 'fieldTitle': '運輸・観光'}, {'index': 11, 'fieldId': 'educationsports', 'fieldTitle': '教育・文化・スポーツ'}, {'index': 12, 'fieldId': 'administrativefinancial', 'fieldTitle': '行財政'}, {'index': 13, 'fieldId': 'safetyenvironment', 'fieldTitle': '司法・安全・環境'}, {'index': 14, 'fieldId': 'socialsecurity', 'fieldTitle': '医療・社会保障・衛生'}, {'index': 15, 'fieldId': 'international', 'fieldTitle': '国際'}]

# %% [markdown]
# GoogleDriveとGoogleCloudStorageに保存

# %%
def save_json(dic,path):
  
  # Google Driveへ保存
  drive_path = "drive/MyDrive/statistics-hyogo/{}".format(path)
  
  with open(drive_path, 'w') as f:
    json.dump(dic,f,ensure_ascii=False)
  
  # GoogleCloudStorage
  gcs_path = "statistics-hyogo/{}".format(path)
  with open(gcs_path, 'w') as f:
    json.dump(dic,f,ensure_ascii=False)

# %%
dic = get_statistics_fields()
path = "contents/statistics-fields.json"

save_json(dic,path)

# %% [markdown]
# ## 統計項目一覧

# %% [markdown]
# GoogleSheetsから統計項目一覧を取得

# %%
def get_statistics_menus():

  # シート情報の設定
  id = "1mAv2gx9khNOty_ILu3aJjJz0uoRkARzwoaG4VBUSNG4"
  sheet_name = 'statisticsMenus'
  worksheet = gc.open_by_key(id).worksheet(sheet_name)
  
  return worksheet.get_all_records()

# %%
statistics_menus = get_statistics_menus()
print(statistics_menus)
# Out:
# [{'index': 11, 'menuId': 'area', 'menuTitle': '面積', 'fieldId': 'landweather', 'fieldTitle': '国土・気象'}, {'index': 12, 'menuId': 'climate', 'menuTitle': '気候', 'fieldId': 'landweather', 'fieldTitle': '国土・気象'}, {'index': 13, 'menuId': 'park', 'menuTitle': '自然・公園', 'fieldId': 'landweather', 'fieldTitle': '国土・気象'}, {'index': 21, 'menuId': 'population', 'menuTitle': '人口', 'fieldId': 'population', 'fieldTitle': '人口・世帯'}, {'index': 22, 'menuId': 'household', 'menuTitle': '世帯', 'fieldId': 'population', 'fieldTitle': '人口・世帯'}, {'index': 23, 'menuId': 'marriage', 'menuTitle': '婚姻', 'fieldId': 'population', 'fieldTitle': '人口・世帯'}, {'index': 24, 'menuId': 'birth', 'menuTitle': '出生', 'fieldId': 'population', 'fieldTitle': '人口・世帯'}, {'index': 25, 'menuId': 'death', 'menuTitle': '死亡', 'fieldId': 'population', 'fieldTitle': '人口・世帯'}, {'index': 26, 'menuId': 'inflowoutflow', 'menuTitle': '流入・流出', 'fieldId': 'population', 'fieldTitle': '人口・世帯'}, {'index': 27, 'menuId': 'moveinmoveout', 'menuTitle': '転入・転出', 'fieldId': 'population', 'fieldTitle': '人口・世帯'}, {'index': 31, 'menuId': 'labor-force', 'menuTitle': '労働力人口', 'fieldId': 'laborwage', 'fieldTitle': '労働・賃金'}, {'index': 32, 'menuId': 'laborwage', 'menuTitle': '労働・賃金', 'fieldId': 'laborwage', 'fieldTitle': '労働・賃金'}, {'index': 41, 'menuId': 'agriculture', 'menuTitle': '農業', 'fieldId': 'agriculture', 'fieldTitle': '農林水産業'}, {'index': 42, 'menuId': 'forestry', 'menuTitle': '林業', 'fieldId': 'agriculture', 'fieldTitle': '農林水産業'}, {'index': 43, 'menuId': 'fishing', 'menuTitle': '漁業', 'fieldId': 'agriculture', 'fieldTitle': '農林水産業'}, {'index': 51, 'menuId': 'manufacturing-industry', 'menuTitle': '製造業', 'fieldId': 'miningindustry', 'fieldTitle': '鉱工業'}, {'index': 52, 'menuId': 'industrial-water', 'menuTitle': '工業用水', 'fieldId': 'miningindustry', 'fieldTitle': '鉱工業'}, {'index': 61, 'menuId': 'commercial', 'menuTitle': '商業', 'fieldId': 'commercial', 'fieldTitle': '商業・サービス業'}, {'index': 71, 'menuId': 'gross-domestic-product', 'menuTitle': '総生産', 'fieldId': 'economy', 'fieldTitle': '企業・家計・経済'}, {'index': 72, 'menuId': 'household-budget', 'menuTitle': '家計', 'fieldId': 'economy', 'fieldTitle': '企業・家計・経済'}, {'index': 73, 'menuId': 'price', 'menuTitle': '物価', 'fieldId': 'economy', 'fieldTitle': '企業・家計・経済'}, {'index': 74, 'menuId': 'sales', 'menuTitle': '売上', 'fieldId': 'economy', 'fieldTitle': '企業・家計・経済'}, {'index': 75, 'menuId': 'establishments', 'menuTitle': '事業所等', 'fieldId': 'economy', 'fieldTitle': '企業・家計・経済'}, {'index': 81, 'menuId': 'land', 'menuTitle': '土地', 'fieldId': 'construction', 'fieldTitle': '住宅・土地・建設'}, {'index': 82, 'menuId': 'construction', 'menuTitle': '建設', 'fieldId': 'construction', 'fieldTitle': '住宅・土地・建設'}, {'index': 91, 'menuId': 'energy', 'menuTitle': 'エネルギー', 'fieldId': 'energy', 'fieldTitle': 'エネルギー・水'}, {'index': 92, 'menuId': 'garbage', 'menuTitle': 'ごみ', 'fieldId': 'energy', 'fieldTitle': 'エネルギー・水'}, {'index': 101, 'menuId': 'car', 'menuTitle': '自動車', 'fieldId': 'tourism', 'fieldTitle': '運輸・観光'}, {'index': 102, 'menuId': 'traffic', 'menuTitle': '交通', 'fieldId': 'tourism', 'fieldTitle': '運輸・観光'}, {'index': 103, 'menuId': 'hotel', 'menuTitle': '宿泊施設', 'fieldId': 'tourism', 'fieldTitle': '運輸・観光'}, {'index': 104, 'menuId': 'guest', 'menuTitle': '宿泊者数', 'fieldId': 'tourism', 'fieldTitle': '運輸・観光'}, {'index': 111, 'menuId': 'education', 'menuTitle': '教育', 'fieldId': 'educationsports', 'fieldTitle': '教育・文化・スポーツ'}, {'index': 112, 'menuId': 'kindergarten', 'menuTitle': '幼稚園', 'fieldId': 'educationsports', 'fieldTitle': '教育・文化・スポーツ'}, {'index': 113, 'menuId': 'primary-schools', 'menuTitle': '小学校', 'fieldId': 'educationsports', 'fieldTitle': '教育・文化・スポーツ'}, {'index': 114, 'menuId': 'junior-high-school', 'menuTitle': '中学校', 'fieldId': 'educationsports', 'fieldTitle': '教育・文化・スポーツ'}, {'index': 115, 'menuId': 'high-school', 'menuTitle': '高等学校', 'fieldId': 'educationsports', 'fieldTitle': '教育・文化・スポーツ'}, {'index': 116, 'menuId': 'university', 'menuTitle': '短大・大学', 'fieldId': 'educationsports', 'field ...

# %% [markdown]
# GoogleDriveとGoogleCloudStorageに保存

# %%
def save_json(dic,path):
  
  # Google Driveへ保存
  drive_path = "drive/MyDrive/statistics-hyogo/{}".format(path)
  
  with open(drive_path, 'w') as f:
    json.dump(dic,f,ensure_ascii=False)
  
  # GoogleCloudStorage
  gcs_path = "statistics-hyogo/{}".format(path)
  with open(gcs_path, 'w') as f:
    json.dump(dic,f,ensure_ascii=False)

# %%
dic = get_statistics_menus()
path = "contents/statistics-menus.json"

save_json(dic,path)

# %% [markdown]
# ## 統計カード一覧

# %% [markdown]
# GoogleSheetsから統計カード一覧を取得してDataFrameに変換

# %%
import numpy as np

def get_statistics_cards():

  # シート情報の設定
  id = "1mAv2gx9khNOty_ILu3aJjJz0uoRkARzwoaG4VBUSNG4"
  sheet_name = 'statisticsCards'
  worksheet = gc.open_by_key(id).worksheet(sheet_name)

  # データを取得してDataFrameに格納
  dic = worksheet.get_all_records()
  df = pd.DataFrame(dic)

  # 空白行を削除
  df['cardId'].replace('', np.nan, inplace=True)
  df.dropna(subset=['cardId'], inplace=True)

  # カテゴリ情報
  df_categories = set_categories(df)

  # estat-APIのパラメータ情報
  df_estatParams = set_estat_params(df)

  # 重複を排除して必要な列だけ抽出
  df_res = df.drop_duplicates(subset='cardId')
  df_res = df_res[['cardId','cardTitle','cardIndex','governmentType','menuId','menuTitle','fieldId','fieldTitle','chartComponent']]

  # マージ
  df_res = pd.merge(df_res, df_categories, on='cardId', how='outer')
  df_res = pd.merge(df_res, df_estatParams, on='cardId', how='outer')
  
  return df_res

"""
カテゴリ情報をセットする関数
"""
def set_categories(df_arg):
  df_res = df_arg.copy()

  # オブジェクト作成
  def func(row):
   return {
        'categoryCode' : row.categoryCode,
        'categoryName' : row.categoryName,
        'isSelect' : row.isSelect,
        'type' : row.type,
        'yAxis' : row.yAxis
    }
  df_res['categories'] = df_res.apply(func, 1)
  
  # cardIdでグループ化
  df_res = df_res.groupby('cardId')['categories'].apply(list).reset_index()
  
  return df_res 

"""
estat-APIのパラメータをセットする関数
"""
def set_estat_params(df_arg):
  # statsDataId
  df_statsDataId = df_arg.drop_duplicates(subset='cardId').loc[:,['cardId','statsDataId']]
  df_statsDataId['statsDataId'] = df_statsDataId.apply(lambda x: str(x['statsDataId']).zfill(10), 1)
  
  # cdCat01
  df_cat01 = df_arg[['cardId','categoryCode']] \
             .rename(columns={'categoryCode':'cdCat01'})  \
             .groupby(['cardId']).agg({'cdCat01': lambda x: ','.join(x)}).reset_index()

  # オブジェクトを'estatParams'に格納
  df_res = pd.merge(df_statsDataId, df_cat01, on='cardId', how='outer')
  def func(row):
   return {
        'statsDataId' : row.statsDataId,
        'cdCat01' : row.cdCat01,
    }
  df_res['estatParams'] = df_res.apply(func, 1)
  

  return df_res[['cardId','estatParams']]

# %%
df_statistics_cards = get_statistics_cards()
df_statistics_cards
# Out:
#                                             cardId         cardTitle  \
# 0                      total-population-prefecture          都道府県の総人口
# 1                   japanese-population-prefecture        都道府県の日本人人口
# 2                    population-pyramid-prefecture      都道府県の人口ピラミッド
# 3                            median-age-prefecture        都道府県の年齢中位数
# 4                       population-age-prefecture       都道府県の年齢３区分人口
# ..                                             ...               ...
# 232                                pharmacist-city         市区町村の薬剤師数
# 233                welfare-facilities-elderly-city      市区町村の老人福祉施設数
# 234                 national-health-insurance-city  市区町村の国民健康保険被保険者数
# 235  national-health-insurance-benefit-amount-city   市区町村の国民健康保険給付金額
# 236                                  incident-city     市区町村の交通事故事件件数
#
#     cardIndex governmentType            menuId menuTitle            fieldId  \
# 0           1     prefecture        population        人口         population
# 1                 prefecture        population        人口         population
# 2                 prefecture        population        人口         population
# 3                 prefecture        population        人口         population
# 4                 prefecture        population        人口         population
# ..        ...            ...               ...       ...                ...
# 232                     city           medical        医療     socialsecurity
# 233                     city           medical        医療     socialsecurity
# 234                     city           medical        医療     socialsecurity
# 235                     city           medical        医療     socialsecurity
# 236                     city  traffic-accident      交通事故  safetyenvironment
#
#      fieldTitle chartComponent  \
# 0         人口・世帯      TimeChart
# 1         人口・世帯      TimeChart
# 2         人口・世帯   PyramidChart
# 3         人口・世帯      TimeChart
# 4         人口・世帯      TimeChart
# ..          ...            ...
# 232  医療・社会保障・衛生      TimeChart
# 233  医療・社会保障・衛生      TImeChart
# 234  医療・社会保障・衛生      TimeChart
# 235  医療・社会保障・衛生      TimeChart
# 236    司法・安全・環境      TimeChart
#
#                                             categories  \
# 0    [{'categoryCode': 'A1101', 'categoryName': '総人...
# 1    [{'categoryCode': 'A1102', 'categoryName': '日本...
# 2    [{'categoryCode': 'A120101', 'categoryName': '...
# 3    [{'categoryCode': 'A1231', 'categoryName': '年齢...
# 4    [{'categoryCode': 'A1301', 'categoryName': '15...
# ..                                                 ...
# 232  [{'categoryCode': 'I6300', 'categoryName': '薬剤...
# 233  [{'categoryCode': 'J2301', 'categoryName': '老人...
# 234  [{'categoryCode': 'J4101', 'categoryName': '国民...
# 235  [{'categoryCode': 'J4102', 'categoryName': '国民...
# 236  [{'categoryCode': 'K3101', 'categoryName': '交通...
#
#                                            estatParams
# 0    {'statsDataId': '0000010101', 'cdCat01': 'A110...
# 1    {'statsDataId': '0000010101', 'cdCat01': 'A110...
# 2    {'statsDataId': '0000010101', 'cdCat01': 'A120...
# 3    {'statsDataId': '0000010101', 'cdCat01': 'A1231'}
# 4    {'statsDataId': '0000010101', 'cdCat01': 'A130...
# ..                                                 ...
# 232  {'statsDataId': '0000020209', 'cdCat01': 'I630...
# 233  {'statsDataId': '0000020210', 'cdCat01': 'J230...
# 234  {'statsDataId': '0000020210', 'cdCat01': 'J410...
# 235  {'statsDataId': '0000020210', 'cdCat01': 'J410...
# 236  {'statsDataId': '0000020211', 'cdCat01': 'K3101'}
#
# [237 rows x 11 columns]

# %% [markdown]
# GoogleDriveとGoogleCloudStorageに保存

# %%
def save_json(df,path):
  
  # Google Driveへ保存
  drive_path = "drive/MyDrive/statistics-hyogo/{}".format(path)
  df.reset_index().to_json(drive_path,orient='records',force_ascii=False)
  
  # GoogleCloudStorage
  gcs_path = "statistics-hyogo/{}".format(path)
  df.reset_index().to_json(gcs_path,orient='records',force_ascii=False)

# %%
df = get_statistics_cards()
path = "contents/statistics-cards.json"

save_json(df,path)

# %% [markdown]
# ## routes

# %% [markdown]
# 都道府県一覧

# %%
def get_preflist():
  with open('drive/MyDrive/statistics-hyogo/resas/preflist.json') as f:
    return json.load(f)

# %% [markdown]
# 市区町村一覧

# %%
def get_citylist():
  with open('drive/MyDrive/statistics-hyogo/resas/citylist.json') as f:
    return json.load(f)

print(get_citylist())
# Out:
# [{'prefCode': 1, 'cityCode': '01100', 'cityName': '札幌市', 'bigCityFlag': '2'}, {'prefCode': 1, 'cityCode': '01101', 'cityName': '札幌市中央区', 'bigCityFlag': '1'}, {'prefCode': 1, 'cityCode': '01102', 'cityName': '札幌市北区', 'bigCityFlag': '1'}, {'prefCode': 1, 'cityCode': '01103', 'cityName': '札幌市東区', 'bigCityFlag': '1'}, {'prefCode': 1, 'cityCode': '01104', 'cityName': '札幌市白石区', 'bigCityFlag': '1'}, {'prefCode': 1, 'cityCode': '01105', 'cityName': '札幌市豊平区', 'bigCityFlag': '1'}, {'prefCode': 1, 'cityCode': '01106', 'cityName': '札幌市南区', 'bigCityFlag': '1'}, {'prefCode': 1, 'cityCode': '01107', 'cityName': '札幌市西区', 'bigCityFlag': '1'}, {'prefCode': 1, 'cityCode': '01108', 'cityName': '札幌市厚別区', 'bigCityFlag': '1'}, {'prefCode': 1, 'cityCode': '01109', 'cityName': '札幌市手稲区', 'bigCityFlag': '1'}, {'prefCode': 1, 'cityCode': '01110', 'cityName': '札幌市清田区', 'bigCityFlag': '1'}, {'prefCode': 1, 'cityCode': '01202', 'cityName': '函館市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01203', 'cityName': '小樽市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01204', 'cityName': '旭川市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01205', 'cityName': '室蘭市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01206', 'cityName': '釧路市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01207', 'cityName': '帯広市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01208', 'cityName': '北見市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01209', 'cityName': '夕張市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01210', 'cityName': '岩見沢市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01211', 'cityName': '網走市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01212', 'cityName': '留萌市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01213', 'cityName': '苫小牧市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01214', 'cityName': '稚内市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01215', 'cityName': '美唄市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01216', 'cityName': '芦別市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01217', 'cityName': '江別市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01218', 'cityName': '赤平市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01219', 'cityName': '紋別市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01220', 'cityName': '士別市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01221', 'cityName': '名寄市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01222', 'cityName': '三笠市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01223', 'cityName': '根室市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01224', 'cityName': '千歳市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01225', 'cityName': '滝川市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01226', 'cityName': '砂川市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01227', 'cityName': '歌志内市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01228', 'cityName': '深川市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01229', 'cityName': '富良野市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01230', 'cityName': '登別市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01231', 'cityName': '恵庭市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01233', 'cityName': '伊達市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01234', 'cityName': '北広島市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01235', 'cityName': '石狩市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01236', 'cityName': '北斗市', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01303', 'cityName': '当別町', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01304', 'cityName': '新篠津村', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01331', 'cityName': '松前町', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01332', 'cityName': '福島町', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01333', 'cityName': '知内町', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01334', 'cityName': '木古内町', 'bigCityFlag': '0'}, {'prefCode': 1, 'cityCode': '01337', 'c ...

# %% [markdown]
# 統計カード一覧

# %%
def get_statistics_cards():
  with open('drive/MyDrive/statistics-hyogo/contents/statistics-cards.json') as f:
    return json.load(f)

print(get_statistics_cards())
# Out:
# [{'index': 0, 'cardId': 'total-population-prefecture', 'cardTitle': '都道府県の総人口', 'cardIndex': 1, 'governmentType': 'prefecture', 'menuId': 'population', 'menuTitle': '人口', 'fieldId': 'population', 'fieldTitle': '人口・世帯', 'chartComponent': 'TimeChart', 'categories': [{'categoryCode': 'A1101', 'categoryName': '総人口', 'isSelect': 'TRUE', 'type': 'column', 'yAxis': 0}, {'categoryCode': 'A110101', 'categoryName': '総人口（男）', 'isSelect': '', 'type': 'column', 'yAxis': 0}, {'categoryCode': 'A110102', 'categoryName': '総人口（女）', 'isSelect': '', 'type': 'column', 'yAxis': 0}], 'estatParams': {'statsDataId': '0000010101', 'cdCat01': 'A1101,A110101,A110102'}}, {'index': 1, 'cardId': 'japanese-population-prefecture', 'cardTitle': '都道府県の日本人人口', 'cardIndex': '', 'governmentType': 'prefecture', 'menuId': 'population', 'menuTitle': '人口', 'fieldId': 'population', 'fieldTitle': '人口・世帯', 'chartComponent': 'TimeChart', 'categories': [{'categoryCode': 'A1102', 'categoryName': '日本人人口', 'isSelect': 'TRUE', 'type': 'column', 'yAxis': 0}, {'categoryCode': 'A110201', 'categoryName': '日本人人口（男）', 'isSelect': '', 'type': 'column', 'yAxis': 0}, {'categoryCode': 'A110202', 'categoryName': '日本人人口（女）', 'isSelect': '', 'type': 'column', 'yAxis': 0}], 'estatParams': {'statsDataId': '0000010101', 'cdCat01': 'A1102,A110201,A110202'}}, {'index': 2, 'cardId': 'population-pyramid-prefecture', 'cardTitle': '都道府県の人口ピラミッド', 'cardIndex': '', 'governmentType': 'prefecture', 'menuId': 'population', 'menuTitle': '人口', 'fieldId': 'population', 'fieldTitle': '人口・世帯', 'chartComponent': 'PyramidChart', 'categories': [{'categoryCode': 'A120101', 'categoryName': '0～4歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120102', 'categoryName': '0～4歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120201', 'categoryName': '5～9歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120202', 'categoryName': '5～9歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120301', 'categoryName': '10～14歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120302', 'categoryName': '10～14歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120401', 'categoryName': '15～19歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120402', 'categoryName': '15～19歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120501', 'categoryName': '20～24歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120502', 'categoryName': '20～24歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120601', 'categoryName': '25～29歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120602', 'categoryName': '25～29歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120701', 'categoryName': '30～34歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120702', 'categoryName': '30～34歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120801', 'categoryName': '35～39歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120802', 'categoryName': '35～39歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120901', 'categoryName': '40～44歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A120902', 'categoryName': '40～44歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A121001', 'categoryName': '45～49歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A121002', 'categoryName': '45～49歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A121101', 'categoryName': '50～54歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A121102', 'categoryName': '50～54歳人口（女）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'categoryCode': 'A121201', 'categoryName': '55～59歳人口（男）', 'isSelect': 'TRUE', 'type': '', 'yAxis': ''}, {'cate ...

# %% [markdown]
# routes一覧を作成

# %%
def generate_routes(cards):

  res = []
  for card in cards:
    
    # 値の取得
    governmentType = card['governmentType']
    fieldId = card['fieldId']
    menuId = card['menuId']
    cardId = card['cardId']
  
    # 地域コード一覧作成
    codes = []
    if governmentType == 'prefecture':
      codes = [d.get('prefCode') for d in get_preflist()]
      codes = [f'{n:02}'+'000' for n in codes]
    elif governmentType == 'city':
      codes = [d.get('cityCode') for d in get_citylist()]

    # routes作成
    for code in codes:
      route = '/{}/{}/{}/{}/{}/'.format(governmentType,code,fieldId,menuId,cardId)
      res.append(route)

  return res

# %%
statistics_cards = get_statistics_cards()
routes = generate_routes(statistics_cards)
print(routes)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# GoogleDriveとGoogleCloudStorageに保存

# %%
def save_json(dic,path):
  
  # Google Driveへ保存
  drive_path = "drive/MyDrive/statistics-hyogo/{}".format(path)
  
  with open(drive_path, 'w') as f:
    json.dump(dic,f,ensure_ascii=False)
  
  # GoogleCloudStorage
  gcs_path = "statistics-hyogo/{}".format(path)
  with open(gcs_path, 'w') as f:
    json.dump(dic,f,ensure_ascii=False)

# %%
routes = generate_routes(statistics_cards)
path = "routes/routes.json"

save_json(routes,path)

# %% [markdown]
# ## sitemap.xml

# %% [markdown]
# サイトマップに反映させるroutesは兵庫県だけ

# %%
def generate_routes_sitemap(cards):

  res = []
  for card in cards:
    
    # 値の取得
    governmentType = card['governmentType']
    fieldId = card['fieldId']
    menuId = card['menuId']
    cardId = card['cardId']

    # 地域コード一覧作成
    codes = []
    if governmentType == 'prefecture':
      codes = ['28000']
    elif governmentType == 'city':
      citylist = list(filter(lambda x: x['prefCode'] == 28, get_citylist()))
      codes = [d.get('cityCode') for d in citylist]

    # routes作成
    for code in codes:
      route = '/{}/{}/{}/{}/{}/'.format(governmentType,code,fieldId,menuId,cardId)
      res.append(route)

  return res

# %%
statistics_cards = get_statistics_cards()
routes_sitemap = generate_routes_sitemap(statistics_cards)
print(routes_sitemap)
# Out:
# ['/prefecture/28000/population/population/total-population-prefecture/', '/prefecture/28000/population/marriage/unmarried-prefecture/', '/prefecture/28000/population/marriage/spouse-prefecture/', '/prefecture/28000/population/marriage/separated-prefecture/', '/prefecture/28000/population/death/standardized-mortality-prefecture/', '/prefecture/28000/population/household/household-prefecture/', '/prefecture/28000/population/household/single-mother-household-prefecture/', '/prefecture/28000/population/marriage/first-marriage-age-prefecture/', '/prefecture/28000/population/marriage/divorce-prefecture/', '/city/28100/population/population/total-population-city/', '/city/28101/population/population/total-population-city/', '/city/28102/population/population/total-population-city/', '/city/28105/population/population/total-population-city/', '/city/28106/population/population/total-population-city/', '/city/28107/population/population/total-population-city/', '/city/28108/population/population/total-population-city/', '/city/28109/population/population/total-population-city/', '/city/28110/population/population/total-population-city/', '/city/28111/population/population/total-population-city/', '/city/28201/population/population/total-population-city/', '/city/28202/population/population/total-population-city/', '/city/28203/population/population/total-population-city/', '/city/28204/population/population/total-population-city/', '/city/28205/population/population/total-population-city/', '/city/28206/population/population/total-population-city/', '/city/28207/population/population/total-population-city/', '/city/28208/population/population/total-population-city/', '/city/28209/population/population/total-population-city/', '/city/28210/population/population/total-population-city/', '/city/28212/population/population/total-population-city/', '/city/28213/population/population/total-population-city/', '/city/28214/population/population/total-population-city/', '/city/28215/population/population/total-population-city/', '/city/28216/population/population/total-population-city/', '/city/28217/population/population/total-population-city/', '/city/28218/population/population/total-population-city/', '/city/28219/population/population/total-population-city/', '/city/28220/population/population/total-population-city/', '/city/28221/population/population/total-population-city/', '/city/28222/population/population/total-population-city/', '/city/28223/population/population/total-population-city/', '/city/28224/population/population/total-population-city/', '/city/28225/population/population/total-population-city/', '/city/28226/population/population/total-population-city/', '/city/28227/population/population/total-population-city/', '/city/28228/population/population/total-population-city/', '/city/28229/population/population/total-population-city/', '/city/28301/population/population/total-population-city/', '/city/28365/population/population/total-population-city/', '/city/28381/population/population/total-population-city/', '/city/28382/population/population/total-population-city/', '/city/28442/population/population/total-population-city/', '/city/28443/population/population/total-population-city/', '/city/28446/population/population/total-population-city/', '/city/28464/population/population/total-population-city/', '/city/28481/population/population/total-population-city/', '/city/28501/population/population/total-population-city/', '/city/28585/population/population/total-population-city/', '/city/28586/population/population/total-population-city/', '/city/28100/population/household/single-mother-household-city/', '/city/28101/population/household/single-mother-household-city/', '/city/28102/population/household/single-mother-household-city/', '/city/28105/population/household/single-mother-household-city/', '/city/28106/population/household/single-mother-household-city/', '/city/28107/population/household/single-mother-household-city/ ...

# %% [markdown]
# sitemap.xmlを保存

# %%
import xml.etree.ElementTree as ET
import datetime
import tempfile

def generate_sitemap(path):

    urlset = ET.Element('urlset')
    urlset.set('xmlns', 'http://www.sitemaps.org/schemas/sitemap/0.9')
    urlset.set('xmlns:news', 'http://www.google.com/schemas/sitemap-news/0.9')
    urlset.set('xmlns:xhtml', 'http://www.w3.org/1999/xhtml')
    urlset.set('xmlns:mobile', 'http://www.google.com/schemas/sitemap-mobile/1.0')
    urlset.set('xmlns:image', 'http://www.google.com/schemas/sitemap-image/1.1')
    urlset.set('xmlns:video', 'http://www.google.com/schemas/sitemap-video/1.1')
    tree = ET.ElementTree(element=urlset)

    for route in routes():
        url = 'https://statistics-hyogo.com'+route
        updated = datetime.date.today()
        updated = updated.strftime('%Y-%m-%d')
        url_element = ET.SubElement(urlset, 'url')
        loc = ET.SubElement(url_element, 'loc')
        loc.text = url
        lastmod = ET.SubElement(url_element, 'lastmod')
        lastmod.text = updated
        
    _, temp_local_filename = tempfile.mkstemp()
    tree.write(temp_local_filename, encoding='utf-8', xml_declaration=True)
        
        
    # bucket = storage_client.bucket('statistics-hyogo')
    # blob = bucket.blob('sitemap.xml')
    # blob.upload_from_filename(temp_local_filename)
    # os.remove(temp_local_filename)

    return 'sitemap.xml generated !!'

# %% [markdown]
# # BigQueryへ保存

# %% [markdown]
# ライブラリのインストール

# %%
# !pip install --upgrade -q gspread

# %% [markdown]
# SpreadSheetの認証

# %%
from google.colab import auth
from google.auth import default
import gspread

auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# %% [markdown]
# worksheetを読み込んでDataFrameに変換

# %%
# シート情報の設定
id = "1mAv2gx9khNOty_ILu3aJjJz0uoRkARzwoaG4VBUSNG4"
sheet_name = 'statisticsCards'
worksheet = gc.open_by_key(id).worksheet(sheet_name)

# DataFrameに格納
dic = worksheet.get_all_records(head=1)
df = pd.DataFrame(dic)
df

# %% [markdown]
# pandas-gbqのインストール

# %%
# !pip install pandas-gbq

# %% [markdown]
# DataFrameをBigQueryへ保存

# %%
import pandas as pd

# プロジェクトの定義
project_id='primal-buttress-342908'
dataset_id = 'contents'
table_id='cards'

# データフレームの内容をBigQueryのテーブルに追加
df.to_gbq( f'{dataset_id}.{table_id}', project_id=project_id, if_exists="replace")
