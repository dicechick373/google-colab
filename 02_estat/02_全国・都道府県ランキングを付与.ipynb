# %% [markdown]
# # 実行環境の作成

# %% [markdown]
# ## Google Drive

# %% [markdown]
# Google Driveをマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## GCP認証

# %% [markdown]
# 下記コードでGCPに接続

# %%
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# # 地域設定

# %% [markdown]
# ## 関数

# %%
import json

def get_area(params={}):
  with open('drive/MyDrive/statistics-hyogo/resas/arealist.json') as j:
    areas = json.load(j)

    if not params:
      return areas

    else:
      for p in params.keys():
        areas = list(filter(lambda x: x[p] == params[p], areas))
      return areas

# %% [markdown]
# ## 都道府県コード一覧

# %%
def prefCodes():
  params = {
      'governmentType': 'prefecture',
  }
  
  area = get_area(params)
  return [d.get('areaCode') for d in area]

# %%
print(prefCodes())
# Out:
# ['01000', '02000', '03000', '04000', '05000', '06000', '07000', '08000', '09000', '10000', '11000', '12000', '13000', '14000', '15000', '16000', '17000', '18000', '19000', '20000', '21000', '22000', '23000', '24000', '25000', '26000', '27000', '28000', '29000', '30000', '31000', '32000', '33000', '34000', '35000', '36000', '37000', '38000', '39000', '40000', '41000', '42000', '43000', '44000', '45000', '46000', '47000']

# %% [markdown]
# ## 市区町村コード一覧

# %% [markdown]
# 政令指定都市の区は無視する

# %%
def cityCodes(prefCode=None):
  params = {'governmentType': 'city'}

  if prefCode is not None:
    params['prefCode'] = prefCode

  area = get_area(params)
  area = list(filter(lambda item : item['bigCityFlag'] != '1', area))
  return [d.get('areaCode') for d in area]

# %%
print(cityCodes())
# Out:
# ['01100', '01202', '01203', '01204', '01205', '01206', '01207', '01208', '01209', '01210', '01211', '01212', '01213', '01214', '01215', '01216', '01217', '01218', '01219', '01220', '01221', '01222', '01223', '01224', '01225', '01226', '01227', '01228', '01229', '01230', '01231', '01233', '01234', '01235', '01236', '01303', '01304', '01331', '01332', '01333', '01334', '01337', '01343', '01345', '01346', '01347', '01361', '01362', '01363', '01364', '01367', '01370', '01371', '01391', '01392', '01393', '01394', '01395', '01396', '01397', '01398', '01399', '01400', '01401', '01402', '01403', '01404', '01405', '01406', '01407', '01408', '01409', '01423', '01424', '01425', '01427', '01428', '01429', '01430', '01431', '01432', '01433', '01434', '01436', '01437', '01438', '01452', '01453', '01454', '01455', '01456', '01457', '01458', '01459', '01460', '01461', '01462', '01463', '01464', '01465', '01468', '01469', '01470', '01471', '01472', '01481', '01482', '01483', '01484', '01485', '01486', '01487', '01511', '01512', '01513', '01514', '01516', '01517', '01518', '01519', '01520', '01543', '01544', '01545', '01546', '01547', '01549', '01550', '01552', '01555', '01559', '01560', '01561', '01562', '01563', '01564', '01571', '01575', '01578', '01581', '01584', '01585', '01586', '01601', '01602', '01604', '01607', '01608', '01609', '01610', '01631', '01632', '01633', '01634', '01635', '01636', '01637', '01638', '01639', '01641', '01642', '01643', '01644', '01645', '01646', '01647', '01648', '01649', '01661', '01662', '01663', '01664', '01665', '01667', '01668', '01691', '01692', '01693', '01694', '01695', '01696', '01697', '01698', '01699', '01700', '02201', '02202', '02203', '02204', '02205', '02206', '02207', '02208', '02209', '02210', '02301', '02303', '02304', '02307', '02321', '02323', '02343', '02361', '02362', '02367', '02381', '02384', '02387', '02401', '02402', '02405', '02406', '02408', '02411', '02412', '02423', '02424', '02425', '02426', '02441', '02442', '02443', '02445', '02446', '02450', '03201', '03202', '03203', '03205', '03206', '03207', '03208', '03209', '03210', '03211', '03213', '03214', '03215', '03216', '03301', '03302', '03303', '03321', '03322', '03366', '03381', '03402', '03441', '03461', '03482', '03483', '03484', '03485', '03501', '03503', '03506', '03507', '03524', '04100', '04202', '04203', '04205', '04206', '04207', '04208', '04209', '04211', '04212', '04213', '04214', '04215', '04216', '04301', '04302', '04321', '04322', '04323', '04324', '04341', '04361', '04362', '04401', '04404', '04406', '04421', '04422', '04424', '04444', '04445', '04501', '04505', '04581', '04606', '05201', '05202', '05203', '05204', '05206', '05207', '05209', '05210', '05211', '05212', '05213', '05214', '05215', '05303', '05327', '05346', '05348', '05349', '05361', '05363', '05366', '05368', '05434', '05463', '05464', '06201', '06202', '06203', '06204', '06205', '06206', '06207', '06208', '06209', '06210', '06211', '06212', '06213', '06301', '06302', '06321', '06322', '06323', '06324', '06341', '06361', '06362', '06363', '06364', '06365', '06366', '06367', '06381', '06382', '06401', '06402', '06403', '06426', '06428', '06461', '07201', '07202', '07203', '07204', '07205', '07207', '07208', '07209', '07210', '07211', '07212', '07213', '07214', '07301', '07303', '07308', '07322', '07342', '07344', '07362', '07364', '07367', '07368', '07402', '07405', '07407', '07408', '07421', '07422', '07423', '07444', '07445', '07446', '07447', '07461', '07464', '07465', '07466', '07481', '07482', '07483', '07484', '07501', '07502', '07503', '07504', '07505', '07521', '07522', '07541', '07542', '07543', '07544', '07545', '07546', '07547', '07548', '07561', '07564', '08201', '08202', '08203', '08204', '08205', '08207', '08208', '08210', '08211', '08212', '08214', '08215', '08216', '08217', '08219', '08220', '08221', '08222', '08223', '08224', '08225', '08226', '08227', '08228', '08229', '08230', '08231', '08232', '08233', '08234', '08235', '08236', '08 ...

# %%
print(cityCodes(28))
# Out:
# ['28100', '28201', '28202', '28203', '28204', '28205', '28206', '28207', '28208', '28209', '28210', '28212', '28213', '28214', '28215', '28216', '28217', '28218', '28219', '28220', '28221', '28222', '28223', '28224', '28225', '28226', '28227', '28228', '28229', '28301', '28365', '28381', '28382', '28442', '28443', '28446', '28464', '28481', '28501', '28585', '28586']

# %% [markdown]
# # GBQからデータ取得

# %% [markdown]
# ## テーブル一覧

# %%
from google.cloud import bigquery

def estat_origin_tables():
  project_id='primal-buttress-342908'
  dataset_id = 'estat_origin'
  client = bigquery.Client(project=project_id)
  
  res = []
  for table in client.list_tables(dataset=dataset_id):
    res.append(table.table_id)
  
  return res

# %%
print(estat_origin_tables())
# Out:
# ['0000010101_A1101', '0000010101_A110101', '0000010101_A110102', '0000010101_A1102', '0000010101_A110201', '0000010101_A110202', '0000010101_A1201', '0000010101_A120101', '0000010101_A120102', '0000010101_A1202', '0000010101_A120201', '0000010101_A120202', '0000010101_A1203', '0000010101_A120301', '0000010101_A120302', '0000010101_A1204', '0000010101_A120401', '0000010101_A120402', '0000010101_A1205', '0000010101_A120501', '0000010101_A120502', '0000010101_A1206', '0000010101_A120601', '0000010101_A120602', '0000010101_A1207', '0000010101_A120701', '0000010101_A120702', '0000010101_A1208', '0000010101_A120801', '0000010101_A120802', '0000010101_A1209', '0000010101_A120901', '0000010101_A120902', '0000010101_A1210', '0000010101_A121001', '0000010101_A121002', '0000010101_A1211', '0000010101_A121101', '0000010101_A121102', '0000010101_A1212', '0000010101_A121201', '0000010101_A121202', '0000010101_A1213', '0000010101_A121301', '0000010101_A121302', '0000010101_A1214', '0000010101_A121401', '0000010101_A121402', '0000010101_A1215', '0000010101_A121501', '0000010101_A121502', '0000010101_A1216', '0000010101_A121601', '0000010101_A121602', '0000010101_A1217', '0000010101_A121701', '0000010101_A121702', '0000010101_A1218', '0000010101_A121801', '0000010101_A121802', '0000010101_A1219', '0000010101_A121901', '0000010101_A121902', '0000010101_A1220', '0000010101_A122001', '0000010101_A122002', '0000010101_A1221', '0000010101_A122101', '0000010101_A122102', '0000010101_A1231', '0000010101_A1301', '0000010101_A130101', '0000010101_A130102', '0000010101_A1302', '0000010101_A130201', '0000010101_A130202', '0000010101_A1303', '0000010101_A130301', '0000010101_A130302', '0000010101_A1304', '0000010101_A130401', '0000010101_A130402', '0000010101_A1305', '0000010101_A130501', '0000010101_A130502', '0000010101_A1306', '0000010101_A130601', '0000010101_A130602', '0000010101_A1401', '0000010101_A140101', '0000010101_A140102', '0000010101_A1402', '0000010101_A140201', '0000010101_A140202', '0000010101_A1403', '0000010101_A140301', '0000010101_A140302', '0000010101_A1404', '0000010101_A140401', '0000010101_A140402', '0000010101_A1405', '0000010101_A140501', '0000010101_A140502', '0000010101_A1406', '0000010101_A140601', '0000010101_A140602', '0000010101_A1407', '0000010101_A140701', '0000010101_A140702', '0000010101_A1408', '0000010101_A140801', '0000010101_A140802', '0000010101_A1409', '0000010101_A140901', '0000010101_A140902', '0000010101_A1410', '0000010101_A141001', '0000010101_A141002', '0000010101_A1411', '0000010101_A141101', '0000010101_A141102', '0000010101_A1412', '0000010101_A141201', '0000010101_A141202', '0000010101_A1413', '0000010101_A141301', '0000010101_A141302', '0000010101_A1414', '0000010101_A141401', '0000010101_A141402', '0000010101_A1415', '0000010101_A141501', '0000010101_A141502', '0000010101_A1416', '0000010101_A141601', '0000010101_A141602', '0000010101_A1417', '0000010101_A141701', '0000010101_A141702', '0000010101_A1418', '0000010101_A141801', '0000010101_A141802', '0000010101_A1419', '0000010101_A141901', '0000010101_A141902', '0000010101_A1420', '0000010101_A142001', '0000010101_A142002', '0000010101_A1501', '0000010101_A1502', '0000010101_A150201', '0000010101_A150202', '0000010101_A1503', '0000010101_A150301', '0000010101_A150302', '0000010101_A1504', '0000010101_A150401', '0000010101_A150402', '0000010101_A1505', '0000010101_A150501', '0000010101_A150502', '0000010101_A1506', '0000010101_A150601', '0000010101_A150602', '0000010101_A1507', '0000010101_A150701', '0000010101_A150702', '0000010101_A1508', '0000010101_A150801', '0000010101_A150802', '0000010101_A1509', '0000010101_A150901', '0000010101_A150902', '0000010101_A1510', '0000010101_A151001', '0000010101_A151002', '0000010101_A1511', '0000010101_A151101', '0000010101_A151102', '0000010101_A1512', '0000010101_A151201', '0000010101_A151202', '0000010101_A1513', '0000010101_A151301', '0000010101_A151302', '0000010101_A1514', '0000010101_A151401', '0000010101_A ...

# %% [markdown]
# ## テーブルのデータ取得

# %%
from google.cloud import bigquery

def get_estat_origin(table_id):
  project_id='primal-buttress-342908'
  dataset_id = 'estat_origin'
  client = bigquery.Client(project=project_id)

  query_string = f'SELECT * FROM {dataset_id}.{table_id}'
  
  df = client.query(query_string).result().to_dataframe()

  return df

# %%
table_id = '0000010101_A1101'
get_estat_origin(table_id).head()
# Out:
#   categoryCode areaCode    timeCode        value unit categoryName areaName  \
# 0        A1101    00000  1975100000  111939643.0    人          総人口       全国
# 1        A1101    00000  1976100000  113094000.0    人          総人口       全国
# 2        A1101    00000  1977100000  114165000.0    人          総人口       全国
# 3        A1101    00000  1978100000  115190000.0    人          総人口       全国
# 4        A1101    00000  1979100000  116155000.0    人          総人口       全国
#
#   timeName
# 0   1975年度
# 1   1976年度
# 2   1977年度
# 3   1978年度
# 4   1979年度

# %% [markdown]
# ## ランキング付与

# %%
import pandas as pd

def df_rank(df):
  
  # 整数値の判定
  values = list(set(df['value'].tolist()))
  isInt = list(map(lambda x: x.is_integer(), values)).count(True) >= len(values)/2
  if isInt:
    df = df.astype({'value': int})
  
  # 返却するDataFrameの定義
  df_res = pd.DataFrame(index=[], columns=[])

  # 都道府県（国内順位）
  df_pref = df[df.copy()['areaCode'].isin(prefCodes())]
  if len(df_pref) != 0:
    df_pref = df_rank_time(df_pref, type='japan')
    df_res = pd.concat([df_res, df_pref])
  
  # 市区町村（国内順位）
  df_city = df[df.copy()['areaCode'].isin(cityCodes())]
  if len(df_city) != 0:
    df_city = df_rank_time(df_city, type='japan')
    df_res = pd.concat([df_res, df_city])

  # 市区町村（県内順位）
  df_city = df[df.copy()['areaCode'].isin(cityCodes())]
  if len(df_city) != 0:
    df_city = df_rank_pref(df_city)
    df_res = pd.merge(df_res, df_city, on=['categoryCode','areaCode','timeCode'], how = 'left')

  return df_res

"""
都道府県ごとに分割してRankを付与する関数

"""
def df_rank_pref(df):
  df_res = pd.DataFrame(index=[], columns=[])

  for p in prefCodes():
    df_city = df[df.copy()['areaCode'].isin(cityCodes(int(p[:2])))]
    df_city = df_rank_time(df_city, type='pref')[['categoryCode','areaCode','timeCode','rankPref']]
    df_res = pd.concat([df_res, df_city])

  return df_res

"""
年次ごとに分割してRankを付与する関数

"""
def df_rank_time(df, type='japan'):
  df_res = pd.DataFrame(index=[], columns=[])

  times = sorted(list(set(df['timeCode'].tolist())))
  for time in times:
      df_time = df.copy().query(f'timeCode == "{time}"').reset_index()
      
      if type == 'japan':
        df_time['rankJapan'] = df_time.rank(ascending=False)['value'].astype(int)
      else:
        df_time['rankPref'] = df_time.rank(ascending=False)['value'].astype(int) 

      df_res = pd.concat([df_res, df_time])

  return df_res

# %%
table_id = '0000020201_A1101'
df = get_estat_origin(table_id)
df_rank(df).head()
# Out:
#    index categoryCode areaCode    timeCode    value unit categoryName  \
# 0      0        A1101    01100  1980100000  1401757    人          総人口
# 1      8        A1101    01202  1980100000   345165    人          総人口
# 2      9        A1101    01203  1980100000   180728    人          総人口
# 3     10        A1101    01204  1980100000   352619    人          総人口
# 4     11        A1101    01205  1980100000   150199    人          総人口
#
#   areaName timeName  rankJapan  rankPref
# 0  北海道 札幌市   1980年度          5         1
# 1  北海道 函館市   1980年度         59         3
# 2  北海道 小樽市   1980年度        133         5
# 3  北海道 旭川市   1980年度         56         2
# 4  北海道 室蘭市   1980年度        169         8

# %% [markdown]
# # GBQへ保存

# %% [markdown]
# ## 単体テスト

# %%
from google.cloud import bigquery

def save_gbq(table_id):
  
  # 元データ
  df = get_estat_origin(table_id)
  
  # ランキング付与
  df = df_rank(df)

  # プロジェクト設定
  project_id='primal-buttress-342908'
  dataset_id = 'estat_ranking'
  
  # スキーマ
  job_config = bigquery.LoadJobConfig(write_disposition='WRITE_TRUNCATE')
  
  # bigqueryへ保存
  client = bigquery.Client(project=project_id)
  job = client.load_table_from_dataframe(df, f'{dataset_id}.{table_id}', job_config=job_config).result()

  # 確認メッセージ  
  table = client.get_table(f'{dataset_id}.{table_id}') 
  print("{} 件のデータを「{}」に保存しました。".format(table.num_rows, table_id))

  return

# %%
table_id = '0000020201_A1101'
save_gbq(table_id)
# Out:
# 13928 件のデータを「0000020201_A1101」に保存しました。

# %% [markdown]
# ## 一括処理

# %%
from google.cloud import bigquery
from google.cloud.exceptions import NotFound

# データセットestat-originのテーブル一覧を取得
tables = estat_origin_tables()

# データセットestat-runkingに保存
project_id='primal-buttress-342908'
dataset_id = 'estat_ranking'
client = bigquery.Client(project=project_id)

for table_id in tables:
  try:
    client.get_table(f'{dataset_id}.{table_id}')  
    print("Table {} already exists.".format(table_id))
  except NotFound:
    save_gbq(table_id)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Table 0000010101_A1602081 already exists.
# Table 0000010101_A1602082 already exists.
# Table 0000010101_A1602091 already exists.
# Table 0000010101_A1602092 already exists.
# Table 0000010101_A1602101 already exists.
# Table 0000010101_A1602102 already exists.
# Table 0000010101_A1602111 already exists.
# Table 0000010101_A1602112 already exists.
# Table 0000010101_A1602121 already exists.
# Table 0000010101_A1602122 already exists.
# Table 0000010101_A1602131 already exists.
# Table 0000010101_A1602132 already exists.
# Table 0000010101_A1602141 already exists.
# Table 0000010101_A1602142 already exists.
# Table 0000010101_A1602151 already exists.
# Table 0000010101_A1602152 already exists.
# Table 0000010101_A1603001 already exists.
# Table 0000010101_A1603002 already exists.
# Table 0000010101_A1603031 already exists.
# Table 0000010101_A1603032 already exists.
# Table 0000010101_A1603041 already exists.
# Table 0000010101_A1603042 already exists.
# Table 0000010101_A1603051 already exists.
# Table 0000010101_A1603052 already exists.
# Table 0000010101_A1603061 already exists.
# Table 0000010101_A1603062 already exists.
# Table 0000010101_A1603071 already exists.
# Table 0000010101_A1603072 already exists.
# Table 0000010101_A1603081 already exists.
# Table 0000010101_A1603082 already exists.
# Table 0000010101_A1603091 already exists.
# Table 0000010101_A1603092 already exists.
# Table 0000010101_A1603101 already exists.
# Table 0000010101_A1603102 already exists.
# Table 0000010101_A1603111 already exists.
# Table 0000010101_A1603112 already exists.
# Table 0000010101_A1603121 already exists.
# Table 0000010101_A1603122 already exists.
# Table 0000010101_A1603131 already exists.
# Table 0000010101_A1603132 already exists.
# Table 0000010101_A1603141 already exists.
# Table 0000010101_A1603142 already exists.
# Table 0000010101_A1603151 already exists.
# Table 0000010101_A1603152 already exists.
# Table 0000010101_A1603201 already exists.
# Table 0000010101_A1603202 already exists.
# Table 0000010101_A1604001 already exists.
# Table 0000010101_A1604002 already exists.
# Table 0000010101_A1604011 already exists.
# Table 0000010101_A1604012 already exists.
# Table 0000010101_A1604021 already exists.
# Table 0000010101_A1604022 already exists.
# Table 0000010101_A1604031 already exists.
# Table 0000010101_A1604032 already exists.
# Table 0000010101_A1604041 already exists.
# Table 0000010101_A1604042 already exists.
# Table 0000010101_A1604051 already exists.
# Table 0000010101_A1604052 already exists.
# Table 0000010101_A1604061 already exists.
# Table 0000010101_A1604062 already exists.
# Table 0000010101_A1604071 already exists.
# Table 0000010101_A1604072 already exists.
# Table 0000010101_A1604081 already exists.
# Table 0000010101_A1604082 already exists.
# Table 0000010101_A1604091 already exists.
# Table 0000010101_A1604092 already exists.
# Table 0000010101_A1604101 already exists.
# Table 0000010101_A1604102 already exists.
# Table 0000010101_A1604111 already exists.
# Table 0000010101_A1604112 already exists.
# Table 0000010101_A1604121 already exists.
# Table 0000010101_A1604122 already exists.
# Table 0000010101_A1604131 already exists.
# Table 0000010101_A1604132 already exists.
# Table 0000010101_A1604141 already exists.
# Table 0000010101_A1604142 already exists.
# Table 0000010101_A1604151 already exists.
# Table 0000010101_A1604152 already exists.
# Table 0000010101_A1604201 already exists.
# Table 0000010101_A1604202 already exists.
# Table 0000010101_A1604301 already exists.
# Table 0000010101_A1604302 already exists.
# Table 0000010101_A161001 already exists.
# Table 0000010101_A1700 already exists.
# Table 0000010101_A170001 already exists.
# Table 0000010101_A170002 already exists.
# Table 0000010101_A1701 already exists.
# Table 0000010101_A170101 already exists.
# Table 0000010101_A170102 already exists.
# Table 0000010101_A1702 already exists.
# Table 0000010101_A170201 already exists.
# Table 0000010101_A170202 already exists.
# Table 0000010101_A1703 already exists.
# Table 0000010101_A170301 already exists.
# Table 0000010101_A170302 already exists.
# Table 0000010101_A1706 already exists.
# Table 0000010101_A170601 already exists.
# Table 0000010101_A170602 already exists.
# Table 0000010101_A1707 already exists.
# Table 0000010101_A170701 already exists.
# Table 0000010101_A170702 already exists.
# Table 0000010101_A1801 already exists.
# Table 0000010101_A180101 already exists.
# Table 0000010101_A180102 already exists.
# Table 0000010101_A1802 already exists.
# Table 0000010101_A191001 already exists.
# Table 0000010101_A191002 already exists.
# Table 0000010101_A191003 already exists.
# Table 0000010101_A191004 already exists.
# Table 0000010101_A191005 already exists.
# Table 0000010101_A191006 already exists.
# Table 0000010101_A2101 already exists.
# Table 0000010101_A210101 already exists.
# Table 0000010101_A210102 already exists.
# Table 0000010101_A2102 already exists.
# Table 0000010101_A2201 already exists.
# Table 0000010101_A2301 already exists.
# Table 0000010101_A3100 already exists.
# Table 0000010101_A3101 already exists.
# Table 0000010101_A310101 already exists.
# Table 0000010101_A310102 already exists.
# Table 0000010101_A310103 already exists.
# Table 0000010101_A310105 already exists.
# Table 0000010101_A3102 already exists.
# Table 0000010101_A310201 already exists.
# Table 0000010101_A3103 already exists.
# Table 0000010101_A310301 already exists.
# Table 0000010101_A3104 already exists.
# Table 0000010101_A310401 already exists.
# Table 0000010101_A310402 already exists.
# Table 0000010101_A3200 already exists.
# Table 0000010101_A3201 already exists.
# Table 0000010101_A320101 already exists.
# Table 0000010101_A320102 already exists.
# Table 0000010101_A320103 already exists.
# Table 0000010101_A320104 already exists.
# Table 0000010101_A3202 already exists.
# Table 0000010101_A3203 already exists.
# Table 0000010101_A3204 already exists.
# Table 0000010101_A4101 already exists.
# Table 0000010101_A410101 already exists.
# Table 0000010101_A410102 already exists.
# Table 0000010101_A410201 already exists.
# Table 0000010101_A410202 already exists.
# Table 0000010101_A410203 already exists.
# Table 0000010101_A410204 already exists.
# Table 0000010101_A410205 already exists.
# Table 0000010101_A410206 already exists.
# Table 0000010101_A410207 already exists.
# Table 0000010101_A410208 already exists.
# Table 0000010101_A410209 already exists.
# Table 0000010101_A4103 already exists.
# Table 0000010101_A4200 already exists.
# Table 0000010101_A420001 already exists.
# Table 0000010101_A420002 already exists.
# Table 0000010101_A4201 already exists.
# Table 0000010101_A420101 already exists.
# Table 0000010101_A420102 already exists.
# Table 0000010101_A4202 already exists.
# Table 0000010101_A420201 already exists.
# Table 0000010101_A420202 already exists.
# Table 0000010101_A4203 already exists.
# Table 0000010101_A420301 already exists.
# Table 0000010101_A420302 already exists.
# Table 0000010101_A4204 already exists.
# Table 0000010101_A420401 already exists.
# Table 0000010101_A420402 already exists.
# Table 0000010101_A4205 already exists.
# Table 0000010101_A420501 already exists.
# Table 0000010101_A420502 already exists.
# Table 0000010101_A4206 already exists.
# Table 0000010101_A420601 already exists.
# Table 0000010101_A420602 already exists.
# Table 0000010101_A4207 already exists.
# Table 0000010101_A420701 already exists.
# Table 0000010101_A420702 already exists.
# Table 0000010101_A4208 already exists.
# Table 0000010101_A420801 already exists.
# Table 0000010101_A420802 already exists.
# Table 0000010101_A4209 already exists.
# Table 0000010101_A420901 already exists.
# Table 0000010101_A420902 already exists.
# Table 0000010101_A4210 already exists.
# Table 0000010101_A421001 already exists.
# Table 0000010101_A421002 already exists.
# Table 0000010101_A4211 already exists.
# Table 0000010101_A421101 already exists.
# Table 0000010101_A421102 already exists.
# Table 0000010101_A4212 already exists.
# Table 0000010101_A421201 already exists.
# Table 0000010101_A421202 already exists.
# Table 0000010101_A4213 already exists.
# Table 0000010101_A421301 already exists.
# Table 0000010101_A421302 already exists.
# Table 0000010101_A4214 already exists.
# Table 0000010101_A421401 already exists.
# Table 0000010101_A421402 already exists.
# Table 0000010101_A4215 already exists.
# Table 0000010101_A421501 already exists.
# Table 0000010101_A421502 already exists.
# Table 0000010101_A4216 already exists.
# Table 0000010101_A421601 already exists.
# Table 0000010101_A421602 already exists.
# Table 0000010101_A4217 already exists.
# Table 0000010101_A421701 already exists.
# Table 0000010101_A421702 already exists.
# Table 0000010101_A4218 already exists.
# Table 0000010101_A421801 already exists.
# Table 0000010101_A421802 already exists.
# Table 0000010101_A4219 already exists.
# Table 0000010101_A421901 already exists.
# Table 0000010101_A421902 already exists.
# Table 0000010101_A4220 already exists.
# Table 0000010101_A422001 already exists.
# Table 0000010101_A422002 already exists.
# Table 0000010101_A4221 already exists.
# Table 0000010101_A422101 already exists.
# Table 0000010101_A422102 already exists.
# Table 0000010101_A4231 already exists.
# Table 0000010101_A423101 already exists.
# Table 0000010101_A423102 already exists.
# Table 0000010101_A424001 already exists.
# Table 0000010101_A424002 already exists.
# Table 0000010101_A4270 already exists.
# Table 0000010101_A427001 already exists.
# Table 0000010101_A4271 already exists.
# Table 0000010101_A4272 already exists.
# Table 0000010101_A4280 already exists.
# Table 0000010101_A4281 already exists.
# Table 0000010101_A4301 already exists.
# Table 0000010101_A5101 already exists.
# Table 0000010101_A510101 already exists.
# Table 0000010101_A510102 already exists.
# Table 0000010101_A5102 already exists.
# Table 0000010101_A510201 already exists.
# Table 0000010101_A510202 already exists.
# Table 0000010101_A5103 already exists.
# Table 0000010101_A510301 already exists.
# Table 0000010101_A510302 already exists.
# Table 0000010101_A5104 already exists.
# Table 0000010101_A510401 already exists.
# Table 0000010101_A510402 already exists.
# Table 0000010101_A5201 already exists.
# Table 0000010101_A520101 already exists.
# Table 0000010101_A520102 already exists.
# Table 0000010101_A5202 already exists.
# Table 0000010101_A520201 already exists.
# Table 0000010101_A520202 already exists.
# Table 0000010101_A5301 already exists.
# Table 0000010101_A6101 already exists.
# Table 0000010101_A610101 already exists.
# Table 0000010101_A610102 already exists.
# Table 0000010101_A6102 already exists.
# Table 0000010101_A610201 already exists.
# Table 0000010101_A610202 already exists.
# Table 0000010101_A6103 already exists.
# Table 0000010101_A610301 already exists.
# Table 0000010101_A610302 already exists.
# Table 0000010101_A6104 already exists.
# Table 0000010101_A610401 already exists.
# Table 0000010101_A610402 already exists.
# Table 0000010101_A6105 already exists.
# Table 0000010101_A610501 already exists.
# Table 0000010101_A610502 already exists.
# Table 0000010101_A6106 already exists.
# Table 0000010101_A610601 already exists.
# Table 0000010101_A610602 already exists.
# Table 0000010101_A6107 already exists.
# Table 0000010101_A610701 already exists.
# Table 0000010101_A610702 already exists.
# Table 0000010101_A6108 already exists.
# Table 0000010101_A7101 already exists.
# Table 0000010101_A710101 already exists.
# Table 0000010101_A710102 already exists.
# Table 0000010101_A710201 already exists.
# Table 0000010101_A710202 already exists.
# Table 0000010101_A710211 already exists.
# Table 0000010101_A7103 already exists.
# Table 0000010101_A810101 already exists.
# Table 0000010101_A810102 already exists.
# Table 0000010101_A810103 already exists.
# Table 0000010101_A810104 already exists.
# Table 0000010101_A810105 already exists.
# Table 0000010101_A8111 already exists.
# Table 0000010101_A811101 already exists.
# Table 0000010101_A811102 already exists.
# Table 0000010101_A811103 already exists.
# Table 0000010101_A811104 already exists.
# Table 0000010101_A811105 already exists.
# Table 0000010101_A8112 already exists.
# Table 0000010101_A811201 already exists.
# Table 0000010101_A811202 already exists.
# Table 0000010101_A811203 already exists.
# Table 0000010101_A811204 already exists.
# Table 0000010101_A811205 already exists.
# Table 0000010101_A8201 already exists.
# Table 0000010101_A8202 already exists.
# Table 0000010101_A8301 already exists.
# Table 0000010101_A830101 already exists.
# Table 0000010101_A830102 already exists.
# Table 0000010101_A8303 already exists.
# Table 0000010101_A830301 already exists.
# Table 0000010101_A830302 already exists.
# Table 0000010101_A8401 already exists.
# Table 0000010101_A840101 already exists.
# Table 0000010101_A840102 already exists.
# Table 0000010101_A840103 already exists.
# Table 0000010101_A840201 already exists.
# Table 0000010101_A840202 already exists.
# Table 0000010101_A840203 already exists.
# Table 0000010101_A840204 already exists.
# Table 0000010101_A840205 already exists.
# Table 0000010101_A8501 already exists.
# Table 0000010101_A850101 already exists.
# Table 0000010101_A850102 already exists.
# Table 0000010101_A850103 already exists.
# Table 0000010101_A850201 already exists.
# Table 0000010101_A850202 already exists.
# Table 0000010101_A850203 already exists.
# Table 0000010101_A850204 already exists.
# Table 0000010101_A850205 already exists.
# Table 0000010101_A9101 already exists.
# Table 0000010101_A9111 already exists.
# Table 0000010101_A9112 already exists.
# Table 0000010101_A9201 already exists.
# Table 0000010102_B1101 already exists.
# Table 0000010102_B1102 already exists.
# Table 0000010102_B1103 already exists.
# Table 0000010102_B1104 already exists.
# Table 0000010102_B1105 already exists.
# Table 0000010102_B1106 already exists.
# Table 0000010102_B1107 already exists.
# Table 0000010102_B1108 already exists.
# Table 0000010102_B1201 already exists.
# Table 0000010102_B120101 already exists.
# Table 0000010102_B120102 already exists.
# Table 0000010102_B120103 already exists.
# Table 0000010102_B120104 already exists.
# Table 0000010102_B120105 already exists.
# Table 0000010102_B120106 already exists.
# Table 0000010102_B120107 already exists.
# Table 0000010102_B1303 already exists.
# Table 0000010102_B2101 already exists.
# Table 0000010102_B2102 already exists.
# Table 0000010102_B2103 already exists.
# Table 0000010102_B2104 already exists.
# Table 0000010102_B2105 already exists.
# Table 0000010102_B3101 already exists.
# Table 0000010102_B3102 already exists.
# Table 0000010102_B3103 already exists.
# Table 0000010102_B3104 already exists.
# Table 0000010102_B3105 already exists.
# Table 0000010102_B3106 already exists.
# Table 0000010102_B3107 already exists.
# Table 0000010102_B3108 already exists.
# Table 0000010102_B3109 already exists.
# Table 0000010102_B3110 already exists.
# Table 0000010102_B4101 already exists.
# Table 0000010102_B4102 already exists.
# Table 0000010102_B4103 already exists.
# Table 0000010102_B4104 already exists.
# Table 0000010102_B4105 already exists.
# Table 0000010102_B4106 already exists.
# Table 0000010102_B4107 already exists.
# Table 0000010102_B4108 already exists.
# Table 0000010102_B4109 already exists.
# Table 0000010102_B4110 already exists.
# Table 0000010102_B4111 already exists.
# Table 0000010102_B4112 already exists.
# Table 0000010103_C1101 already exists.
# Table 0000010103_C1102 already exists.
# Table 0000010103_C110201 already exists.
# Table 0000010103_C110202 already exists.
# Table 0000010103_C110203 already exists.
# Table 0000010103_C110204 already exists.
# Table 0000010103_C110205 already exists.
# Table 0000010103_C110206 already exists.
# Table 0000010103_C110207 already exists.
# Table 0000010103_C110208 already exists.
# Table 0000010103_C110209 already exists.
# Table 0000010103_C110210 already exists.
# Table 0000010103_C110211 already exists.
# Table 0000010103_C1102121 already exists.
# Table 0000010103_C1102122 already exists.
# Table 0000010103_C110213 already exists.
# Table 0000010103_C1103 already exists.
# Table 0000010103_C110301 already exists.
# Table 0000010103_C110302 already exists.
# Table 0000010103_C110303 already exists.
# Table 0000010103_C1104 already exists.
# Table 0000010103_C1105 already exists.
# Table 0000010103_C1106 already exists.
# Table 0000010103_C1107 already exists.
# Table 0000010103_C1111 already exists.
# Table 0000010103_C111201 already exists.
# Table 0000010103_C111202 already exists.
# Table 0000010103_C111203 already exists.
# Table 0000010103_C111204 already exists.
# Table 0000010103_C111205 already exists.
# Table 0000010103_C111206 already exists.
# Table 0000010103_C111207 already exists.
# Table 0000010103_C111208 already exists.
# Table 0000010103_C111209 already exists.
# Table 0000010103_C111210 already exists.
# Table 0000010103_C111211 already exists.
# Table 0000010103_C1112121 already exists.
# Table 0000010103_C1112122 already exists.
# Table 0000010103_C111213 already exists.
# Table 0000010103_C111214 already exists.
# Table 0000010103_C111215 already exists.
# Table 0000010103_C111216 already exists.
# Table 0000010103_C111217 already exists.
# Table 0000010103_C111218 already exists.
# Table 0000010103_C1115 already exists.
# Table 0000010103_C1116 already exists.
# Table 0000010103_C1117 already exists.
# Table 0000010103_C1201 already exists.
# Table 0000010103_C120101 already exists.
# Table 0000010103_C120110 already exists.
# Table 0000010103_C120120 already exists.
# Table 0000010103_C120130 already exists.
# Table 0000010103_C1202 already exists.
# Table 0000010103_C120201 already exists.
# Table 0000010103_C1203 already exists.
# Table 0000010103_C1204 already exists.
# Table 0000010103_C1211 already exists.
# Table 0000010103_C121101 already exists.
# Table 0000010103_C1212 already exists.
# Table 0000010103_C121201 already exists.
# Table 0000010103_C1213 already exists.
# Table 0000010103_C1214 already exists.
# Table 0000010103_C1301 already exists.
# Table 0000010103_C1302 already exists.
# Table 0000010103_C1303 already exists.
# Table 0000010103_C130301 already exists.
# Table 0000010103_C130302 already exists.
# Table 0000010103_C1304 already exists.
# Table 0000010103_C1305 already exists.
# Table 0000010103_C1306 already exists.
# Table 0000010103_C1307 already exists.
# Table 0000010103_C1308 already exists.
# Table 0000010103_C1311 already exists.
# Table 0000010103_C1312 already exists.
# Table 0000010103_C1313 already exists.
# Table 0000010103_C131301 already exists.
# Table 0000010103_C131302 already exists.
# Table 0000010103_C1314 already exists.
# Table 0000010103_C1315 already exists.
# Table 0000010103_C1316 already exists.
# Table 0000010103_C1317 already exists.
# Table 0000010103_C1318 already exists.
# Table 0000010103_C1401 already exists.
# Table 0000010103_C1402 already exists.
# Table 0000010103_C1403 already exists.
# Table 0000010103_C140301 already exists.
# Table 0000010103_C140302 already exists.
# Table 0000010103_C1404 already exists.
# Table 0000010103_C1405 already exists.
# Table 0000010103_C1406 already exists.
# Table 0000010103_C1407 already exists.
# Table 0000010103_C1408 already exists.
# Table 0000010103_C1411 already exists.
# Table 0000010103_C1412 already exists.
# Table 0000010103_C1413 already exists.
# Table 0000010103_C141301 already exists.
# Table 0000010103_C141302 already exists.
# Table 0000010103_C1416 already exists.
# Table 0000010103_C1417 already exists.
# Table 0000010103_C2101 already exists.
# Table 0000010103_C2102 already exists.
# Table 0000010103_C210220 already exists.
# Table 0000010103_C210230 already exists.
# Table 0000010103_C210231 already exists.
# Table 0000010103_C210232 already exists.
# Table 0000010103_C2103 already exists.
# Table 0000010103_C210301 already exists.
# Table 0000010103_C210302 already exists.
# Table 0000010103_C210303 already exists.
# Table 0000010103_C2104 already exists.
# Table 0000010103_C2105 already exists.
# Table 0000010103_C2106 already exists.
# Table 0000010103_C2107 already exists.
# Table 0000010103_C210701 already exists.
# Table 0000010103_C210702 already exists.
# Table 0000010103_C210703 already exists.
# Table 0000010103_C210704 already exists.
# Table 0000010103_C210705 already exists.
# Table 0000010103_C210706 already exists.
# Table 0000010103_C210707 already exists.
# Table 0000010103_C210708 already exists.
# Table 0000010103_C210709 already exists.
# Table 0000010103_C210710 already exists.
# Table 0000010103_C210711 already exists.
# Table 0000010103_C210712 already exists.
# Table 0000010103_C210713 already exists.
# Table 0000010103_C210714 already exists.
# Table 0000010103_C210715 already exists.
# Table 0000010103_C210716 already exists.
# Table 0000010103_C210717 already exists.
# Table 0000010103_C210718 already exists.
# Table 0000010103_C210719 already exists.
# Table 0000010103_C210720 already exists.
# Table 0000010103_C210721 already exists.
# Table 0000010103_C210722 already exists.
# Table 0000010103_C210723 already exists.
# Table 0000010103_C210724 already exists.
# Table 0000010103_C210725 already exists.
# Table 0000010103_C2108 already exists.
# Table 0000010103_C210801 already exists.
# Table 0000010103_C210802 already exists.
# Table 0000010103_C210803 already exists.
# Table 0000010103_C210804 already exists.
# Table 0000010103_C210805 already exists.
# Table 0000010103_C210806 already exists.
# Table 0000010103_C210807 already exists.
# Table 0000010103_C210820 already exists.
# Table 0000010103_C210821 already exists.
# Table 0000010103_C210822 already exists.
# Table 0000010103_C210823 already exists.
# Table 0000010103_C210831 already exists.
# Table 0000010103_C210832 already exists.
# Table 0000010103_C210833 already exists.
# Table 0000010103_C210834 already exists.
# Table 0000010103_C210835 already exists.
# Table 0000010103_C210836 already exists.
# Table 0000010103_C210837 already exists.
# Table 0000010103_C210838 already exists.
# Table 0000010103_C210839 already exists.
# Table 0000010103_C210840 already exists.
# Table 0000010103_C210841 already exists.
# Table 0000010103_C210842 already exists.
# Table 0000010103_C210843 already exists.
# Table 0000010103_C210844 already exists.
# Table 0000010103_C210845 already exists.
# Table 0000010103_C210846 already exists.
# Table 0000010103_C210847 already exists.
# Table 0000010103_C210848 already exists.
# Table 0000010103_C210849 already exists.
# Table 0000010103_C210850 already exists.
# Table 0000010103_C210851 already exists.
# Table 0000010103_C210852 already exists.
# Table 0000010103_C2109 already exists.
# Table 0000010103_C210901 already exists.
# Table 0000010103_C210902 already exists.
# Table 0000010103_C210903 already exists.
# Table 0000010103_C210904 already exists.
# Table 0000010103_C2110 already exists.
# Table 0000010103_C2111 already exists.
# Table 0000010103_C2112 already exists.
# Table 0000010103_C2201 already exists.
# Table 0000010103_C2202 already exists.
# Table 0000010103_C220220 already exists.
# Table 0000010103_C220230 already exists.
# Table 0000010103_C220231 already exists.
# Table 0000010103_C220232 already exists.
# Table 0000010103_C2203 already exists.
# Table 0000010103_C220301 already exists.
# Table 0000010103_C220302 already exists.
# Table 0000010103_C220303 already exists.
# Table 0000010103_C2204 already exists.
# Table 0000010103_C2205 already exists.
# Table 0000010103_C2206 already exists.
# Table 0000010103_C2207 already exists.
# Table 0000010103_C220701 already exists.
# Table 0000010103_C220702 already exists.
# Table 0000010103_C220703 already exists.
# Table 0000010103_C220704 already exists.
# Table 0000010103_C220705 already exists.
# Table 0000010103_C220706 already exists.
# Table 0000010103_C220707 already exists.
# Table 0000010103_C220708 already exists.
# Table 0000010103_C220709 already exists.
# Table 0000010103_C220710 already exists.
# Table 0000010103_C220711 already exists.
# Table 0000010103_C220712 already exists.
# Table 0000010103_C220713 already exists.
# Table 0000010103_C220714 already exists.
# Table 0000010103_C220715 already exists.
# Table 0000010103_C220716 already exists.
# Table 0000010103_C220717 already exists.
# Table 0000010103_C220718 already exists.
# Table 0000010103_C220719 already exists.
# Table 0000010103_C220720 already exists.
# Table 0000010103_C220721 already exists.
# Table 0000010103_C220722 already exists.
# Table 0000010103_C220723 already exists.
# Table 0000010103_C220724 already exists.
# Table 0000010103_C220725 already exists.
# Table 0000010103_C2208 already exists.
# Table 0000010103_C220801 already exists.
# Table 0000010103_C220802 already exists.
# Table 0000010103_C220803 already exists.
# Table 0000010103_C220804 already exists.
# Table 0000010103_C220805 already exists.
# Table 0000010103_C220806 already exists.
# Table 0000010103_C220807 already exists.
# Table 0000010103_C220820 already exists.
# Table 0000010103_C220821 already exists.
# Table 0000010103_C220822 already exists.
# Table 0000010103_C220823 already exists.
# Table 0000010103_C220831 already exists.
# Table 0000010103_C220832 already exists.
# Table 0000010103_C220833 already exists.
# Table 0000010103_C220834 already exists.
# Table 0000010103_C220835 already exists.
# Table 0000010103_C220836 already exists.
# Table 0000010103_C220837 already exists.
# Table 0000010103_C220838 already exists.
# Table 0000010103_C220839 already exists.
# Table 0000010103_C220840 already exists.
# Table 0000010103_C220841 already exists.
# Table 0000010103_C220842 already exists.
# Table 0000010103_C220843 already exists.
# Table 0000010103_C220844 already exists.
# Table 0000010103_C220845 already exists.
# Table 0000010103_C220846 already exists.
# Table 0000010103_C220847 already exists.
# Table 0000010103_C220848 already exists.
# Table 0000010103_C220849 already exists.
# Table 0000010103_C220850 already exists.
# Table 0000010103_C220851 already exists.
# Table 0000010103_C220852 already exists.
# Table 0000010103_C2209 already exists.
# Table 0000010103_C220901 already exists.
# Table 0000010103_C220902 already exists.
# Table 0000010103_C220903 already exists.
# Table 0000010103_C220904 already exists.
# Table 0000010103_C2210 already exists.
# Table 0000010103_C2211 already exists.
# Table 0000010103_C2212 already exists.
# Table 0000010103_C3101 already exists.
# Table 0000010103_C3102 already exists.
# Table 0000010103_C310201 already exists.
# Table 0000010103_C310202 already exists.
# Table 0000010103_C310211 already exists.
# Table 0000010103_C310212 already exists.
# Table 0000010103_C310234 already exists.
# Table 0000010103_C310235 already exists.
# Table 0000010103_C310236 already exists.
# Table 0000010103_C310237 already exists.
# Table 0000010103_C310238 already exists.
# Table 0000010103_C310239 already exists.
# Table 0000010103_C310240 already exists.
# Table 0000010103_C310241 already exists.
# Table 0000010103_C310242 already exists.
# Table 0000010103_C310410 already exists.
# Table 0000010103_C310411 already exists.
# Table 0000010103_C310412 already exists.
# Table 0000010103_C310510 already exists.
# Table 0000010103_C310511 already exists.
# Table 0000010103_C310610 already exists.
# Table 0000010103_C310611 already exists.
# Table 0000010103_C310612 already exists.
# Table 0000010103_C310614 already exists.
# Table 0000010103_C3107 already exists.
# Table 0000010103_C310701 already exists.
# Table 0000010103_C310702 already exists.
# Table 0000010103_C310703 already exists.
# Table 0000010103_C310704 already exists.
# Table 0000010103_C310705 already exists.
# Table 0000010103_C3108 already exists.
# Table 0000010103_C3109 already exists.
# Table 0000010103_C3110 already exists.
# Table 0000010103_C3111 already exists.
# Table 0000010103_C3112 already exists.
# Table 0000010103_C3114 already exists.
# Table 0000010103_C3120 already exists.
# Table 0000010103_C312001 already exists.
# Table 0000010103_C312002 already exists.
# Table 0000010103_C312003 already exists.
# Table 0000010103_C31201 already exists.
# Table 0000010103_C3121 already exists.
# Table 0000010103_C312101 already exists.
# Table 0000010103_C312102 already exists.
# Table 0000010103_C3122 already exists.
# Table 0000010103_C312201 already exists.
# Table 0000010103_C312202 already exists.
# Table 0000010103_C312301 already exists.
# Table 0000010103_C3125 already exists.
# Table 0000010103_C312601 already exists.
# Table 0000010103_C312602 already exists.
# Table 0000010103_C312701 already exists.
# Table 0000010103_C312702 already exists.
# Table 0000010103_C3301 already exists.
# Table 0000010103_C3302 already exists.
# Table 0000010103_C3303 already exists.
# Table 0000010103_C3304 already exists.
# Table 0000010103_C330401 already exists.
# Table 0000010103_C330402 already exists.
# Table 0000010103_C330403 already exists.
# Table 0000010103_C330410 already exists.
# Table 0000010103_C330411 already exists.
# Table 0000010103_C330412 already exists.
# Table 0000010103_C330413 already exists.
# Table 0000010103_C330420 already exists.
# Table 0000010103_C330421 already exists.
# Table 0000010103_C330422 already exists.
# Table 0000010103_C330423 already exists.
# Table 0000010103_C3305 already exists.
# Table 0000010103_C330501 already exists.
# Table 0000010103_C330502 already exists.
# Table 0000010103_C330503 already exists.
# Table 0000010103_C3306 already exists.
# Table 0000010103_C3307 already exists.
# Table 0000010103_C3308 already exists.
# Table 0000010103_C3401 already exists.
# Table 0000010103_C3402 already exists.
# Table 0000010103_C3403 already exists.
# Table 0000010103_C3404 already exists.
# Table 0000010103_C3405 already exists.
# Table 0000010103_C3406 already exists.
# Table 0000010103_C340601 already exists.
# Table 0000010103_C340602 already exists.
# Table 0000010103_C3501 already exists.
# Table 0000010103_C350101 already exists.
# Table 0000010103_C350102 already exists.
# Table 0000010103_C3502 already exists.
# Table 0000010103_C350201 already exists.
# Table 0000010103_C350202 already exists.
# Table 0000010103_C3503 already exists.
# Table 0000010103_C350301 already exists.
# Table 0000010103_C350302 already exists.
# Table 0000010103_C3505 already exists.
# Table 0000010103_C350501 already exists.
# Table 0000010103_C350502 already exists.
# Table 0000010103_C3601 already exists.
# Table 0000010103_C360111 already exists.
# Table 0000010103_C360120 already exists.
# Table 0000010103_C360211 already exists.
# Table 0000010103_C360311 already exists.
# Table 0000010103_C3702 already exists.
# Table 0000010103_C370201 already exists.
# Table 0000010103_C3704 already exists.
# Table 0000010103_C3705 already exists.
# Table 0000010103_C3706 already exists.
# Table 0000010103_C370601 already exists.
# Table 0000010103_C3707 already exists.
# Table 0000010103_C370701 already exists.
# Table 0000010103_C3708 already exists.
# Table 0000010103_C3709 already exists.
# Table 0000010103_C3710 already exists.
# Table 0000010103_C3711 already exists.
# Table 0000010103_C3712 already exists.
# Table 0000010103_C3713 already exists.
# Table 0000010103_C3714 already exists.
# Table 0000010103_C3715 already exists.
# Table 0000010103_C3801 already exists.
# Table 0000010103_C3802 already exists.
# Table 0000010103_C3803 already exists.
# Table 0000010103_C3804 already exists.
# Table 0000010103_C3805 already exists.
# Table 0000010103_C5101 already exists.
# Table 0000010103_C5102 already exists.
# Table 0000010103_C5103 already exists.
# Table 0000010103_C5104 already exists.
# Table 0000010103_C5105 already exists.
# Table 0000010103_C5106 already exists.
# Table 0000010103_C5107 already exists.
# Table 0000010103_C5108 already exists.
# Table 0000010103_C5109 already exists.
# Table 0000010103_C5110 already exists.
# Table 0000010103_C5111 already exists.
# Table 0000010103_C5112 already exists.
# Table 0000010103_C5113 already exists.
# Table 0000010103_C5114 already exists.
# Table 0000010103_C5115 already exists.
# Table 0000010103_C5116 already exists.
# Table 0000010103_C5117 already exists.
# Table 0000010103_C5118 already exists.
# Table 0000010103_C5119 already exists.
# Table 0000010103_C5120 already exists.
# Table 0000010103_C5121 already exists.
# Table 0000010103_C5122 already exists.
# Table 0000010103_C5123 already exists.
# Table 0000010103_C5124 already exists.
# Table 0000010103_C5125 already exists.
# Table 0000010103_C5126 already exists.
# Table 0000010103_C5127 already exists.
# Table 0000010103_C5128 already exists.
# Table 0000010103_C5201 already exists.
# Table 0000010103_C5202 already exists.
# Table 0000010103_C5203 already exists.
# Table 0000010103_C5205 already exists.
# Table 0000010103_C5206 already exists.
# Table 0000010103_C5207 already exists.
# Table 0000010103_C5208 already exists.
# Table 0000010103_C5209 already exists.
# Table 0000010103_C5210 already exists.
# Table 0000010103_C5211 already exists.
# Table 0000010103_C5212 already exists.
# Table 0000010103_C5213 already exists.
# Table 0000010103_C5214 already exists.
# Table 0000010103_C5301 already exists.
# Table 0000010103_C5302 already exists.
# Table 0000010103_C5303 already exists.
# Table 0000010103_C5401 already exists.
# Table 0000010103_C5403 already exists.
# Table 0000010103_C5405 already exists.
# Table 0000010103_C5501 already exists.
# Table 0000010103_C5503 already exists.
# Table 0000010103_C5505 already exists.
# Table 0000010103_C5601 already exists.
# Table 0000010103_C5602 already exists.
# Table 0000010103_C5603 already exists.
# Table 0000010103_C5701 already exists.
# Table 0000010103_C5702 already exists.
# Table 0000010103_C5703 already exists.
# Table 0000010103_C5704 already exists.
# Table 0000010103_C5705 already exists.
# Table 0000010103_C5706 already exists.
# Table 0000010103_C5707 already exists.
# Table 0000010103_C5708 already exists.
# Table 0000010103_C5709 already exists.
# Table 0000010103_C5710 already exists.
# Table 0000010103_C5711 already exists.
# Table 0000010103_C5712 already exists.
# Table 0000010103_C6101 already exists.
# Table 0000010103_C610101 already exists.
# Table 0000010103_C610102 already exists.
# Table 0000010103_C610103 already exists.
# Table 0000010103_C610104 already exists.
# Table 0000010103_C610105 already exists.
# Table 0000010103_C610106 already exists.
# Table 0000010103_C610107 already exists.
# Table 0000010103_C610108 already exists.
# Table 0000010103_C610109 already exists.
# Table 0000010103_C610110 already exists.
# Table 0000010103_C610111 already exists.
# Table 0000010103_C610112 already exists.
# Table 0000010103_C610113 already exists.
# Table 0000010103_C610114 already exists.
# Table 0000010103_C610115 already exists.
# Table 0000010103_C610116 already exists.
# Table 0000010103_C610117 already exists.
# Table 0000010103_C610118 already exists.
# Table 0000010103_C610119 already exists.
# Table 0000010103_C610120 already exists.
# Table 0000010103_C610121 already exists.
# Table 0000010103_C610122 already exists.
# Table 0000010103_C6201 already exists.
# Table 0000010103_C620101 already exists.
# Table 0000010103_C620102 already exists.
# Table 0000010103_C620103 already exists.
# Table 0000010103_C620104 already exists.
# Table 0000010103_C620105 already exists.
# Table 0000010103_C620106 already exists.
# Table 0000010103_C620107 already exists.
# Table 0000010103_C620108 already exists.
# Table 0000010103_C620109 already exists.
# Table 0000010103_C620110 already exists.
# Table 0000010103_C620111 already exists.
# Table 0000010103_C620112 already exists.
# Table 0000010103_C620113 already exists.
# Table 0000010103_C620114 already exists.
# Table 0000010103_C620115 already exists.
# Table 0000010103_C620116 already exists.
# Table 0000010103_C620117 already exists.
# Table 0000010103_C620118 already exists.
# Table 0000010103_C620119 already exists.
# Table 0000010103_C620120 already exists.
# Table 0000010103_C620121 already exists.
# Table 0000010103_C620122 already exists.
# Table 0000010103_C6301 already exists.
# Table 0000010103_C630101 already exists.
# Table 0000010103_C630102 already exists.
# Table 0000010103_C630103 already exists.
# Table 0000010103_C630104 already exists.
# Table 0000010103_C630105 already exists.
# Table 0000010103_C630106 already exists.
# Table 0000010103_C630107 already exists.
# Table 0000010103_C630108 already exists.
# Table 0000010104_D110101 already exists.
# Table 0000010104_D110102 already exists.
# Table 0000010104_D110103 already exists.
# Table 0000010104_D1201 already exists.
# Table 0000010104_D1202 already exists.
# Table 0000010104_D1203 already exists.
# Table 0000010104_D1204 already exists.
# Table 0000010104_D1205 already exists.
# Table 0000010104_D1206 already exists.
# Table 0000010104_D1210 already exists.
# Table 0000010104_D1211 already exists.
# Table 0000010104_D1212 already exists.
# Table 0000010104_D2101 already exists.
# Table 0000010104_D2102 already exists.
# Table 0000010104_D2103 already exists.
# Table 0000010104_D2105 already exists.
# Table 0000010104_D2106 already exists.
# Table 0000010104_D2109 already exists.
# Table 0000010104_D2110 already exists.
# Table 0000010104_D2111 already exists.
# Table 0000010104_D2112 already exists.
# Table 0000010104_D2205 already exists.
# Table 0000010104_D2206 already exists.
# Table 0000010104_D2209 already exists.
# Table 0000010104_D2210 already exists.
# Table 0000010104_D3101 already exists.
# Table 0000010104_D310101 already exists.
# Table 0000010104_D310102 already exists.
# Table 0000010104_D310103 already exists.
# Table 0000010104_D310104 already exists.
# Table 0000010104_D310105 already exists.
# Table 0000010104_D310106 already exists.
# Table 0000010104_D310107 already exists.
# Table 0000010104_D310108 already exists.
# Table 0000010104_D310110 already exists.
# Table 0000010104_D310111 already exists.
# Table 0000010104_D310112 already exists.
# Table 0000010104_D310113 already exists.
# Table 0000010104_D310114 already exists.
# Table 0000010104_D310115 already exists.
# Table 0000010104_D310116 already exists.
# Table 0000010104_D3102 already exists.
# Table 0000010104_D3103 already exists.
# Table 0000010104_D310301 already exists.
# Table 0000010104_D310302 already exists.
# Table 0000010104_D310303 already exists.
# Table 0000010104_D3103031 already exists.
# Table 0000010104_D3103032 already exists.
# Table 0000010104_D3103033 already exists.
# Table 0000010104_D3103034 already exists.
# Table 0000010104_D3103035 already exists.
# Table 0000010104_D310304 already exists.
# Table 0000010104_D3103041 already exists.
# Table 0000010104_D3103043 already exists.
# Table 0000010104_D3103044 already exists.
# Table 0000010104_D3103045 already exists.
# Table 0000010104_D3103046 already exists.
# Table 0000010104_D310305 already exists.
# Table 0000010104_D3103051 already exists.
# Table 0000010104_D3103052 already exists.
# Table 0000010104_D3103053 already exists.
# Table 0000010104_D310306 already exists.
# Table 0000010104_D310307 already exists.
# Table 0000010104_D310308 already exists.
# Table 0000010104_D3103082 already exists.
# Table 0000010104_D3103085 already exists.
# Table 0000010104_D3103086 already exists.
# Table 0000010104_D310309 already exists.
# Table 0000010104_D310310 already exists.
# Table 0000010104_D310311 already exists.
# Table 0000010104_D3103112 already exists.
# Table 0000010104_D3103113 already exists.
# Table 0000010104_D3103114 already exists.
# Table 0000010104_D3103115 already exists.
# Table 0000010104_D3103116 already exists.
# Table 0000010104_D3103117 already exists.
# Table 0000010104_D3103118 already exists.
# Table 0000010104_D310312 already exists.
# Table 0000010104_D310313 already exists.
# Table 0000010104_D310401 already exists.
# Table 0000010104_D310402 already exists.
# Table 0000010104_D310403 already exists.
# Table 0000010104_D310404 already exists.
# Table 0000010104_D310405 already exists.
# Table 0000010104_D310406 already exists.
# Table 0000010104_D310407 already exists.
# Table 0000010104_D310408 already exists.
# Table 0000010104_D310409 already exists.
# Table 0000010104_D310410 already exists.
# Table 0000010104_D310411 already exists.
# Table 0000010104_D310412 already exists.
# Table 0000010104_D3105 already exists.
# Table 0000010104_D3201 already exists.
# Table 0000010104_D320101 already exists.
# Table 0000010104_D320102 already exists.
# Table 0000010104_D320103 already exists.
# Table 0000010104_D320104 already exists.
# Table 0000010104_D320105 already exists.
# Table 0000010104_D320106 already exists.
# Table 0000010104_D320107 already exists.
# Table 0000010104_D320108 already exists.
# Table 0000010104_D320109 already exists.
# Table 0000010104_D320110 already exists.
# Table 0000010104_D320111 already exists.
# Table 0000010104_D320113 already exists.
# Table 0000010104_D320115 already exists.
# Table 0000010104_D320116 already exists.
# Table 0000010104_D320117 already exists.
# Table 0000010104_D320118 already exists.
# Table 0000010104_D320119 already exists.
# Table 0000010104_D320120 already exists.
# Table 0000010104_D320121 already exists.
# Table 0000010104_D320122 already exists.
# Table 0000010104_D3202 already exists.
# Table 0000010104_D3203 already exists.
# Table 0000010104_D3203001 already exists.
# Table 0000010104_D320301 already exists.
# Table 0000010104_D320302 already exists.
# Table 0000010104_D320303 already exists.
# Table 0000010104_D3203031 already exists.
# Table 0000010104_D3203032 already exists.
# Table 0000010104_D3203033 already exists.
# Table 0000010104_D3203034 already exists.
# Table 0000010104_D3203035 already exists.
# Table 0000010104_D320304 already exists.
# Table 0000010104_D3203042 already exists.
# Table 0000010104_D3203043 already exists.
# Table 0000010104_D3203044 already exists.
# Table 0000010104_D320305 already exists.
# Table 0000010104_D3203051 already exists.
# Table 0000010104_D320306 already exists.
# Table 0000010104_D320307 already exists.
# Table 0000010104_D320308 already exists.
# Table 0000010104_D3203082 already exists.
# Table 0000010104_D3203085 already exists.
# Table 0000010104_D3203086 already exists.
# Table 0000010104_D320309 already exists.
# Table 0000010104_D3203099 already exists.
# Table 0000010104_D320310 already exists.
# Table 0000010104_D3203102 already exists.
# Table 0000010104_D3203103 already exists.
# Table 0000010104_D3203104 already exists.
# Table 0000010104_D3203105 already exists.
# Table 0000010104_D3203106 already exists.
# Table 0000010104_D3203107 already exists.
# Table 0000010104_D3203108 already exists.
# Table 0000010104_D320311 already exists.
# Table 0000010104_D320312 already exists.
# Table 0000010104_D320401 already exists.
# Table 0000010104_D320402 already exists.
# Table 0000010104_D320403 already exists.
# Table 0000010104_D320404 already exists.
# Table 0000010104_D320405 already exists.
# Table 0000010104_D320406 already exists.
# Table 0000010104_D320407 already exists.
# Table 0000010104_D320408 already exists.
# Table 0000010104_D320409 already exists.
# Table 0000010104_D320410 already exists.
# Table 0000010104_D320411 already exists.
# Table 0000010104_D320412 already exists.
# Table 0000010104_D3205 already exists.
# Table 0000010104_D4101 already exists.
# Table 0000010104_D410101 already exists.
# Table 0000010104_D410102 already exists.
# Table 0000010104_D4102 already exists.
# Table 0000010104_D410201 already exists.
# Table 0000010104_D410202 already exists.
# Table 0000010104_D4201 already exists.
# Table 0000010104_D420101 already exists.
# Table 0000010104_D420102 already exists.
# Table 0000010104_D4202 already exists.
# Table 0000010104_D420201 already exists.
# Table 0000010104_D420202 already exists.
# Table 0000010104_D4203 already exists.
# Table 0000010104_D430101 already exists.
# Table 0000010104_D430102 already exists.
# Table 0000010104_D430103 already exists.
# Table 0000010104_D4302 already exists.
# Table 0000010104_D430201 already exists.
# Table 0000010104_D430202 already exists.
# Table 0000010104_D430203 already exists.
# Table 0000010104_D5100 already exists.
# Table 0000010104_D5200 already exists.
# Table 0000010104_D5201 already exists.
# Table 0000010104_D5202 already exists.
# Table 0000010104_D5203 already exists.
# Table 0000010104_D5204 already exists.
# Table 0000010104_D5205 already exists.
# Table 0000010104_D5206 already exists.
# Table 0000010104_D5207 already exists.
# Table 0000010104_D5208 already exists.
# Table 0000010104_D5210 already exists.
# Table 0000010104_D5211 already exists.
# Table 0000010104_D5300 already exists.
# Table 0000010105_E1101 already exists.
# Table 0000010105_E110102 already exists.
# Table 0000010105_E1201 already exists.
# Table 0000010105_E120101 already exists.
# Table 0000010105_E120102 already exists.
# Table 0000010105_E120103 already exists.
# Table 0000010105_E1301 already exists.
# Table 0000010105_E130101 already exists.
# Table 0000010105_E130102 already exists.
# Table 0000010105_E1302 already exists.
# Table 0000010105_E130201 already exists.
# Table 0000010105_E130202 already exists.
# Table 0000010105_E1303 already exists.
# Table 0000010105_E130301 already exists.
# Table 0000010105_E130302 already exists.
# Table 0000010105_E1401 already exists.
# Table 0000010105_E140101 already exists.
# Table 0000010105_E140102 already exists.
# Table 0000010105_E140103 already exists.
# Table 0000010105_E1501 already exists.
# Table 0000010105_E150101 already exists.
# Table 0000010105_E150102 already exists.
# Table 0000010105_E150103 already exists.
# Table 0000010105_E150104 already exists.
# Table 0000010105_E150105 already exists.
# Table 0000010105_E1502 already exists.
# Table 0000010105_E150201 already exists.
# Table 0000010105_E150202 already exists.
# Table 0000010105_E150203 already exists.
# Table 0000010105_E150204 already exists.
# Table 0000010105_E150205 already exists.
# Table 0000010105_E1601 already exists.
# Table 0000010105_E160101 already exists.
# Table 0000010105_E160102 already exists.
# Table 0000010105_E2101 already exists.
# Table 0000010105_E210101 already exists.
# Table 0000010105_E210102 already exists.
# Table 0000010105_E210103 already exists.
# Table 0000010105_E2202 already exists.
# Table 0000010105_E2203 already exists.
# Table 0000010105_E2205 already exists.
# Table 0000010105_E2206 already exists.
# Table 0000010105_E2207 already exists.
# Table 0000010105_E2301 already exists.
# Table 0000010105_E230101 already exists.
# Table 0000010105_E230102 already exists.
# Table 0000010105_E2301021 already exists.
# Table 0000010105_E2301022 already exists.
# Table 0000010105_E2301023 already exists.
# Table 0000010105_E230103 already exists.
# Table 0000010105_E2401 already exists.
# Table 0000010105_E240101 already exists.
# Table 0000010105_E240102 already exists.
# Table 0000010105_E2402 already exists.
# Table 0000010105_E240201 already exists.
# Table 0000010105_E240202 already exists.
# Table 0000010105_E2501 already exists.
# Table 0000010105_E250101 already exists.
# Table 0000010105_E250102 already exists.
# Table 0000010105_E2501021 already exists.
# Table 0000010105_E2501022 already exists.
# Table 0000010105_E2501023 already exists.
# Table 0000010105_E2501024 already exists.
# Table 0000010105_E2501025 already exists.
# Table 0000010105_E250103 already exists.
# Table 0000010105_E250104 already exists.
# Table 0000010105_E250105 already exists.
# Table 0000010105_E2502 already exists.
# Table 0000010105_E250401 already exists.
# Table 0000010105_E250402 already exists.
# Table 0000010105_E2508 already exists.
# Table 0000010105_E250801 already exists.
# Table 0000010105_E250802 already exists.
# Table 0000010105_E2601 already exists.
# Table 0000010105_E3101 already exists.
# Table 0000010105_E310101 already exists.
# Table 0000010105_E310102 already exists.
# Table 0000010105_E310103 already exists.
# Table 0000010105_E3202 already exists.
# Table 0000010105_E3203 already exists.
# Table 0000010105_E3205 already exists.
# Table 0000010105_E3206 already exists.
# Table 0000010105_E3207 already exists.
# Table 0000010105_E3301 already exists.
# Table 0000010105_E330101 already exists.
# Table 0000010105_E330102 already exists.
# Table 0000010105_E3301021 already exists.
# Table 0000010105_E3301022 already exists.
# Table 0000010105_E3301023 already exists.
# Table 0000010105_E330103 already exists.
# Table 0000010105_E3401 already exists.
# Table 0000010105_E340101 already exists.
# Table 0000010105_E340102 already exists.
# Table 0000010105_E3402 already exists.
# Table 0000010105_E340201 already exists.
# Table 0000010105_E340202 already exists.
# Table 0000010105_E3501 already exists.
# Table 0000010105_E350101 already exists.
# Table 0000010105_E3501011 already exists.
# Table 0000010105_E3501012 already exists.
# Table 0000010105_E3501013 already exists.
# Table 0000010105_E3501014 already exists.
# Table 0000010105_E3501015 already exists.
# Table 0000010105_E350102 already exists.
# Table 0000010105_E350103 already exists.
# Table 0000010105_E350201 already exists.
# Table 0000010105_E350202 already exists.
# Table 0000010105_E3505 already exists.
# Table 0000010105_E350501 already exists.
# Table 0000010105_E350502 already exists.
# Table 0000010105_E3601 already exists.
# Table 0000010105_E3701 already exists.
# Table 0000010105_E370101 already exists.
# Table 0000010105_E370102 already exists.
# Table 0000010105_E3702 already exists.
# Table 0000010105_E370201 already exists.
# Table 0000010105_E370202 already exists.
# Table 0000010105_E3703 already exists.
# Table 0000010105_E370301 already exists.
# Table 0000010105_E370302 already exists.
# ...
# Table 0000020204_D3203107 already exists.
# Table 0000020204_D3203108 already exists.
# Table 0000020204_D320311 already exists.
# Table 0000020204_D320312 already exists.
# Table 0000020204_D320401 already exists.
# Table 0000020204_D320402 already exists.
# Table 0000020204_D320403 already exists.
# Table 0000020204_D320404 already exists.
# Table 0000020204_D320405 already exists.
# Table 0000020204_D320406 already exists.
# Table 0000020204_D320407 already exists.
# Table 0000020204_D320408 already exists.
# Table 0000020204_D320409 already exists.
# Table 0000020204_D320410 already exists.
# Table 0000020204_D320411 already exists.
# Table 0000020204_D320412 already exists.
# Table 0000020204_D3205 already exists.
# Table 0000020204_D420102 already exists.
# Table 0000020204_D420202 already exists.
# Table 0000020204_D430103 already exists.
# Table 0000020204_D430203 already exists.
# Table 0000020205_E1101 already exists.
# Table 0000020205_E1501 already exists.
# Table 0000020205_E2101 already exists.
# Table 0000020205_E2401 already exists.
# Table 0000020205_E2501 already exists.
# Table 0000020205_E3101 already exists.
# Table 0000020205_E3401 already exists.
# Table 0000020205_E3501 already exists.
# Table 0000020205_E3901 already exists.
# Table 0000020205_E3902 already exists.
# Table 0000020205_E3903 already exists.
# Table 0000020205_E3904 already exists.
# Table 0000020205_E3905 already exists.
# Table 0000020205_E3906 already exists.
# Table 0000020205_E4101 already exists.
# Table 0000020205_E4501 already exists.
# Table 0000020205_E9101 already exists.
# Table 0000020205_E9102 already exists.
# Table 0000020205_E9103 already exists.
# Table 0000020205_E9105 already exists.
# Table 0000020205_E9106 already exists.
# Table 0000020206_F1101 already exists.
# Table 0000020206_F110101 already exists.
# Table 0000020206_F110102 already exists.
# Table 0000020206_F1102 already exists.
# Table 0000020206_F110201 already exists.
# Table 0000020206_F110202 already exists.
# Table 0000020206_F1103 already exists.
# Table 0000020206_F1104 already exists.
# Table 0000020206_F1105 already exists.
# Table 0000020206_F1106 already exists.
# Table 0000020206_F1107 already exists.
# Table 0000020206_F110701 already exists.
# Table 0000020206_F110702 already exists.
# Table 0000020206_F1108 already exists.
# Table 0000020206_F110801 already exists.
# Table 0000020206_F110802 already exists.
# Table 0000020206_F1109 already exists.
# Table 0000020206_F1110 already exists.
# Table 0000020206_F1111 already exists.
# Table 0000020206_F1301 already exists.
# Table 0000020206_F1302 already exists.
# Table 0000020206_F1303 already exists.
# Table 0000020206_F1304 already exists.
# Table 0000020206_F1305 already exists.
# Table 0000020206_F1306 already exists.
# Table 0000020206_F1307 already exists.
# Table 0000020206_F1308 already exists.
# Table 0000020206_F1309 already exists.
# Table 0000020206_F1310 already exists.
# Table 0000020206_F1311 already exists.
# Table 0000020206_F1312 already exists.
# Table 0000020206_F1313 already exists.
# Table 0000020206_F1314 already exists.
# Table 0000020206_F1315 already exists.
# Table 0000020206_F1316 already exists.
# Table 0000020206_F1317 already exists.
# Table 0000020206_F1318 already exists.
# Table 0000020206_F2116 already exists.
# Table 0000020206_F2201 already exists.
# Table 0000020206_F2211 already exists.
# Table 0000020206_F2221 already exists.
# Table 0000020206_F2401 already exists.
# Table 0000020206_F2402 already exists.
# Table 0000020206_F2403 already exists.
# Table 0000020206_F2404 already exists.
# Table 0000020206_F2405 already exists.
# Table 0000020206_F2406 already exists.
# Table 0000020206_F2409 already exists.
# Table 0000020206_F2410 already exists.
# Table 0000020206_F2411 already exists.
# Table 0000020206_F2701 already exists.
# Table 0000020206_F270101 already exists.
# Table 0000020206_F270102 already exists.
# Table 0000020206_F2702 already exists.
# Table 0000020206_F270201 already exists.
# Table 0000020206_F270202 already exists.
# Table 0000020206_F2703 already exists.
# Table 0000020206_F270301 already exists.
# Table 0000020206_F270302 already exists.
# Table 0000020206_F2705 already exists.
# Table 0000020206_F270501 already exists.
# Table 0000020206_F270502 already exists.
# Table 0000020206_F2801 already exists.
# Table 0000020206_F2802 already exists.
# Table 0000020206_F2803 already exists.
# Table 0000020207_G1201 already exists.
# Table 0000020207_G1401 already exists.
# Table 0000020208_H1100 already exists.
# Table 0000020208_H1101 already exists.
# Table 0000020208_H1102 already exists.
# Table 0000020208_H110201 already exists.
# Table 0000020208_H110202 already exists.
# Table 0000020208_H110203 already exists.
# Table 0000020208_H1201 already exists.
# Table 0000020208_H1203 already exists.
# Table 0000020208_H1310 already exists.
# Table 0000020208_H1320 already exists.
# Table 0000020208_H1321 already exists.
# Table 0000020208_H132101 already exists.
# Table 0000020208_H132102 already exists.
# Table 0000020208_H1322 already exists.
# Table 0000020208_H1323 already exists.
# Table 0000020208_H1401 already exists.
# Table 0000020208_H140101 already exists.
# Table 0000020208_H140102 already exists.
# Table 0000020208_H1402 already exists.
# Table 0000020208_H140201 already exists.
# Table 0000020208_H140202 already exists.
# Table 0000020208_H1403 already exists.
# Table 0000020208_H140301 already exists.
# Table 0000020208_H140302 already exists.
# Table 0000020208_H1404 already exists.
# Table 0000020208_H1501 already exists.
# Table 0000020208_H150101 already exists.
# Table 0000020208_H150102 already exists.
# Table 0000020208_H1502 already exists.
# Table 0000020208_H1504 already exists.
# Table 0000020208_H1505 already exists.
# Table 0000020208_H1506 already exists.
# Table 0000020208_H1604 already exists.
# Table 0000020208_H1605 already exists.
# Table 0000020208_H1612 already exists.
# Table 0000020208_H1613 already exists.
# Table 0000020208_H1615 already exists.
# Table 0000020208_H1616 already exists.
# Table 0000020208_H1619 already exists.
# Table 0000020208_H1620 already exists.
# Table 0000020208_H1621 already exists.
# Table 0000020208_H1622 already exists.
# Table 0000020208_H1623 already exists.
# Table 0000020208_H1624 already exists.
# Table 0000020208_H1625 already exists.
# Table 0000020208_H1800 already exists.
# Table 0000020208_H1801 already exists.
# Table 0000020208_H1802 already exists.
# Table 0000020208_H1803 already exists.
# Table 0000020208_H1804 already exists.
# Table 0000020208_H1810 already exists.
# Table 0000020208_H2101 already exists.
# Table 0000020208_H2102 already exists.
# Table 0000020208_H2103 already exists.
# Table 0000020208_H2104 already exists.
# Table 0000020208_H2105 already exists.
# Table 0000020208_H2106 already exists.
# Table 0000020208_H2107 already exists.
# Table 0000020208_H2108 already exists.
# Table 0000020208_H2110 already exists.
# Table 0000020208_H211010 already exists.
# Table 0000020208_H211020 already exists.
# Table 0000020208_H2120 already exists.
# Table 0000020208_H212010 already exists.
# Table 0000020208_H212020 already exists.
# Table 0000020208_H2130 already exists.
# Table 0000020208_H213010 already exists.
# Table 0000020208_H213020 already exists.
# Table 0000020208_H2201 already exists.
# Table 0000020208_H2230 already exists.
# Table 0000020208_H2250 already exists.
# Table 0000020208_H2270 already exists.
# Table 0000020208_H227004 already exists.
# Table 0000020208_H227005 already exists.
# Table 0000020208_H2280 already exists.
# Table 0000020208_H2281 already exists.
# Table 0000020208_H2282 already exists.
# Table 0000020208_H2283 already exists.
# Table 0000020208_H2500 already exists.
# Table 0000020208_H2600 already exists.
# Table 0000020208_H2601 already exists.
# Table 0000020208_H2602 already exists.
# Table 0000020208_H2603 already exists.
# Table 0000020208_H2604 already exists.
# Table 0000020208_H2900 already exists.
# Table 0000020208_H2901 already exists.
# Table 0000020208_H2902 already exists.
# Table 0000020208_H2903 already exists.
# Table 0000020208_H2904 already exists.
# Table 0000020208_H2905 already exists.
# Table 0000020208_H2906 already exists.
# Table 0000020208_H2907 already exists.
# Table 0000020208_H2908 already exists.
# Table 0000020208_H2909 already exists.
# Table 0000020208_H2910 already exists.
# Table 0000020208_H2911 already exists.
# Table 0000020208_H2912 already exists.
# Table 0000020208_H2913 already exists.
# Table 0000020208_H2914 already exists.
# Table 0000020208_H2915 already exists.
# Table 0000020208_H2916 already exists.
# Table 0000020208_H2917 already exists.
# Table 0000020208_H2918 already exists.
# Table 0000020208_H2919 already exists.
# Table 0000020208_H3100 already exists.
# Table 0000020208_H3110 already exists.
# Table 0000020208_H3111 already exists.
# Table 0000020208_H311110 already exists.
# Table 0000020208_H3120 already exists.
# Table 0000020208_H3210 already exists.
# Table 0000020208_H3211 already exists.
# Table 0000020208_H3220 already exists.
# Table 0000020208_H3300 already exists.
# Table 0000020208_H3310 already exists.
# Table 0000020208_H3311 already exists.
# Table 0000020208_H3312 already exists.
# Table 0000020208_H3313 already exists.
# Table 0000020208_H3320 already exists.
# Table 0000020208_H3410 already exists.
# Table 0000020208_H3411 already exists.
# Table 0000020208_H3420 already exists.
# Table 0000020208_H3510 already exists.
# Table 0000020208_H3511 already exists.
# Table 0000020208_H351101 already exists.
# Table 0000020208_H351102 already exists.
# Table 0000020208_H3520 already exists.
# Table 0000020208_H3521 already exists.
# Table 0000020208_H352101 already exists.
# Table 0000020208_H352102 already exists.
# Table 0000020208_H3730 already exists.
# Table 0000020208_H3740 already exists.
# Table 0000020208_H4104 already exists.
# Table 0000020208_H5501 already exists.
# Table 0000020208_H5507 already exists.
# Table 0000020208_H550701 already exists.
# Table 0000020208_H5508 already exists.
# Table 0000020208_H5509 already exists.
# Table 0000020208_H5601 already exists.
# Table 0000020208_H5608 already exists.
# Table 0000020208_H5609 already exists.
# Table 0000020208_H560901 already exists.
# Table 0000020208_H560902 already exists.
# Table 0000020208_H560903 already exists.
# Table 0000020208_H560904 already exists.
# Table 0000020208_H5610 already exists.
# Table 0000020208_H5612 already exists.
# Table 0000020208_H561201 already exists.
# Table 0000020208_H5613 already exists.
# Table 0000020208_H5614 already exists.
# Table 0000020208_H5615 already exists.
# Table 0000020208_H6101 already exists.
# Table 0000020208_H6102 already exists.
# Table 0000020208_H6103 already exists.
# Table 0000020208_H6104 already exists.
# Table 0000020208_H6130 already exists.
# Table 0000020208_H613001 already exists.
# Table 0000020208_H613002 already exists.
# Table 0000020208_H613003 already exists.
# Table 0000020208_H613004 already exists.
# Table 0000020208_H613005 already exists.
# Table 0000020208_H613006 already exists.
# Table 0000020208_H6131 already exists.
# Table 0000020208_H6132 already exists.
# Table 0000020208_H6133 already exists.
# Table 0000020208_H6201 already exists.
# Table 0000020208_H7207 already exists.
# Table 0000020208_H7208 already exists.
# Table 0000020208_H7209 already exists.
# Table 0000020208_H720901 already exists.
# Table 0000020208_H720902 already exists.
# Table 0000020208_H720903 already exists.
# Table 0000020208_H720904 already exists.
# Table 0000020208_H7210 already exists.
# Table 0000020208_H721001 already exists.
# Table 0000020208_H721002 already exists.
# Table 0000020208_H7301 already exists.
# Table 0000020208_H730101 already exists.
# Table 0000020208_H730102 already exists.
# Table 0000020208_H730103 already exists.
# Table 0000020208_H730104 already exists.
# Table 0000020208_H730105 already exists.
# Table 0000020208_H730108 already exists.
# Table 0000020208_H730109 already exists.
# Table 0000020208_H730110 already exists.
# Table 0000020208_H730111 already exists.
# Table 0000020208_H730112 already exists.
# Table 0000020208_H730113 already exists.
# Table 0000020208_H7302 already exists.
# Table 0000020208_H7303 already exists.
# Table 0000020208_H7304 already exists.
# Table 0000020208_H7401 already exists.
# Table 0000020208_H740101 already exists.
# Table 0000020208_H740102 already exists.
# Table 0000020208_H740103 already exists.
# Table 0000020208_H740104 already exists.
# Table 0000020208_H7701 already exists.
# Table 0000020208_H770101 already exists.
# Table 0000020208_H8101 already exists.
# Table 0000020208_H8102 already exists.
# Table 0000020208_H8103 already exists.
# Table 0000020208_H8104 already exists.
# Table 0000020208_H810401 already exists.
# Table 0000020208_H810402 already exists.
# Table 0000020208_H810403 already exists.
# Table 0000020208_H810404 already exists.
# Table 0000020208_H810405 already exists.
# Table 0000020208_H810406 already exists.
# Table 0000020208_H810407 already exists.
# Table 0000020208_H810408 already exists.
# 60935 件のデータを「0000020208_H810409」に保存しました。
# 3482 件のデータを「0000020209_I1101」に保存しました。
# 3482 件のデータを「0000020209_I1102」に保存しました。
# 40043 件のデータを「0000020209_I5101」に保存しました。
# 40043 件のデータを「0000020209_I510110」に保存しました。
# 69640 件のデータを「0000020209_I510120」に保存しました。
# 41784 件のデータを「0000020209_I510150」に保存しました。
# 69640 件のデータを「0000020209_I5102」に保存しました。
# 34820 件のデータを「0000020209_I510201」に保存しました。
# 41784 件のデータを「0000020209_I5103」に保存しました。
# 34820 件のデータを「0000020209_I5211」に保存しました。
# 34820 件のデータを「0000020209_I5212」に保存しました。
# 31338 件のデータを「0000020209_I5501」に保存しました。
# 31338 件のデータを「0000020209_I5502」に保存しました。
# 3482 件のデータを「0000020209_I5511」に保存しました。
# 3482 件のデータを「0000020209_I5512」に保存しました。
# 40042 件のデータを「0000020209_I6100」に保存しました。
# 17410 件のデータを「0000020209_I6101」に保存しました。
# 40042 件のデータを「0000020209_I6200」に保存しました。
# 17410 件のデータを「0000020209_I6201」に保存しました。
# 17410 件のデータを「0000020209_I6300」に保存しました。
# 17410 件のデータを「0000020209_I6310」に保存しました。
# 31338 件のデータを「0000020210_J2201」に保存しました。
# 3482 件のデータを「0000020210_J2221」に保存しました。
# 31338 件のデータを「0000020210_J2301」に保存しました。
# 31338 件のデータを「0000020210_J230111」に保存しました。
# 31338 件のデータを「0000020210_J230112」に保存しました。
# 31338 件のデータを「0000020210_J230113」に保存しました。
# 36561 件のデータを「0000020210_J230121」に保存しました。
# 31338 件のデータを「0000020210_J230124」に保存しました。
# 3482 件のデータを「0000020210_J230127」に保存しました。
# 3482 件のデータを「0000020210_J230128」に保存しました。
# 31338 件のデータを「0000020210_J230131」に保存しました。
# 31338 件のデータを「0000020210_J230132」に保存しました。
# 31338 件のデータを「0000020210_J230133」に保存しました。
# 31338 件のデータを「0000020210_J230141」に保存しました。
# 17410 件のデータを「0000020210_J230191」に保存しました。
# 17410 件のデータを「0000020210_J230211」に保存しました。
# 31338 件のデータを「0000020210_J230221」に保存しました。
# 31338 件のデータを「0000020210_J230222」に保存しました。
# 31338 件のデータを「0000020210_J230223」に保存しました。
# 17410 件のデータを「0000020210_J2303」に保存しました。
# 3482 件のデータを「0000020210_J2304」に保存しました。
# 3482 件のデータを「0000020210_J230411」に保存しました。
# 3482 件のデータを「0000020210_J230412」に保存しました。
# 3482 件のデータを「0000020210_J230421」に保存しました。
# 3482 件のデータを「0000020210_J230422」に保存しました。
# 3482 件のデータを「0000020210_J230431」に保存しました。
# 3482 件のデータを「0000020210_J230432」に保存しました。
# 13928 件のデータを「0000020210_J232101」に保存しました。
# 26115 件のデータを「0000020210_J2401」に保存しました。
# 20892 件のデータを「0000020210_J2402」に保存しました。
# 20892 件のデータを「0000020210_J2403」に保存しました。
# 31338 件のデータを「0000020210_J2501」に保存しました。
# 3482 件のデータを「0000020210_J250204」に保存しました。
# 66154 件のデータを「0000020210_J2503」に保存しました。
# 31338 件のデータを「0000020210_J250301」に保存しました。
# 3482 件のデータを「0000020210_J250302」に保存しました。
# 3482 件のデータを「0000020210_J250303」に保存しました。
# 66154 件のデータを「0000020210_J2506」に保存しました。
# 31338 件のデータを「0000020210_J250604」に保存しました。
# 1741 件のデータを「0000020210_J2545」に保存しました。
# 1741 件のデータを「0000020210_J2546」に保存しました。
# 26115 件のデータを「0000020210_J2641」に保存しました。
# 26115 件のデータを「0000020210_J2642」に保存しました。
# 20892 件のデータを「0000020210_J2701」に保存しました。
# 20892 件のデータを「0000020210_J2702」に保存しました。
# 20892 件のデータを「0000020210_J2703」に保存しました。
# 31338 件のデータを「0000020210_J2801」に保存しました。
# 3482 件のデータを「0000020210_J2804」に保存しました。
# 17410 件のデータを「0000020210_J2901」に保存しました。
# 6964 件のデータを「0000020210_J2902」に保存しました。
# 17410 件のデータを「0000020210_J2903」に保存しました。
# 17410 件のデータを「0000020210_J2904」に保存しました。
# 3482 件のデータを「0000020210_J2905」に保存しました。
# 3482 件のデータを「0000020210_J2906」に保存しました。
# 69639 件のデータを「0000020210_J4101」に保存しました。
# 19150 件のデータを「0000020210_J4102」に保存しました。
# 26114 件のデータを「0000020210_J4104」に保存しました。
# 26114 件のデータを「0000020210_J4106」に保存しました。
# 26114 件のデータを「0000020210_J4107」に保存しました。
# 24364 件のデータを「0000020210_J4108」に保存しました。
# 24364 件のデータを「0000020210_J4109」に保存しました。
# 52230 件のデータを「0000020211_K3101」に保存しました。
# 50489 件のデータを「0000020211_K4201」に保存しました。
