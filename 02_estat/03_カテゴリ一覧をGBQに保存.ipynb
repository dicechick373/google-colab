# %% [markdown]
# # 実行環境の作成

# %% [markdown]
# ## GCP認証

# %% [markdown]
# 下記コードでGCPに接続

# %%
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# # estatの統計情報を取得

# %% [markdown]
# メタ情報を取得する関数を作成

# %%
import urllib.parse
import urllib.request
import json

def get_estat_meta(statsDataId):
  params ={
      'statsDataId': statsDataId,
      'appId': '724e5b90772a3e9289f41a253e4e7e32438f4fff',
  }

  url = 'http://api.e-stat.go.jp/rest/3.0/app/json/getMetaInfo?'
  url += urllib.parse.urlencode(params)

  with urllib.request.urlopen(url) as response:
    return json.loads(response.read().decode('utf-8'))

# %%
meta = get_estat_meta('0000020211')
print(meta)
# Out:
# {'GET_META_INFO': {'RESULT': {'STATUS': 0, 'ERROR_MSG': '正常に終了しました。', 'DATE': '2022-12-28T21:25:33.854+09:00'}, 'PARAMETER': {'LANG': 'J', 'STATS_DATA_ID': '0000020211', 'DATA_FORMAT': 'J'}, 'METADATA_INF': {'TABLE_INF': {'@id': '0000020211', 'STAT_NAME': {'@code': '00200502', '$': '社会・人口統計体系'}, 'GOV_ORG': {'@code': '00200', '$': '総務省'}, 'STATISTICS_NAME': '市区町村データ 基礎データ（廃置分合処理済）', 'TITLE': {'@no': '0000020211', '$': 'Ｋ\u3000安全'}, 'CYCLE': '年度次', 'SURVEY_DATE': 0, 'OPEN_DATE': '2022-06-21', 'SMALL_AREA': 0, 'COLLECT_AREA': '市区町村', 'MAIN_CATEGORY': {'@code': '99', '$': 'その他'}, 'SUB_CATEGORY': {'@code': '99', '$': 'その他'}, 'OVERALL_TOTAL_NUMBER': 112933, 'UPDATED_DATE': '2022-06-21', 'STATISTICS_NAME_SPEC': {'TABULATION_CATEGORY': '市区町村データ', 'TABULATION_SUB_CATEGORY1': '基礎データ（廃置分合処理済）'}, 'DESCRIPTION': {'TABULATION_CATEGORY_EXPLANATION': '社会・人口統計体系の市区町村ごとに集計したデータを提供します。', 'TABULATION_SUB_CATEGORY_EXPLANATION1': 'データは、2021年3月31日時点の市区町村で整備しています。'}, 'TITLE_SPEC': {'TABLE_NAME': 'Ｋ\u3000安全'}}, 'CLASS_INF': {'CLASS_OBJ': [{'@id': 'tab', '@name': '観測値', 'CLASS': {'@code': '00001', '@name': '観測値', '@level': '1'}}, {'@id': 'cat01', '@name': 'Ｋ\u3000安全', 'CLASS': [{'@code': 'K3101', '@name': 'K3101_交通事故発生件数', '@level': '1', '@unit': '件'}, {'@code': 'K4201', '@name': 'K4201_刑法犯認知件数', '@level': '1', '@unit': '件'}]}, {'@id': 'area', '@name': '地域', 'CLASS': [{'@code': '01100', '@name': '北海道 札幌市', '@level': '2', '@parentCode': '01000'}, {'@code': '01101', '@name': '北海道 札幌市 中央区', '@level': '3', '@parentCode': '01100'}, {'@code': '01102', '@name': '北海道 札幌市 北区', '@level': '3', '@parentCode': '01100'}, {'@code': '01103', '@name': '北海道 札幌市 東区', '@level': '3', '@parentCode': '01100'}, {'@code': '01104', '@name': '北海道 札幌市 白石区', '@level': '3', '@parentCode': '01100'}, {'@code': '01105', '@name': '北海道 札幌市 豊平区', '@level': '3', '@parentCode': '01100'}, {'@code': '01106', '@name': '北海道 札幌市 南区', '@level': '3', '@parentCode': '01100'}, {'@code': '01107', '@name': '北海道 札幌市 西区', '@level': '3', '@parentCode': '01100'}, {'@code': '01108', '@name': '北海道 札幌市 厚別区', '@level': '3', '@parentCode': '01100'}, {'@code': '01109', '@name': '北海道 札幌市 手稲区', '@level': '3', '@parentCode': '01100'}, {'@code': '01110', '@name': '北海道 札幌市 清田区', '@level': '3', '@parentCode': '01100'}, {'@code': '01202', '@name': '北海道 函館市', '@level': '2', '@parentCode': '01000'}, {'@code': '01203', '@name': '北海道 小樽市', '@level': '2', '@parentCode': '01000'}, {'@code': '01204', '@name': '北海道 旭川市', '@level': '2', '@parentCode': '01000'}, {'@code': '01205', '@name': '北海道 室蘭市', '@level': '2', '@parentCode': '01000'}, {'@code': '01206', '@name': '北海道 釧路市', '@level': '2', '@parentCode': '01000'}, {'@code': '01207', '@name': '北海道 帯広市', '@level': '2', '@parentCode': '01000'}, {'@code': '01208', '@name': '北海道 北見市', '@level': '2', '@parentCode': '01000'}, {'@code': '01209', '@name': '北海道 夕張市', '@level': '2', '@parentCode': '01000'}, {'@code': '01210', '@name': '北海道 岩見沢市', '@level': '2', '@parentCode': '01000'}, {'@code': '01211', '@name': '北海道 網走市', '@level': '2', '@parentCode': '01000'}, {'@code': '01212', '@name': '北海道 留萌市', '@level': '2', '@parentCode': '01000'}, {'@code': '01213', '@name': '北海道 苫小牧市', '@level': '2', '@parentCode': '01000'}, {'@code': '01214', '@name': '北海道 稚内市', '@level': '2', '@parentCode': '01000'}, {'@code': '01215', '@name': '北海道 美唄市', '@level': '2', '@parentCode': '01000'}, {'@code': '01216', '@name': '北海道 芦別市', '@level': '2', '@parentCode': '01000'}, {'@code': '01217', '@name': '北海道 江別市', '@level': '2', '@parentCode': '01000'}, {'@code': '01218', '@name': '北海道 赤平市', '@level': '2', '@parentCode': '01000'}, {'@code': '01219', '@name': '北海道 紋別市', '@level': '2', '@parentCode': '01000'}, {'@code': '01220', '@name': '北海道 士別市', '@level': '2', '@parentCode': '01000'}, {'@code': '01221', '@name': '北海道 名寄市', '@level': '2', '@parentCode': '01000'}, {'@code': '01222', '@name': '北海道 三笠市', '@level': '2', '@parentCode': '01000'}, {'@code': '01223', '@name': '北海道 根室市', '@level': '2', '@parentCode':  ...

# %% [markdown]
# ## DataFrameの作成

# %% [markdown]
# メタ情報をDataFrameに整形する

# %%
import pandas as pd

def df_meta(statsDataId):
  # メタ情報の取得
  meta= get_estat_meta(statsDataId)

  # CLASS_OBJ
  CLASS_OBJ = meta['GET_META_INFO']['METADATA_INF']['CLASS_INF']['CLASS_OBJ']
  cat01 = next((d for d in CLASS_OBJ if d['@id'] == 'cat01'), None)['CLASS']
  
  # 都道府県 or 市区町村
  COLLECT_AREA = meta['GET_META_INFO']['METADATA_INF']['TABLE_INF']['COLLECT_AREA']
  governmentType = 'prefecture' if COLLECT_AREA == '全国' else 'city'

  # DataFrame
  df = pd.json_normalize(cat01)[['@code','@name','@unit']]
  
  # 列名の変更
  columns = {'@code':'categoryCode', '@name':'categoryName', '@unit':'unit'}
  df= df.rename(columns=columns)

  # categoryNameから不要な情報（categoryCode）を削除
  df['categoryName'] = df.apply(lambda x: x['categoryName'].replace(x['categoryCode']+'_', ''), 1)
  
  # 並べ替え
  df = df.reindex(columns=['categoryCode','categoryName','unit'])
  df['statsDataId'] = statsDataId
  df['statsDataName'] = meta['GET_META_INFO']['METADATA_INF']['TABLE_INF']['STAT_NAME']['$']
  df['governmentType'] = governmentType

  return df

# %% [markdown]
# 単体テスト

# %%
df = df_meta('0000010102')
df
# Out:
#    categoryCode         categoryName unit statsDataId statsDataName  \
# 0         B1101     総面積（北方地域及び竹島を除く）   ｈａ  0000010102     社会・人口統計体系
# 1         B1102     総面積（北方地域及び竹島を含む）   ｈａ  0000010102     社会・人口統計体系
# 2         B1103                可住地面積   ｈａ  0000010102     社会・人口統計体系
# 3         B1104               主要湖沼面積   ｈａ  0000010102     社会・人口統計体系
# 4         B1105                 林野面積   ｈａ  0000010102     社会・人口統計体系
# 5         B1106                 森林面積   ｈａ  0000010102     社会・人口統計体系
# 6         B1107           森林以外の草生地面積   ｈａ  0000010102     社会・人口統計体系
# 7         B1108           自然環境保全地域面積   ｈａ  0000010102     社会・人口統計体系
# 8         B1201        評価総地積（課税対象土地）   ｍ2  0000010102     社会・人口統計体系
# 9       B120101             評価総地積（田）   ｍ2  0000010102     社会・人口統計体系
# 10      B120102             評価総地積（畑）   ｍ2  0000010102     社会・人口統計体系
# 11      B120103            評価総地積（宅地）   ｍ2  0000010102     社会・人口統計体系
# 12      B120104            評価総地積（山林）   ｍ2  0000010102     社会・人口統計体系
# 13      B120105            評価総地積（牧場）   ｍ2  0000010102     社会・人口統計体系
# 14      B120106            評価総地積（原野）   ｍ2  0000010102     社会・人口統計体系
# 15      B120107           評価総地積（その他）   ｍ2  0000010102     社会・人口統計体系
# 16        B1303               人工造林面積   ｈａ  0000010102     社会・人口統計体系
# 17        B2101               自然公園面積   ｈａ  0000010102     社会・人口統計体系
# 18        B2102           都道府県立自然公園数   箇所  0000010102     社会・人口統計体系
# 19        B2103          都道府県立自然公園面積   ｈａ  0000010102     社会・人口統計体系
# 20        B2104               国立公園面積   ｈａ  0000010102     社会・人口統計体系
# 21        B2105               国定公園面積   ｈａ  0000010102     社会・人口統計体系
# 22        B3101          植生自然度1（構成比）    ％  0000010102     社会・人口統計体系
# 23        B3102          植生自然度2（構成比）    ％  0000010102     社会・人口統計体系
# 24        B3103          植生自然度3（構成比）    ％  0000010102     社会・人口統計体系
# 25        B3104          植生自然度4（構成比）    ％  0000010102     社会・人口統計体系
# 26        B3105          植生自然度5（構成比）    ％  0000010102     社会・人口統計体系
# 27        B3106          植生自然度6（構成比）    ％  0000010102     社会・人口統計体系
# 28        B3107          植生自然度7（構成比）    ％  0000010102     社会・人口統計体系
# 29        B3108          植生自然度8（構成比）    ％  0000010102     社会・人口統計体系
# 30        B3109          植生自然度9（構成比）    ％  0000010102     社会・人口統計体系
# 31        B3110         植生自然度10（構成比）    ％  0000010102     社会・人口統計体系
# 32        B4101                年平均気温    ℃  0000010102     社会・人口統計体系
# 33        B4102  最高気温（日最高気温の月平均の最高値）    ℃  0000010102     社会・人口統計体系
# 34        B4103  最低気温（日最低気温の月平均の最低値）    ℃  0000010102     社会・人口統計体系
# 35        B4104             快晴日数（年間）    日  0000010102     社会・人口統計体系
# 36        B4105             曇天日数（年間）    日  0000010102     社会・人口統計体系
# 37        B4106             降水日数（年間）    日  0000010102     社会・人口統計体系
# 38        B4107              雪日数（年間）    日  0000010102     社会・人口統計体系
# 39        B4108             日照時間（年間）   時間  0000010102     社会・人口統計体系
# 40        B4109              降水量（年間）   ｍｍ  0000010102     社会・人口統計体系
# 41        B4110                 最深積雪   ｃｍ  0000010102     社会・人口統計体系
# 42        B4111              年平均相対湿度    ％  0000010102     社会・人口統計体系
# 43        B4112           最小相対湿度（年間）    ％  0000010102     社会・人口統計体系
#
#    governmentType
# 0      prefecture
# 1      prefecture
# 2      prefecture
# 3      prefecture
# 4      prefecture
# 5      prefecture
# 6      prefecture
# 7      prefecture
# 8      prefecture
# 9      prefecture
# 10     prefecture
# 11     prefecture
# 12     prefecture
# 13     prefecture
# 14     prefecture
# 15     prefecture
# 16     prefecture
# 17     prefecture
# 18     prefecture
# 19     prefecture
# 20     prefecture
# 21     prefecture
# 22     prefecture
# 23     prefecture
# 24     prefecture
# 25     prefecture
# 26     prefecture
# 27     prefecture
# 28     prefecture
# 29     prefecture
# 30     prefecture
# 31     prefecture
# 32     prefecture
# 33     prefecture
# 34     prefecture
# 35     prefecture
# 36     prefecture
# 37     prefecture
# 38     prefecture
# 39     prefecture
# 40     prefecture
# 41     prefecture
# 42     prefecture
# 43     prefecture

# %% [markdown]
# 一括処理

# %%
def df_metas(data):
  df = pd.DataFrame(index=[], columns=[])
  for d in data:
    df1 = df_meta(d)
    df = pd.concat([df,df1],ignore_index=True)

  return df

# %%
data = ['0000010101', '0000010102', '0000010103', '0000010104', '0000010105', '0000010106', '0000010107', 
        '0000010108', '0000010109', '0000010110', '0000010111', '0000010112', '0000010113',
        '0000020201', '0000020202', '0000020203', '0000020204', '0000020205', '0000020206', 
        '0000020207', '0000020208', '0000020209', '0000020210', '0000020211']

df = df_metas(data)
df.head()
# Out:
#   categoryCode categoryName unit statsDataId statsDataName governmentType
# 0        A1101          総人口    人  0000010101     社会・人口統計体系     prefecture
# 1      A110101       総人口（男）    人  0000010101     社会・人口統計体系     prefecture
# 2      A110102       総人口（女）    人  0000010101     社会・人口統計体系     prefecture
# 3        A1102        日本人人口    人  0000010101     社会・人口統計体系     prefecture
# 4      A110201     日本人人口（男）    人  0000010101     社会・人口統計体系     prefecture

# %%
from google.cloud import bigquery

def save_gbq(df):
  project_id='primal-buttress-342908'
  dataset_id = 'estat_config'
  table_id = 'categories'
  
  # スキーマ
  job_config = bigquery.LoadJobConfig(write_disposition='WRITE_TRUNCATE')

  # bigqueryへ保存
  client = bigquery.Client(project=project_id)
  job = client.load_table_from_dataframe(df, f'{dataset_id}.{table_id}', job_config=job_config).result()

  # 確認メッセージ  
  table = client.get_table(f'{dataset_id}.{table_id}') 
  print("{} 件のデータを「{}」に保存しました。".format(table.num_rows, table_id))

  return

# %%
df = df_metas(data)
save_gbq(df)
# Out:
# 5257 件のデータを「categories」に保存しました。
