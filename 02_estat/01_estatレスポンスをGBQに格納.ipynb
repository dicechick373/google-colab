# %% [markdown]
# # 単体テスト

# %% [markdown]
# ## 統計データ取得

# %%
import urllib.parse
import urllib.request
import json

def get_estat_response(params):
  # appId
  params['appId'] = '724e5b90772a3e9289f41a253e4e7e32438f4fff'
  
  # url生成
  url = 'http://api.e-stat.go.jp/rest/2.1/app/json/getStatsData?'
  url += urllib.parse.urlencode(params)

  with urllib.request.urlopen(url) as response:
    return json.loads(response.read().decode('utf-8'))

# %%
params = {
    'statsDataId': '0000010101',
    'cdCat01': 'A1101',
    }

res = get_estat_response(params)
print(res)
# Out:
# {'GET_STATS_DATA': {'RESULT': {'STATUS': 0, 'ERROR_MSG': '正常に終了しました。', 'DATE': '2022-12-25T08:11:58.147+09:00'}, 'PARAMETER': {'LANG': 'J', 'STATS_DATA_ID': '0000010101', 'NARROWING_COND': {'CODE_CAT01_SELECT': 'A1101'}, 'DATA_FORMAT': 'J', 'START_POSITION': 1, 'METAGET_FLG': 'Y'}, 'STATISTICAL_DATA': {'RESULT_INF': {'TOTAL_NUMBER': 2160, 'FROM_NUMBER': 1, 'TO_NUMBER': 2160}, 'TABLE_INF': {'@id': '0000010101', 'STAT_NAME': {'@code': '00200502', '$': '社会・人口統計体系'}, 'GOV_ORG': {'@code': '00200', '$': '総務省'}, 'STATISTICS_NAME': '都道府県データ 基礎データ', 'TITLE': {'@no': '0000010101', '$': 'Ａ\u3000人口・世帯'}, 'CYCLE': '年度次', 'SURVEY_DATE': 0, 'OPEN_DATE': '2022-03-04', 'SMALL_AREA': 0, 'MAIN_CATEGORY': {'@code': '99', '$': 'その他'}, 'SUB_CATEGORY': {'@code': '99', '$': 'その他'}, 'OVERALL_TOTAL_NUMBER': 500976, 'UPDATED_DATE': '2022-03-04', 'STATISTICS_NAME_SPEC': {'TABULATION_CATEGORY': '都道府県データ', 'TABULATION_SUB_CATEGORY1': '基礎データ'}, 'TITLE_SPEC': {'TABLE_NAME': 'Ａ\u3000人口・世帯'}}, 'CLASS_INF': {'CLASS_OBJ': [{'@id': 'tab', '@name': '観測値', 'CLASS': {'@code': '00001', '@name': '観測値', '@level': '1'}}, {'@id': 'cat01', '@name': 'Ａ\u3000人口・世帯', 'CLASS': {'@code': 'A1101', '@name': 'A1101_総人口', '@level': '1', '@unit': '人'}}, {'@id': 'area', '@name': '地域', 'CLASS': [{'@code': '00000', '@name': '全国', '@level': '1'}, {'@code': '01000', '@name': '北海道', '@level': '2'}, {'@code': '02000', '@name': '青森県', '@level': '2'}, {'@code': '03000', '@name': '岩手県', '@level': '2'}, {'@code': '04000', '@name': '宮城県', '@level': '2'}, {'@code': '05000', '@name': '秋田県', '@level': '2'}, {'@code': '06000', '@name': '山形県', '@level': '2'}, {'@code': '07000', '@name': '福島県', '@level': '2'}, {'@code': '08000', '@name': '茨城県', '@level': '2'}, {'@code': '09000', '@name': '栃木県', '@level': '2'}, {'@code': '10000', '@name': '群馬県', '@level': '2'}, {'@code': '11000', '@name': '埼玉県', '@level': '2'}, {'@code': '12000', '@name': '千葉県', '@level': '2'}, {'@code': '13000', '@name': '東京都', '@level': '2'}, {'@code': '14000', '@name': '神奈川県', '@level': '2'}, {'@code': '15000', '@name': '新潟県', '@level': '2'}, {'@code': '16000', '@name': '富山県', '@level': '2'}, {'@code': '17000', '@name': '石川県', '@level': '2'}, {'@code': '18000', '@name': '福井県', '@level': '2'}, {'@code': '19000', '@name': '山梨県', '@level': '2'}, {'@code': '20000', '@name': '長野県', '@level': '2'}, {'@code': '21000', '@name': '岐阜県', '@level': '2'}, {'@code': '22000', '@name': '静岡県', '@level': '2'}, {'@code': '23000', '@name': '愛知県', '@level': '2'}, {'@code': '24000', '@name': '三重県', '@level': '2'}, {'@code': '25000', '@name': '滋賀県', '@level': '2'}, {'@code': '26000', '@name': '京都府', '@level': '2'}, {'@code': '27000', '@name': '大阪府', '@level': '2'}, {'@code': '28000', '@name': '兵庫県', '@level': '2'}, {'@code': '29000', '@name': '奈良県', '@level': '2'}, {'@code': '30000', '@name': '和歌山県', '@level': '2'}, {'@code': '31000', '@name': '鳥取県', '@level': '2'}, {'@code': '32000', '@name': '島根県', '@level': '2'}, {'@code': '33000', '@name': '岡山県', '@level': '2'}, {'@code': '34000', '@name': '広島県', '@level': '2'}, {'@code': '35000', '@name': '山口県', '@level': '2'}, {'@code': '36000', '@name': '徳島県', '@level': '2'}, {'@code': '37000', '@name': '香川県', '@level': '2'}, {'@code': '38000', '@name': '愛媛県', '@level': '2'}, {'@code': '39000', '@name': '高知県', '@level': '2'}, {'@code': '40000', '@name': '福岡県', '@level': '2'}, {'@code': '41000', '@name': '佐賀県', '@level': '2'}, {'@code': '42000', '@name': '長崎県', '@level': '2'}, {'@code': '43000', '@name': '熊本県', '@level': '2'}, {'@code': '44000', '@name': '大分県', '@level': '2'}, {'@code': '45000', '@name': '宮崎県', '@level': '2'}, {'@code': '46000', '@name': '鹿児島県', '@level': '2'}, {'@code': '47000', '@name': '沖縄県', '@level': '2'}]}, {'@id': 'time', '@name': '調査年', 'CLASS': [{'@code': '1975100000', '@name': '1975年度', '@level': '1'}, {'@code': '1976100000', '@name': '1976年度', '@level': '1'}, {'@code': '1977100000', '@name': '1977年度', '@level': '1'}, {'@code': '1978100000', '@name': '1978年度', '@level': '1'}, {'@code': ' ...

# %% [markdown]
# ### categories

# %%
import pandas as pd

def df_categories(res: dict) :
  CLASS_OBJ = res['GET_STATS_DATA']['STATISTICAL_DATA']['CLASS_INF']['CLASS_OBJ']
  categories = list(filter(lambda x: x['@id'] == 'cat01', CLASS_OBJ))[0]['CLASS']
  
  # DataFrameに変換
  df = pd.DataFrame(categories) if type(categories) is list else pd.DataFrame([categories])

  # 列の整理
  columns = {'@code':'categoryCode','@name':'categoryName'}
  df = df[list(columns.keys())].rename(columns = columns)
  
  # categoryNameから不要な情報（categoryCode）を削除
  df['categoryName'] = df.apply(lambda x: x['categoryName'].replace(x['categoryCode']+'_', ''), 1)

  return df

# %%
df_categories(res)
# Out:
#   categoryCode categoryName
# 0        A1101          総人口

# %% [markdown]
# ### areas

# %%
def df_areas(res: dict) :
  CLASS_OBJ = res['GET_STATS_DATA']['STATISTICAL_DATA']['CLASS_INF']['CLASS_OBJ']
  areas = list(filter(lambda x: x['@id'] == 'area', CLASS_OBJ))[0]['CLASS']

  # DataFrameに変換
  df = pd.DataFrame(areas) if type(areas) is list else pd.DataFrame([areas])

  # 列の整理
  columns = {'@code':'areaCode','@name':'areaName'}
  df = df[list(columns.keys())].rename(columns = columns)

  return df

# %%
df_areas(res)

# %% [markdown]
# ### times

# %%
def df_times(res: dict) -> list:
  CLASS_OBJ = res['GET_STATS_DATA']['STATISTICAL_DATA']['CLASS_INF']['CLASS_OBJ']
  times = list(filter(lambda x: x['@id'] == 'time', CLASS_OBJ))[0]['CLASS']

  # DataFrameに変換
  df = pd.DataFrame(times) if type(times) is list else pd.DataFrame([times])

  # 列の整理
  columns = {'@code':'timeCode','@name':'timeName'}
  df = df[list(columns.keys())].rename(columns = columns)

  return df

# %%
df_times(res)
# Out:
#       timeCode timeName
# 0   1975100000   1975年度
# 1   1976100000   1976年度
# 2   1977100000   1977年度
# 3   1978100000   1978年度
# 4   1979100000   1979年度
# 5   1980100000   1980年度
# 6   1981100000   1981年度
# 7   1982100000   1982年度
# 8   1983100000   1983年度
# 9   1984100000   1984年度
# 10  1985100000   1985年度
# 11  1986100000   1986年度
# 12  1987100000   1987年度
# 13  1988100000   1988年度
# 14  1989100000   1989年度
# 15  1990100000   1990年度
# 16  1991100000   1991年度
# 17  1992100000   1992年度
# 18  1993100000   1993年度
# 19  1994100000   1994年度
# 20  1995100000   1995年度
# 21  1996100000   1996年度
# 22  1997100000   1997年度
# 23  1998100000   1998年度
# 24  1999100000   1999年度
# 25  2000100000   2000年度
# 26  2001100000   2001年度
# 27  2002100000   2002年度
# 28  2003100000   2003年度
# 29  2004100000   2004年度
# 30  2005100000   2005年度
# 31  2006100000   2006年度
# 32  2007100000   2007年度
# 33  2008100000   2008年度
# 34  2009100000   2009年度
# 35  2010100000   2010年度
# 36  2011100000   2011年度
# 37  2012100000   2012年度
# 38  2013100000   2013年度
# 39  2014100000   2014年度
# 40  2015100000   2015年度
# 41  2016100000   2016年度
# 42  2017100000   2017年度
# 43  2018100000   2018年度
# 44  2019100000   2019年度
# 45  2020100000   2020年度

# %% [markdown]
# ### formated Data

# %%
import pandas as pd

def df_data(res):
  VALUE = res['GET_STATS_DATA']['STATISTICAL_DATA']['DATA_INF']['VALUE']
  
  # DataFrameに変換
  df = pd.DataFrame(VALUE)

  # 欠損値の処理
  df = df.dropna().replace('-', '0').replace('X', '0')
  
  # 列の整理
  columns = {'@cat01':'categoryCode','@area':'areaCode','@time':'timeCode','$':'value','@unit':'unit'}
  df = df[list(columns.keys())].rename(columns = columns)
  
  # merge
  df = pd.merge(df, df_categories(res), on='categoryCode', how='left')
  df = pd.merge(df, df_areas(res), on='areaCode', how='left')
  df = pd.merge(df, df_times(res), on='timeCode', how='left')
  
  # 型変換
  if isinstance(float(df.iloc[1,3]), int):
    df = df.astype({'value': int})
  else:
    df = df.astype({'value': float})

  return df

# %%
params = {
    'statsDataId': '0000010101',
    'cdCat01': 'A1231',
    }
res = get_estat_response(params)

# print(df_data(res).dtypes)
df_data(res).head()
# Out:
#   categoryCode areaCode    timeCode  value unit categoryName areaName timeName
# 0        A1231    00000  2010100000   45.0    歳        年齢中位数       全国   2010年度
# 1        A1231    00000  2015100000   46.7    歳        年齢中位数       全国   2015年度
# 2        A1231    01000  2010100000   47.7    歳        年齢中位数      北海道   2010年度
# 3        A1231    01000  2015100000   49.7    歳        年齢中位数      北海道   2015年度
# 4        A1231    02000  2010100000   49.1    歳        年齢中位数      青森県   2010年度

# %% [markdown]
# ## メタ情報

# %%
import urllib.parse
import urllib.request
import json

def get_estat_meta(statsDataId):
  params ={
      'statsDataId': statsDataId,
      'appId': '724e5b90772a3e9289f41a253e4e7e32438f4fff',
  }

  url = 'http://api.e-stat.go.jp/rest/3.0/app/json/getMetaInfo?'
  url += urllib.parse.urlencode(params)

  with urllib.request.urlopen(url) as response:
    return json.loads(response.read().decode('utf-8'))

# %%
meta = get_estat_meta('0000010101')
print(meta)

# %% [markdown]
# ### カテゴリ情報

# %%
def catelgoryCodes(statsDataId):
  # メタ情報の取得
  meta= get_estat_meta(statsDataId)

  # CLASS_OBJ
  CLASS_OBJ = meta['GET_META_INFO']['METADATA_INF']['CLASS_INF']['CLASS_OBJ']
  cat01 = next((d for d in CLASS_OBJ if d['@id'] == 'cat01'), None)['CLASS']
  
  return [d.get('@code') for d in cat01]

# %%
print(catelgoryCodes('0000010101'))

# %% [markdown]
# ## BigQueryへの登録

# %% [markdown]
# ### ライブラリ

# %% [markdown]
# pandas-gbqではなくgoogle-cloud-bigqueryを使う
#
# https://cloud.google.com/bigquery/docs/pandas-gbq-migration?hl=ja

# %%
# !pip install --upgrade 'google-cloud-bigquery[bqstorage,pandas]'
# !pip install pyarrow

# %% [markdown]
# ### GCP認証

# %%
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# ### プロジェクト設定

# %%
project_id='primal-buttress-342908'
dataset_id = 'estat_origin'

# %% [markdown]
# ### GBQに保存する関数

# %%
from google.cloud import bigquery

def estat_to_gbq(params):
  # estatレスポンスの取得
  res = get_estat_response(params)
  
  # Dataframe作成  
  df = df_data(res)
  
  # table設定
  table_id = params['statsDataId'] + '_' + params['cdCat01']
  
  # スキーマ
  job_config = bigquery.LoadJobConfig(write_disposition='WRITE_TRUNCATE')

  # bigqueryへ保存
  client = bigquery.Client(project=project_id)
  job = client.load_table_from_dataframe(df, f'{dataset_id}.{table_id}', job_config=job_config).result()

  # 確認メッセージ  
  table = client.get_table(f'{dataset_id}.{table_id}') 
  print("{} 件のデータを「{}」に保存しました。".format(table.num_rows, table_id))
  
  return

# %%
params = {
    'statsDataId': '0000020201',
    'cdCat01': 'A1101',
    }

estat_to_gbq(params)
# Out:
# 15313 件のデータを「0000020201_A1101」に保存しました。

# %% [markdown]
# # 一括処理

# %%
from google.cloud import bigquery
from google.cloud.exceptions import NotFound

def save_gbq(data):
  for statsDataId in data:
    for c in catelgoryCodes(statsDataId):
      params = {
          'statsDataId': statsDataId,
          'cdCat01': c,
      }

      client = bigquery.Client(project=project_id)
      table_id = params['statsDataId'] + '_' + params['cdCat01'] 
      
      try:
        client.get_table(f'{dataset_id}.{table_id}')  
        print("Table {} already exists.".format(table_id))
      except NotFound:
        estat_to_gbq(params)

# %% [markdown]
# ## 社会・人口統計体系（都道府県）

# %% [markdown]
# https://www.e-stat.go.jp/stat-search/database?page=1&layout=datalist&toukei=00200502&tstat=000001111375&cycle=8&tclass1=000001111377&tclass2val=0

# %%
# 統計表のリスト
data = ['0000010101', '0000010102', '0000010103', '0000010104', '0000010105', '0000010106', '0000010107', 
        '0000010108', '0000010109', '0000010110', '0000010111', '0000010112', '0000010113']

# %% [markdown]
# ## メタ情報をGBQに保存

# %% [markdown]
# ## データをGBQに保存

# %%
save_gbq(data)

# %% [markdown]
# ## 社会・人口統計体系（市区町村）

# %% [markdown]
# https://www.e-stat.go.jp/stat-search/database?page=1&layout=datalist&toukei=00200502&tstat=000001111376&cycle=8&tclass1=000001111380&collect_area=200&result_page=1&tclass2val=0

# %%
# 統計表のリスト
data = ['0000020201', '0000020202', '0000020203', '0000020204', '0000020205', '0000020206', 
        '0000020207', '0000020208', '0000020209', '0000020210', '0000020211']
save_gbq(data)
# Out:
# Table 0000020201_A1101 already exists.
# 7668 件のデータを「0000020201_A110101」に保存しました。
# 7668 件のデータを「0000020201_A110102」に保存しました。
# 7668 件のデータを「0000020201_A1102」に保存しました。
# 7668 件のデータを「0000020201_A110201」に保存しました。
# 7668 件のデータを「0000020201_A110202」に保存しました。
# 3834 件のデータを「0000020201_A1231」に保存しました。
# 15313 件のデータを「0000020201_A1301」に保存しました。
# 7668 件のデータを「0000020201_A130101」に保存しました。
# 7668 件のデータを「0000020201_A130102」に保存しました。
# 15313 件のデータを「0000020201_A1302」に保存しました。
# 7668 件のデータを「0000020201_A130201」に保存しました。
# 7668 件のデータを「0000020201_A130202」に保存しました。
# 15313 件のデータを「0000020201_A1303」に保存しました。
# 7668 件のデータを「0000020201_A130301」に保存しました。
# 7668 件のデータを「0000020201_A130302」に保存しました。
# 7668 件のデータを「0000020201_A1401」に保存しました。
# 7668 件のデータを「0000020201_A140101」に保存しました。
# 7668 件のデータを「0000020201_A140102」に保存しました。
# 7668 件のデータを「0000020201_A1402」に保存しました。
# 7668 件のデータを「0000020201_A140201」に保存しました。
# 7668 件のデータを「0000020201_A140202」に保存しました。
# 7668 件のデータを「0000020201_A1403」に保存しました。
# 7668 件のデータを「0000020201_A140301」に保存しました。
# 7668 件のデータを「0000020201_A140302」に保存しました。
# 7668 件のデータを「0000020201_A1404」に保存しました。
# 7668 件のデータを「0000020201_A140401」に保存しました。
# 7668 件のデータを「0000020201_A140402」に保存しました。
# 7668 件のデータを「0000020201_A1405」に保存しました。
# 7668 件のデータを「0000020201_A140501」に保存しました。
# 7668 件のデータを「0000020201_A140502」に保存しました。
# 7668 件のデータを「0000020201_A1406」に保存しました。
# 7668 件のデータを「0000020201_A140601」に保存しました。
# 7668 件のデータを「0000020201_A140602」に保存しました。
# 7668 件のデータを「0000020201_A1407」に保存しました。
# 7668 件のデータを「0000020201_A140701」に保存しました。
# 7668 件のデータを「0000020201_A140702」に保存しました。
# 7668 件のデータを「0000020201_A1408」に保存しました。
# 7668 件のデータを「0000020201_A140801」に保存しました。
# 7668 件のデータを「0000020201_A140802」に保存しました。
# 7668 件のデータを「0000020201_A1409」に保存しました。
# 7668 件のデータを「0000020201_A140901」に保存しました。
# 7668 件のデータを「0000020201_A140902」に保存しました。
# 7668 件のデータを「0000020201_A1410」に保存しました。
# 7668 件のデータを「0000020201_A141001」に保存しました。
# 7668 件のデータを「0000020201_A141002」に保存しました。
# 7668 件のデータを「0000020201_A1411」に保存しました。
# 7668 件のデータを「0000020201_A141101」に保存しました。
# 7668 件のデータを「0000020201_A141102」に保存しました。
# 7668 件のデータを「0000020201_A1412」に保存しました。
# 7668 件のデータを「0000020201_A141201」に保存しました。
# 7668 件のデータを「0000020201_A141202」に保存しました。
# 7668 件のデータを「0000020201_A1413」に保存しました。
# 7668 件のデータを「0000020201_A141301」に保存しました。
# 7668 件のデータを「0000020201_A141302」に保存しました。
# 7668 件のデータを「0000020201_A1414」に保存しました。
# 7668 件のデータを「0000020201_A141401」に保存しました。
# 7668 件のデータを「0000020201_A141402」に保存しました。
# 7668 件のデータを「0000020201_A1415」に保存しました。
# 7668 件のデータを「0000020201_A141501」に保存しました。
# 7668 件のデータを「0000020201_A141502」に保存しました。
# 7668 件のデータを「0000020201_A1416」に保存しました。
# 7668 件のデータを「0000020201_A141601」に保存しました。
# 7668 件のデータを「0000020201_A141602」に保存しました。
# 7668 件のデータを「0000020201_A1417」に保存しました。
# 7668 件のデータを「0000020201_A141701」に保存しました。
# 7668 件のデータを「0000020201_A141702」に保存しました。
# 7668 件のデータを「0000020201_A1418」に保存しました。
# 7668 件のデータを「0000020201_A141801」に保存しました。
# 7668 件のデータを「0000020201_A141802」に保存しました。
# 1917 件のデータを「0000020201_A1419」に保存しました。
# 1917 件のデータを「0000020201_A141901」に保存しました。
# 1917 件のデータを「0000020201_A141902」に保存しました。
# 1917 件のデータを「0000020201_A1420」に保存しました。
# 1917 件のデータを「0000020201_A142001」に保存しました。
# 1917 件のデータを「0000020201_A142002」に保存しました。
# 1917 件のデータを「0000020201_A161001」に保存しました。
# 15313 件のデータを「0000020201_A1700」に保存しました。
# 15313 件のデータを「0000020201_A1801」に保存しました。
# 7668 件のデータを「0000020201_A180101」に保存しました。
# 7668 件のデータを「0000020201_A180102」に保存しました。
# 7668 件のデータを「0000020201_A1802」に保存しました。
# 1917 件のデータを「0000020201_A191001」に保存しました。
# 1917 件のデータを「0000020201_A191002」に保存しました。
# 1917 件のデータを「0000020201_A191003」に保存しました。
# 1917 件のデータを「0000020201_A191004」に保存しました。
# 1917 件のデータを「0000020201_A191005」に保存しました。
# 1917 件のデータを「0000020201_A191006」に保存しました。
# 40257 件のデータを「0000020201_A2101」に保存しました。
# 40257 件のデータを「0000020201_A210101」に保存しました。
# 40257 件のデータを「0000020201_A210102」に保存しました。
# 15336 件のデータを「0000020201_A2201」に保存しました。
# 17253 件のデータを「0000020201_A2301」に保存しました。
# 49840 件のデータを「0000020201_A4101」に保存しました。
# 78506 件のデータを「0000020201_A4200」に保存しました。
# 47924 件のデータを「0000020201_A5101」に保存しました。
# 47923 件のデータを「0000020201_A5102」に保存しました。
# 5751 件のデータを「0000020201_A5103」に保存しました。
# 5751 件のデータを「0000020201_A5104」に保存しました。
# 15313 件のデータを「0000020201_A6101」に保存しました。
# 15313 件のデータを「0000020201_A6102」に保存しました。
# 15313 件のデータを「0000020201_A6103」に保存しました。
# 15313 件のデータを「0000020201_A6104」に保存しました。
# 15313 件のデータを「0000020201_A6105」に保存しました。
# 15313 件のデータを「0000020201_A6106」に保存しました。
# 15313 件のデータを「0000020201_A6107」に保存しました。
# 7668 件のデータを「0000020201_A6108」に保存しました。
# 15313 件のデータを「0000020201_A7101」に保存しました。
# 13408 件のデータを「0000020201_A710101」に保存しました。
# 7668 件のデータを「0000020201_A710102」に保存しました。
# 7668 件のデータを「0000020201_A710201」に保存しました。
# 7668 件のデータを「0000020201_A710202」に保存しました。
# 40257 件のデータを「0000020201_A7103」に保存しました。
# 7668 件のデータを「0000020201_A810101」に保存しました。
# 15313 件のデータを「0000020201_A810102」に保存しました。
# 7668 件のデータを「0000020201_A810103」に保存しました。
# 7668 件のデータを「0000020201_A810104」に保存しました。
# 15313 件のデータを「0000020201_A810105」に保存しました。
# 15313 件のデータを「0000020201_A811102」に保存しました。
# 11498 件のデータを「0000020201_A8201」に保存しました。
# 15313 件のデータを「0000020201_A8301」に保存しました。
# 7668 件のデータを「0000020201_A830101」に保存しました。
# 7668 件のデータを「0000020201_A830102」に保存しました。
# 7668 件のデータを「0000020201_A8401」に保存しました。
# 7668 件のデータを「0000020201_A840101」に保存しました。
# 7668 件のデータを「0000020201_A840102」に保存しました。
# 7668 件のデータを「0000020201_A840103」に保存しました。
# 7668 件のデータを「0000020201_A8501」に保存しました。
# 7668 件のデータを「0000020201_A850101」に保存しました。
# 7668 件のデータを「0000020201_A850102」に保存しました。
# 7668 件のデータを「0000020201_A850103」に保存しました。
# 78508 件のデータを「0000020201_A9101」に保存しました。
# 78509 件のデータを「0000020201_A9201」に保存しました。
# 76602 件のデータを「0000020202_B1101」に保存しました。
# 40257 件のデータを「0000020202_B1102」に保存しました。
# 76602 件のデータを「0000020202_B1103」に保存しました。
# 59409 件のデータを「0000020202_B1104」に保存しました。
# 11455 件のデータを「0000020202_B1105」に保存しました。
# 11455 件のデータを「0000020202_B1106」に保存しました。
# 11456 件のデータを「0000020202_B1107」に保存しました。
# 38340 件のデータを「0000020202_B1201」に保存しました。
# 38340 件のデータを「0000020202_B120103」に保存しました。
# 68972 件のデータを「0000020203_C120110」に保存しました。
# 68972 件のデータを「0000020203_C120120」に保存しました。
# 21087 件のデータを「0000020203_C120130」に保存しました。
# 11479 件のデータを「0000020203_C2101」に保存しました。
# 11479 件のデータを「0000020203_C2104」に保存しました。
# 11479 件のデータを「0000020203_C2105」に保存しました。
# 5751 件のデータを「0000020203_C2107」に保存しました。
# 3834 件のデータを「0000020203_C210701」に保存しました。
# 3834 件のデータを「0000020203_C210702」に保存しました。
# 3834 件のデータを「0000020203_C210703」に保存しました。
# 3834 件のデータを「0000020203_C210704」に保存しました。
# 3834 件のデータを「0000020203_C210705」に保存しました。
# 3834 件のデータを「0000020203_C210706」に保存しました。
# 3834 件のデータを「0000020203_C210707」に保存しました。
# 3834 件のデータを「0000020203_C210708」に保存しました。
# 3834 件のデータを「0000020203_C210709」に保存しました。
# 3834 件のデータを「0000020203_C210710」に保存しました。
# 3834 件のデータを「0000020203_C210711」に保存しました。
# 3834 件のデータを「0000020203_C210712」に保存しました。
# 3834 件のデータを「0000020203_C210713」に保存しました。
# 3834 件のデータを「0000020203_C210714」に保存しました。
# 3834 件のデータを「0000020203_C210715」に保存しました。
# 3834 件のデータを「0000020203_C210716」に保存しました。
# 3834 件のデータを「0000020203_C210717」に保存しました。
# 3834 件のデータを「0000020203_C210718」に保存しました。
# 3834 件のデータを「0000020203_C210719」に保存しました。
# 3834 件のデータを「0000020203_C210720」に保存しました。
# 3834 件のデータを「0000020203_C210721」に保存しました。
# 3834 件のデータを「0000020203_C210722」に保存しました。
# 3834 件のデータを「0000020203_C210723」に保存しました。
# 3834 件のデータを「0000020203_C210724」に保存しました。
# 3834 件のデータを「0000020203_C210725」に保存しました。
# 7668 件のデータを「0000020203_C2108」に保存しました。
# 7668 件のデータを「0000020203_C210801」に保存しました。
# 7668 件のデータを「0000020203_C210802」に保存しました。
# 7668 件のデータを「0000020203_C210803」に保存しました。
# 7668 件のデータを「0000020203_C210804」に保存しました。
# 7668 件のデータを「0000020203_C210805」に保存しました。
# 7668 件のデータを「0000020203_C210820」に保存しました。
# 7668 件のデータを「0000020203_C210821」に保存しました。
# 7668 件のデータを「0000020203_C210822」に保存しました。
# 7668 件のデータを「0000020203_C210823」に保存しました。
# 5751 件のデータを「0000020203_C210831」に保存しました。
# 5751 件のデータを「0000020203_C210832」に保存しました。
# 5751 件のデータを「0000020203_C210833」に保存しました。
# 5751 件のデータを「0000020203_C210834」に保存しました。
# 5751 件のデータを「0000020203_C210835」に保存しました。
# 5751 件のデータを「0000020203_C210836」に保存しました。
# 5751 件のデータを「0000020203_C210837」に保存しました。
# 5751 件のデータを「0000020203_C210838」に保存しました。
# 5751 件のデータを「0000020203_C210839」に保存しました。
# 5751 件のデータを「0000020203_C210840」に保存しました。
# 5751 件のデータを「0000020203_C210841」に保存しました。
# 5751 件のデータを「0000020203_C210842」に保存しました。
# 5751 件のデータを「0000020203_C210843」に保存しました。
# 5751 件のデータを「0000020203_C210844」に保存しました。
# 5751 件のデータを「0000020203_C210845」に保存しました。
# 5751 件のデータを「0000020203_C210846」に保存しました。
# 5751 件のデータを「0000020203_C210847」に保存しました。
# 5751 件のデータを「0000020203_C210848」に保存しました。
# 5751 件のデータを「0000020203_C210849」に保存しました。
# 5751 件のデータを「0000020203_C210850」に保存しました。
# 5751 件のデータを「0000020203_C210851」に保存しました。
# 5751 件のデータを「0000020203_C210852」に保存しました。
# 5751 件のデータを「0000020203_C2109」に保存しました。
# 3834 件のデータを「0000020203_C210901」に保存しました。
# 3834 件のデータを「0000020203_C210902」に保存しました。
# 3834 件のデータを「0000020203_C210903」に保存しました。
# 3834 件のデータを「0000020203_C210904」に保存しました。
# 3834 件のデータを「0000020203_C2110」に保存しました。
# 3834 件のデータを「0000020203_C2111」に保存しました。
# 3834 件のデータを「0000020203_C2112」に保存しました。
# 11479 件のデータを「0000020203_C2201」に保存しました。
# 11479 件のデータを「0000020203_C2204」に保存しました。
# 11479 件のデータを「0000020203_C2205」に保存しました。
# 3834 件のデータを「0000020203_C2207」に保存しました。
# 3834 件のデータを「0000020203_C220701」に保存しました。
# 3834 件のデータを「0000020203_C220702」に保存しました。
# 3834 件のデータを「0000020203_C220703」に保存しました。
# 3834 件のデータを「0000020203_C220704」に保存しました。
# 3834 件のデータを「0000020203_C220705」に保存しました。
# 3834 件のデータを「0000020203_C220706」に保存しました。
# 3834 件のデータを「0000020203_C220707」に保存しました。
# 3834 件のデータを「0000020203_C220708」に保存しました。
# 3834 件のデータを「0000020203_C220709」に保存しました。
# 3834 件のデータを「0000020203_C220710」に保存しました。
# 3834 件のデータを「0000020203_C220711」に保存しました。
# 3834 件のデータを「0000020203_C220712」に保存しました。
# 3834 件のデータを「0000020203_C220713」に保存しました。
# 3834 件のデータを「0000020203_C220714」に保存しました。
# 3834 件のデータを「0000020203_C220715」に保存しました。
# 3834 件のデータを「0000020203_C220716」に保存しました。
# 3834 件のデータを「0000020203_C220717」に保存しました。
# 3834 件のデータを「0000020203_C220718」に保存しました。
# 3834 件のデータを「0000020203_C220719」に保存しました。
# 3834 件のデータを「0000020203_C220720」に保存しました。
# 3834 件のデータを「0000020203_C220721」に保存しました。
# 3834 件のデータを「0000020203_C220722」に保存しました。
# 3834 件のデータを「0000020203_C220723」に保存しました。
# 3834 件のデータを「0000020203_C220724」に保存しました。
# 3834 件のデータを「0000020203_C220725」に保存しました。
# 7668 件のデータを「0000020203_C2208」に保存しました。
# 7668 件のデータを「0000020203_C220801」に保存しました。
# 7668 件のデータを「0000020203_C220802」に保存しました。
# 7668 件のデータを「0000020203_C220803」に保存しました。
# 7668 件のデータを「0000020203_C220804」に保存しました。
# 7668 件のデータを「0000020203_C220805」に保存しました。
# 7668 件のデータを「0000020203_C220820」に保存しました。
# 7668 件のデータを「0000020203_C220821」に保存しました。
# 7668 件のデータを「0000020203_C220822」に保存しました。
# 7668 件のデータを「0000020203_C220823」に保存しました。
# 5751 件のデータを「0000020203_C220831」に保存しました。
# 5751 件のデータを「0000020203_C220832」に保存しました。
# 5751 件のデータを「0000020203_C220833」に保存しました。
# 5751 件のデータを「0000020203_C220834」に保存しました。
# 5751 件のデータを「0000020203_C220835」に保存しました。
# 5751 件のデータを「0000020203_C220836」に保存しました。
# 5751 件のデータを「0000020203_C220837」に保存しました。
# 5751 件のデータを「0000020203_C220838」に保存しました。
# 5751 件のデータを「0000020203_C220839」に保存しました。
# 5751 件のデータを「0000020203_C220840」に保存しました。
# 5751 件のデータを「0000020203_C220841」に保存しました。
# 5751 件のデータを「0000020203_C220842」に保存しました。
# 5751 件のデータを「0000020203_C220843」に保存しました。
# 5751 件のデータを「0000020203_C220844」に保存しました。
# 5751 件のデータを「0000020203_C220845」に保存しました。
# 5751 件のデータを「0000020203_C220846」に保存しました。
# 5751 件のデータを「0000020203_C220847」に保存しました。
# 5751 件のデータを「0000020203_C220848」に保存しました。
# 5751 件のデータを「0000020203_C220849」に保存しました。
# 5751 件のデータを「0000020203_C220850」に保存しました。
# 5751 件のデータを「0000020203_C220851」に保存しました。
# 5751 件のデータを「0000020203_C220852」に保存しました。
# 3834 件のデータを「0000020203_C2209」に保存しました。
# 3834 件のデータを「0000020203_C220901」に保存しました。
# 3834 件のデータを「0000020203_C220902」に保存しました。
# 3834 件のデータを「0000020203_C220903」に保存しました。
# 3834 件のデータを「0000020203_C220904」に保存しました。
# 3834 件のデータを「0000020203_C2210」に保存しました。
# 3834 件のデータを「0000020203_C2211」に保存しました。
# 3834 件のデータを「0000020203_C2212」に保存しました。
# 51610 件のデータを「0000020203_C3101」に保存しました。
# 7668 件のデータを「0000020203_C310201」に保存しました。
# 7668 件のデータを「0000020203_C310202」に保存しました。
# 7668 件のデータを「0000020203_C310211」に保存しました。
# 7668 件のデータを「0000020203_C310212」に保存しました。
# 78493 件のデータを「0000020203_C3107」に保存しました。
# 3834 件のデータを「0000020203_C3109」に保存しました。
# 76491 件のデータを「0000020203_C3401」に保存しました。
# 38338 件のデータを「0000020203_C3403」に保存しました。
# 76487 件のデータを「0000020203_C3404」に保存しました。
# 24891 件のデータを「0000020203_C3501」に保存しました。
# 11502 件のデータを「0000020203_C350101」に保存しました。
# 11502 件のデータを「0000020203_C350102」に保存しました。
# 24891 件のデータを「0000020203_C3502」に保存しました。
# 11502 件のデータを「0000020203_C350201」に保存しました。
# 11502 件のデータを「0000020203_C350202」に保存しました。
# 24891 件のデータを「0000020203_C3503」に保存しました。
# 11502 件のデータを「0000020203_C350301」に保存しました。
# 11502 件のデータを「0000020203_C350302」に保存しました。
# 32581 件のデータを「0000020203_C5401」に保存しました。
# 32581 件のデータを「0000020203_C5403」に保存しました。
# 24913 件のデータを「0000020203_C5405」に保存しました。
# 5751 件のデータを「0000020203_C6101」に保存しました。
# 5751 件のデータを「0000020203_C610101」に保存しました。
# 5751 件のデータを「0000020203_C610104」に保存しました。
# 5751 件のデータを「0000020203_C610105」に保存しました。
# 5751 件のデータを「0000020203_C610106」に保存しました。
# 5751 件のデータを「0000020203_C610107」に保存しました。
# 5751 件のデータを「0000020203_C610108」に保存しました。
# 5751 件のデータを「0000020203_C610109」に保存しました。
# 5751 件のデータを「0000020203_C610110」に保存しました。
# 5751 件のデータを「0000020203_C610111」に保存しました。
# 5751 件のデータを「0000020203_C610114」に保存しました。
# 5751 件のデータを「0000020203_C610115」に保存しました。
# 5751 件のデータを「0000020203_C610116」に保存しました。
# 5751 件のデータを「0000020203_C610117」に保存しました。
# 5751 件のデータを「0000020203_C610118」に保存しました。
# 5751 件のデータを「0000020203_C610119」に保存しました。
# 5751 件のデータを「0000020203_C610120」に保存しました。
# 5751 件のデータを「0000020203_C610121」に保存しました。
# 5751 件のデータを「0000020203_C610122」に保存しました。
# 3834 件のデータを「0000020203_C620101」に保存しました。
# 3834 件のデータを「0000020203_C620105」に保存しました。
# 3834 件のデータを「0000020203_C620106」に保存しました。
# 3834 件のデータを「0000020203_C620107」に保存しました。
# 3834 件のデータを「0000020203_C620108」に保存しました。
# 3834 件のデータを「0000020203_C620109」に保存しました。
# 3834 件のデータを「0000020203_C620110」に保存しました。
# 3834 件のデータを「0000020203_C620111」に保存しました。
# 3834 件のデータを「0000020203_C620114」に保存しました。
# 3834 件のデータを「0000020203_C620115」に保存しました。
# 3834 件のデータを「0000020203_C620116」に保存しました。
# 3834 件のデータを「0000020203_C620117」に保存しました。
# 3834 件のデータを「0000020203_C620118」に保存しました。
# 3834 件のデータを「0000020203_C620119」に保存しました。
# 3834 件のデータを「0000020203_C620120」に保存しました。
# 3834 件のデータを「0000020203_C620121」に保存しました。
# 3834 件のデータを「0000020203_C620122」に保存しました。
# 40257 件のデータを「0000020204_D1202」に保存しました。
# 76590 件のデータを「0000020204_D2201」に保存しました。
# 76590 件のデータを「0000020204_D2202」に保存しました。
# 38340 件のデータを「0000020204_D2203」に保存しました。
# 53585 件のデータを「0000020204_D2204」に保存しました。
# 38340 件のデータを「0000020204_D2205」に保存しました。
# 38340 件のデータを「0000020204_D2206」に保存しました。
# 38340 件のデータを「0000020204_D2209」に保存しました。
# 38340 件のデータを「0000020204_D2210」に保存しました。
# 23004 件のデータを「0000020204_D2211」に保存しました。
# 17253 件のデータを「0000020204_D2212」に保存しました。
# 7668 件のデータを「0000020204_D2213」に保存しました。
# 7668 件のデータを「0000020204_D2214」に保存しました。
# 7668 件のデータを「0000020204_D2215」に保存しました。
# 76591 件のデータを「0000020204_D3201」に保存しました。
# 76590 件のデータを「0000020204_D320101」に保存しました。
# 38340 件のデータを「0000020204_D320102」に保存しました。
# 38340 件のデータを「0000020204_D320103」に保存しました。
# 38340 件のデータを「0000020204_D320104」に保存しました。
# 44091 件のデータを「0000020204_D320105」に保存しました。
# 38340 件のデータを「0000020204_D320106」に保存しました。
# 9887 件のデータを「0000020204_D320107」に保存しました。
# 38340 件のデータを「0000020204_D320108」に保存しました。
# 38340 件のデータを「0000020204_D320109」に保存しました。
# 38340 件のデータを「0000020204_D320110」に保存しました。
# 38340 件のデータを「0000020204_D320111」に保存しました。
# 38340 件のデータを「0000020204_D320113」に保存しました。
# 38340 件のデータを「0000020204_D320115」に保存しました。
# 28755 件のデータを「0000020204_D320116」に保存しました。
# 28755 件のデータを「0000020204_D320117」に保存しました。
# 44091 件のデータを「0000020204_D320118」に保存しました。
# 38340 件のデータを「0000020204_D320119」に保存しました。
# 44091 件のデータを「0000020204_D320120」に保存しました。
# 38340 件のデータを「0000020204_D320121」に保存しました。
# 38340 件のデータを「0000020204_D320122」に保存しました。
# 38340 件のデータを「0000020204_D3202」に保存しました。
# 76592 件のデータを「0000020204_D3203」に保存しました。
# 38340 件のデータを「0000020204_D320301」に保存しました。
# 38340 件のデータを「0000020204_D320302」に保存しました。
# 38340 件のデータを「0000020204_D320303」に保存しました。
# 38340 件のデータを「0000020204_D3203031」に保存しました。
# 44091 件のデータを「0000020204_D3203032」に保存しました。
# 76595 件のデータを「0000020204_D3203033」に保存しました。
# 38340 件のデータを「0000020204_D3203034」に保存しました。
# 38340 件のデータを「0000020204_D3203035」に保存しました。
# 38340 件のデータを「0000020204_D320304」に保存しました。
# 38340 件のデータを「0000020204_D3203042」に保存しました。
# 38340 件のデータを「0000020204_D3203043」に保存しました。
# 38340 件のデータを「0000020204_D3203044」に保存しました。
# 38340 件のデータを「0000020204_D320305」に保存しました。
# 19170 件のデータを「0000020204_D3203051」に保存しました。
# 38340 件のデータを「0000020204_D320306」に保存しました。
# 38340 件のデータを「0000020204_D320307」に保存しました。
# 38340 件のデータを「0000020204_D320308」に保存しました。
# 38340 件のデータを「0000020204_D3203082」に保存しました。
# 38340 件のデータを「0000020204_D3203085」に保存しました。
# 38340 件のデータを「0000020204_D3203086」に保存しました。
# 38340 件のデータを「0000020204_D320309」に保存しました。
# 38340 件のデータを「0000020204_D320310」に保存しました。
# 38340 件のデータを「0000020204_D3203102」に保存しました。
# 38340 件のデータを「0000020204_D3203103」に保存しました。
# 38340 件のデータを「0000020204_D3203104」に保存しました。
# 38340 件のデータを「0000020204_D3203105」に保存しました。
# 38340 件のデータを「0000020204_D3203106」に保存しました。
# 38340 件のデータを「0000020204_D3203107」に保存しました。
# 38340 件のデータを「0000020204_D3203108」に保存しました。
# 38340 件のデータを「0000020204_D320311」に保存しました。
# 38340 件のデータを「0000020204_D320312」に保存しました。
# 38340 件のデータを「0000020204_D320401」に保存しました。
# 38340 件のデータを「0000020204_D320402」に保存しました。
# 38340 件のデータを「0000020204_D320403」に保存しました。
# 38340 件のデータを「0000020204_D320404」に保存しました。
# 38340 件のデータを「0000020204_D320405」に保存しました。
# 38340 件のデータを「0000020204_D320406」に保存しました。
# 38340 件のデータを「0000020204_D320407」に保存しました。
# 19170 件のデータを「0000020204_D320408」に保存しました。
# 38340 件のデータを「0000020204_D320409」に保存しました。
# 38340 件のデータを「0000020204_D320410」に保存しました。
# 38340 件のデータを「0000020204_D320411」に保存しました。
# 38340 件のデータを「0000020204_D320412」に保存しました。
# 19170 件のデータを「0000020204_D3205」に保存しました。
# 19120 件のデータを「0000020204_D420102」に保存しました。
# 19120 件のデータを「0000020204_D420202」に保存しました。
# 17253 件のデータを「0000020204_D430103」に保存しました。
# 17253 件のデータを「0000020204_D430203」に保存しました。
# 78510 件のデータを「0000020205_E1101」に保存しました。
# 78510 件のデータを「0000020205_E1501」に保存しました。
# 78510 件のデータを「0000020205_E2101」に保存しました。
# 78510 件のデータを「0000020205_E2401」に保存しました。
# 78510 件のデータを「0000020205_E2501」に保存しました。
# 78510 件のデータを「0000020205_E3101」に保存しました。
# 78510 件のデータを「0000020205_E3401」に保存しました。
# 78510 件のデータを「0000020205_E3501」に保存しました。
# 3834 件のデータを「0000020205_E3901」に保存しました。
# 3834 件のデータを「0000020205_E3902」に保存しました。
# 3834 件のデータを「0000020205_E3903」に保存しました。
# 3834 件のデータを「0000020205_E3904」に保存しました。
# 3834 件のデータを「0000020205_E3905」に保存しました。
# 3834 件のデータを「0000020205_E3906」に保存しました。
# 78510 件のデータを「0000020205_E4101」に保存しました。
# 78510 件のデータを「0000020205_E4501」に保存しました。
# 3834 件のデータを「0000020205_E9101」に保存しました。
# 3834 件のデータを「0000020205_E9102」に保存しました。
# 3834 件のデータを「0000020205_E9103」に保存しました。
# 3834 件のデータを「0000020205_E9105」に保存しました。
# 3834 件のデータを「0000020205_E9106」に保存しました。
# 15313 件のデータを「0000020206_F1101」に保存しました。
# 7668 件のデータを「0000020206_F110101」に保存しました。
# 7668 件のデータを「0000020206_F110102」に保存しました。
# 15313 件のデータを「0000020206_F1102」に保存しました。
# 7668 件のデータを「0000020206_F110201」に保存しました。
# 7668 件のデータを「0000020206_F110202」に保存しました。
# 7668 件のデータを「0000020206_F1103」に保存しました。
# 7668 件のデータを「0000020206_F1104」に保存しました。
# 7668 件のデータを「0000020206_F1105」に保存しました。
# 7668 件のデータを「0000020206_F1106」に保存しました。
# 15313 件のデータを「0000020206_F1107」に保存しました。
# 7668 件のデータを「0000020206_F110701」に保存しました。
# 7668 件のデータを「0000020206_F110702」に保存しました。
# 7668 件のデータを「0000020206_F1108」に保存しました。
# 7668 件のデータを「0000020206_F110801」に保存しました。
# 7668 件のデータを「0000020206_F110802」に保存しました。
# 7668 件のデータを「0000020206_F1109」に保存しました。
# 7668 件のデータを「0000020206_F1110」に保存しました。
# 7668 件のデータを「0000020206_F1111」に保存しました。
# 7668 件のデータを「0000020206_F1301」に保存しました。
# 7668 件のデータを「0000020206_F1302」に保存しました。
# 7668 件のデータを「0000020206_F1303」に保存しました。
# 7668 件のデータを「0000020206_F1304」に保存しました。
# 7668 件のデータを「0000020206_F1305」に保存しました。
# 7668 件のデータを「0000020206_F1306」に保存しました。
# 7668 件のデータを「0000020206_F1307」に保存しました。
# 7668 件のデータを「0000020206_F1308」に保存しました。
# 7668 件のデータを「0000020206_F1309」に保存しました。
# 7668 件のデータを「0000020206_F1310」に保存しました。
# 7668 件のデータを「0000020206_F1311」に保存しました。
# 7668 件のデータを「0000020206_F1312」に保存しました。
# 7668 件のデータを「0000020206_F1313」に保存しました。
# 7668 件のデータを「0000020206_F1314」に保存しました。
# 7668 件のデータを「0000020206_F1315」に保存しました。
# 7668 件のデータを「0000020206_F1316」に保存しました。
# 7668 件のデータを「0000020206_F1317」に保存しました。
# 7668 件のデータを「0000020206_F1318」に保存しました。
# 1917 件のデータを「0000020206_F2116」に保存しました。
# 15313 件のデータを「0000020206_F2201」に保存しました。
# 15313 件のデータを「0000020206_F2211」に保存しました。
# 15313 件のデータを「0000020206_F2221」に保存しました。
# 15313 件のデータを「0000020206_F2401」に保存しました。
# 15313 件のデータを「0000020206_F2402」に保存しました。
# 15313 件のデータを「0000020206_F2403」に保存しました。
# 15313 件のデータを「0000020206_F2404」に保存しました。
# 15313 件のデータを「0000020206_F2405」に保存しました。
# 7668 件のデータを「0000020206_F2406」に保存しました。
# 3834 件のデータを「0000020206_F2409」に保存しました。
# 3834 件のデータを「0000020206_F2410」に保存しました。
# 3834 件のデータを「0000020206_F2411」に保存しました。
# 15313 件のデータを「0000020206_F2701」に保存しました。
# 7668 件のデータを「0000020206_F270101」に保存しました。
# 7668 件のデータを「0000020206_F270102」に保存しました。
# 7668 件のデータを「0000020206_F2702」に保存しました。
# 7668 件のデータを「0000020206_F270201」に保存しました。
# 7668 件のデータを「0000020206_F270202」に保存しました。
# 7668 件のデータを「0000020206_F2703」に保存しました。
# 7668 件のデータを「0000020206_F270301」に保存しました。
# 7668 件のデータを「0000020206_F270302」に保存しました。
# 15313 件のデータを「0000020206_F2705」に保存しました。
# 7668 件のデータを「0000020206_F270501」に保存しました。
# 7668 件のデータを「0000020206_F270502」に保存しました。
# 15313 件のデータを「0000020206_F2801」に保存しました。
# 7668 件のデータを「0000020206_F2802」に保存しました。
# 15313 件のデータを「0000020206_F2803」に保存しました。
# 19168 件のデータを「0000020207_G1201」に保存しました。
# 19168 件のデータを「0000020207_G1401」に保存しました。
# 7668 件のデータを「0000020208_H1100」に保存しました。
# 10983 件のデータを「0000020208_H1101」に保存しました。
# 7668 件のデータを「0000020208_H1102」に保存しました。
# 7668 件のデータを「0000020208_H110201」に保存しました。
# 7668 件のデータを「0000020208_H110202」に保存しました。
# 7668 件のデータを「0000020208_H110203」に保存しました。
# 7668 件のデータを「0000020208_H1201」に保存しました。
# 7668 件のデータを「0000020208_H1203」に保存しました。
# 10983 件のデータを「0000020208_H1310」に保存しました。
# 10983 件のデータを「0000020208_H1320」に保存しました。
# 7668 件のデータを「0000020208_H1321」に保存しました。
# 7668 件のデータを「0000020208_H132101」に保存しました。
# 7668 件のデータを「0000020208_H132102」に保存しました。
# 7668 件のデータを「0000020208_H1322」に保存しました。
# 7668 件のデータを「0000020208_H1323」に保存しました。
# 7668 件のデータを「0000020208_H1401」に保存しました。
# 7668 件のデータを「0000020208_H140101」に保存しました。
# 7668 件のデータを「0000020208_H140102」に保存しました。
# 7668 件のデータを「0000020208_H1402」に保存しました。
# 7668 件のデータを「0000020208_H140201」に保存しました。
# 7668 件のデータを「0000020208_H140202」に保存しました。
# 7668 件のデータを「0000020208_H1403」に保存しました。
# 7668 件のデータを「0000020208_H140301」に保存しました。
# 7668 件のデータを「0000020208_H140302」に保存しました。
# 7668 件のデータを「0000020208_H1404」に保存しました。
# 7668 件のデータを「0000020208_H1501」に保存しました。
# 7668 件のデータを「0000020208_H150101」に保存しました。
# 7668 件のデータを「0000020208_H150102」に保存しました。
# 7668 件のデータを「0000020208_H1502」に保存しました。
# 7668 件のデータを「0000020208_H1504」に保存しました。
# 5751 件のデータを「0000020208_H1505」に保存しました。
# 7668 件のデータを「0000020208_H1506」に保存しました。
# 2826 件のデータを「0000020208_H1604」に保存しました。
# 2826 件のデータを「0000020208_H1605」に保存しました。
# 7668 件のデータを「0000020208_H1612」に保存しました。
# 7668 件のデータを「0000020208_H1613」に保存しました。
# 2826 件のデータを「0000020208_H1615」に保存しました。
# 7668 件のデータを「0000020208_H1616」に保存しました。
# 5751 件のデータを「0000020208_H1619」に保存しました。
# 5751 件のデータを「0000020208_H1620」に保存しました。
# 1917 件のデータを「0000020208_H1621」に保存しました。
# 3834 件のデータを「0000020208_H1622」に保存しました。
# 1917 件のデータを「0000020208_H1623」に保存しました。
# 1917 件のデータを「0000020208_H1624」に保存しました。
# 1917 件のデータを「0000020208_H1625」に保存しました。
# 20111 件のデータを「0000020208_H1800」に保存しました。
# 20111 件のデータを「0000020208_H1801」に保存しました。
# 20111 件のデータを「0000020208_H1802」に保存しました。
# 20111 件のデータを「0000020208_H1803」に保存しました。
# 20111 件のデータを「0000020208_H1804」に保存しました。
# 20111 件のデータを「0000020208_H1810」に保存しました。
# 7668 件のデータを「0000020208_H2101」に保存しました。
# 7668 件のデータを「0000020208_H2102」に保存しました。
# 7668 件のデータを「0000020208_H2103」に保存しました。
# 7668 件のデータを「0000020208_H2104」に保存しました。
# 7668 件のデータを「0000020208_H2105」に保存しました。
# 7668 件のデータを「0000020208_H2106」に保存しました。
# 7668 件のデータを「0000020208_H2107」に保存しました。
# 7668 件のデータを「0000020208_H2108」に保存しました。
# 7668 件のデータを「0000020208_H2110」に保存しました。
# 7668 件のデータを「0000020208_H211010」に保存しました。
# 7668 件のデータを「0000020208_H211020」に保存しました。
# 7668 件のデータを「0000020208_H2120」に保存しました。
# 7668 件のデータを「0000020208_H212010」に保存しました。
# 7668 件のデータを「0000020208_H212020」に保存しました。
# 10983 件のデータを「0000020208_H2130」に保存しました。
# 7668 件のデータを「0000020208_H213010」に保存しました。
# 7668 件のデータを「0000020208_H213020」に保存しました。
# 3834 件のデータを「0000020208_H2201」に保存しました。
# 7668 件のデータを「0000020208_H2230」に保存しました。
# 3834 件のデータを「0000020208_H2250」に保存しました。
# 3834 件のデータを「0000020208_H2270」に保存しました。
# 1917 件のデータを「0000020208_H227004」に保存しました。
# 1917 件のデータを「0000020208_H227005」に保存しました。
# 5751 件のデータを「0000020208_H2280」に保存しました。
# 5751 件のデータを「0000020208_H2281」に保存しました。
# 5751 件のデータを「0000020208_H2282」に保存しました。
# 1979 件のデータを「0000020208_H2283」に保存しました。
# 19120 件のデータを「0000020208_H2500」に保存しました。
# 20111 件のデータを「0000020208_H2600」に保存しました。
# 20111 件のデータを「0000020208_H2601」に保存しました。
# 20111 件のデータを「0000020208_H2602」に保存しました。
# 20111 件のデータを「0000020208_H2603」に保存しました。
# 20111 件のデータを「0000020208_H2604」に保存しました。
# 5751 件のデータを「0000020208_H2900」に保存しました。
# 5751 件のデータを「0000020208_H2901」に保存しました。
# 5751 件のデータを「0000020208_H2902」に保存しました。
# 5751 件のデータを「0000020208_H2903」に保存しました。
# 5751 件のデータを「0000020208_H2904」に保存しました。
# 1917 件のデータを「0000020208_H2905」に保存しました。
# 1917 件のデータを「0000020208_H2906」に保存しました。
# 1917 件のデータを「0000020208_H2907」に保存しました。
# 1917 件のデータを「0000020208_H2908」に保存しました。
# 1917 件のデータを「0000020208_H2909」に保存しました。
# 5751 件のデータを「0000020208_H2910」に保存しました。
# 5751 件のデータを「0000020208_H2911」に保存しました。
# 5751 件のデータを「0000020208_H2912」に保存しました。
# 5751 件のデータを「0000020208_H2913」に保存しました。
# 5751 件のデータを「0000020208_H2914」に保存しました。
# 1917 件のデータを「0000020208_H2915」に保存しました。
# 1917 件のデータを「0000020208_H2916」に保存しました。
# 1917 件のデータを「0000020208_H2917」に保存しました。
# 1917 件のデータを「0000020208_H2918」に保存しました。
# 1917 件のデータを「0000020208_H2919」に保存しました。
# 7668 件のデータを「0000020208_H3100」に保存しました。
# 7668 件のデータを「0000020208_H3110」に保存しました。
# 7668 件のデータを「0000020208_H3111」に保存しました。
# 6608 件のデータを「0000020208_H311110」に保存しました。
# 7668 件のデータを「0000020208_H3120」に保存しました。
# 7668 件のデータを「0000020208_H3210」に保存しました。
# 7668 件のデータを「0000020208_H3211」に保存しました。
# 7668 件のデータを「0000020208_H3220」に保存しました。
# 7668 件のデータを「0000020208_H3300」に保存しました。
# 7668 件のデータを「0000020208_H3310」に保存しました。
# 7668 件のデータを「0000020208_H3311」に保存しました。
# 1917 件のデータを「0000020208_H3312」に保存しました。
# 1917 件のデータを「0000020208_H3313」に保存しました。
# 7668 件のデータを「0000020208_H3320」に保存しました。
# 7668 件のデータを「0000020208_H3410」に保存しました。
# 7668 件のデータを「0000020208_H3411」に保存しました。
# 7668 件のデータを「0000020208_H3420」に保存しました。
# 7668 件のデータを「0000020208_H3510」に保存しました。
# 7668 件のデータを「0000020208_H3511」に保存しました。
# 7668 件のデータを「0000020208_H351101」に保存しました。
# 7668 件のデータを「0000020208_H351102」に保存しました。
# 7668 件のデータを「0000020208_H3520」に保存しました。
# 7668 件のデータを「0000020208_H3521」に保存しました。
# 7668 件のデータを「0000020208_H352101」に保存しました。
# 7668 件のデータを「0000020208_H352102」に保存しました。
# 5751 件のデータを「0000020208_H3730」に保存しました。
# 5751 件のデータを「0000020208_H3740」に保存しました。
# 2960 件のデータを「0000020208_H4104」に保存しました。
# 43975 件のデータを「0000020208_H5501」に保存しました。
# 28755 件のデータを「0000020208_H5507」に保存しました。
# 40257 件のデータを「0000020208_H550701」に保存しました。
# 28755 件のデータを「0000020208_H5508」に保存しました。
# 28755 件のデータを「0000020208_H5509」に保存しました。
# 43979 件のデータを「0000020208_H5601」に保存しました。
# 40257 件のデータを「0000020208_H5608」に保存しました。
# 40257 件のデータを「0000020208_H5609」に保存しました。
# 28755 件のデータを「0000020208_H560901」に保存しました。
# 28755 件のデータを「0000020208_H560902」に保存しました。
# 28755 件のデータを「0000020208_H560903」に保存しました。
# 28755 件のデータを「0000020208_H560904」に保存しました。
# 28755 件のデータを「0000020208_H5610」に保存しました。
# 38340 件のデータを「0000020208_H5612」に保存しました。
# 28755 件のデータを「0000020208_H561201」に保存しました。
# 28755 件のデータを「0000020208_H5613」に保存しました。
# 40257 件のデータを「0000020208_H5614」に保存しました。
# 38340 件のデータを「0000020208_H5615」に保存しました。
# 11479 件のデータを「0000020208_H6101」に保存しました。
# 11479 件のデータを「0000020208_H6102」に保存しました。
# 11479 件のデータを「0000020208_H6103」に保存しました。
# 11479 件のデータを「0000020208_H6104」に保存しました。
# 7668 件のデータを「0000020208_H6130」に保存しました。
# 7668 件のデータを「0000020208_H613001」に保存しました。
# 7668 件のデータを「0000020208_H613002」に保存しました。
# 7668 件のデータを「0000020208_H613003」に保存しました。
# 7668 件のデータを「0000020208_H613004」に保存しました。
# 7668 件のデータを「0000020208_H613005」に保存しました。
# 7668 件のデータを「0000020208_H613006」に保存しました。
# 7668 件のデータを「0000020208_H6131」に保存しました。
# 7668 件のデータを「0000020208_H6132」に保存しました。
# 7668 件のデータを「0000020208_H6133」に保存しました。
# 7668 件のデータを「0000020208_H6201」に保存しました。
# 21087 件のデータを「0000020208_H7207」に保存しました。
# 21087 件のデータを「0000020208_H7208」に保存しました。
# 21087 件のデータを「0000020208_H7209」に保存しました。
# 21087 件のデータを「0000020208_H720901」に保存しました。
# 21087 件のデータを「0000020208_H720902」に保存しました。
# 21087 件のデータを「0000020208_H720903」に保存しました。
# 21087 件のデータを「0000020208_H720904」に保存しました。
# 21087 件のデータを「0000020208_H7210」に保存しました。
# 21087 件のデータを「0000020208_H721001」に保存しました。
# 21087 件のデータを「0000020208_H721002」に保存しました。
# 1917 件のデータを「0000020208_H7301」に保存しました。
# 1917 件のデータを「0000020208_H730101」に保存しました。
# 1917 件のデータを「0000020208_H730102」に保存しました。
# 1917 件のデータを「0000020208_H730103」に保存しました。
# 1917 件のデータを「0000020208_H730104」に保存しました。
# 1917 件のデータを「0000020208_H730105」に保存しました。
# 1917 件のデータを「0000020208_H730108」に保存しました。
# 1917 件のデータを「0000020208_H730109」に保存しました。
# 1917 件のデータを「0000020208_H730110」に保存しました。
# 1917 件のデータを「0000020208_H730111」に保存しました。
# 1917 件のデータを「0000020208_H730112」に保存しました。
# 1917 件のデータを「0000020208_H730113」に保存しました。
# 1917 件のデータを「0000020208_H7302」に保存しました。
# 3834 件のデータを「0000020208_H7303」に保存しました。
# 3834 件のデータを「0000020208_H7304」に保存しました。
# 6608 件のデータを「0000020208_H7401」に保存しました。
# 6608 件のデータを「0000020208_H740101」に保存しました。
# 6608 件のデータを「0000020208_H740102」に保存しました。
# 6608 件のデータを「0000020208_H740103」に保存しました。
# 6608 件のデータを「0000020208_H740104」に保存しました。
# 40257 件のデータを「0000020208_H7701」に保存しました。
# 40257 件のデータを「0000020208_H770101」に保存しました。
# 28755 件のデータを「0000020208_H8101」に保存しました。
# 67057 件のデータを「0000020208_H8102」に保存しました。
# 28755 件のデータを「0000020208_H8103」に保存しました。
# 67057 件のデータを「0000020208_H8104」に保存しました。
# 67057 件のデータを「0000020208_H810401」に保存しました。
# 67057 件のデータを「0000020208_H810402」に保存しました。
# 67057 件のデータを「0000020208_H810403」に保存しました。
# 28755 件のデータを「0000020208_H810404」に保存しました。
# 28755 件のデータを「0000020208_H810405」に保存しました。
# 28755 件のデータを「0000020208_H810406」に保存しました。
# 67057 件のデータを「0000020208_H810407」に保存しました。
# 67057 件のデータを「0000020208_H810408」に保存しました。
# 67057 件のデータを「0000020208_H810409」に保存しました。
# 3834 件のデータを「0000020209_I1101」に保存しました。
# 3834 件のデータを「0000020209_I1102」に保存しました。
# 44090 件のデータを「0000020209_I5101」に保存しました。
# 44090 件のデータを「0000020209_I510110」に保存しました。
# 76593 件のデータを「0000020209_I510120」に保存しました。
# 46006 件のデータを「0000020209_I510150」に保存しました。
# 76593 件のデータを「0000020209_I5102」に保存しました。
# 38340 件のデータを「0000020209_I510201」に保存しました。
# 46007 件のデータを「0000020209_I5103」に保存しました。
# 38340 件のデータを「0000020209_I5211」に保存しました。
# 38340 件のデータを「0000020209_I5212」に保存しました。
# 34506 件のデータを「0000020209_I5501」に保存しました。
# 34506 件のデータを「0000020209_I5502」に保存しました。
# 3834 件のデータを「0000020209_I5511」に保存しました。
# 3834 件のデータを「0000020209_I5512」に保存しました。
# 44044 件のデータを「0000020209_I6100」に保存しました。
# 19170 件のデータを「0000020209_I6101」に保存しました。
# 44044 件のデータを「0000020209_I6200」に保存しました。
# 19170 件のデータを「0000020209_I6201」に保存しました。
# 19170 件のデータを「0000020209_I6300」に保存しました。
# 19170 件のデータを「0000020209_I6310」に保存しました。
# 34506 件のデータを「0000020210_J2201」に保存しました。
# 3834 件のデータを「0000020210_J2221」に保存しました。
# 34506 件のデータを「0000020210_J2301」に保存しました。
# 34506 件のデータを「0000020210_J230111」に保存しました。
# 34506 件のデータを「0000020210_J230112」に保存しました。
# 34506 件のデータを「0000020210_J230113」に保存しました。
# 40256 件のデータを「0000020210_J230121」に保存しました。
# 34506 件のデータを「0000020210_J230124」に保存しました。
# 3834 件のデータを「0000020210_J230127」に保存しました。
# 3834 件のデータを「0000020210_J230128」に保存しました。
# 34506 件のデータを「0000020210_J230131」に保存しました。
# 34506 件のデータを「0000020210_J230132」に保存しました。
# 34506 件のデータを「0000020210_J230133」に保存しました。
# 34506 件のデータを「0000020210_J230141」に保存しました。
# 19170 件のデータを「0000020210_J230191」に保存しました。
# 19170 件のデータを「0000020210_J230211」に保存しました。
# 34506 件のデータを「0000020210_J230221」に保存しました。
# 34506 件のデータを「0000020210_J230222」に保存しました。
# 34506 件のデータを「0000020210_J230223」に保存しました。
# 19170 件のデータを「0000020210_J2303」に保存しました。
# 3834 件のデータを「0000020210_J2304」に保存しました。
# 3834 件のデータを「0000020210_J230411」に保存しました。
# 3834 件のデータを「0000020210_J230412」に保存しました。
# 3834 件のデータを「0000020210_J230421」に保存しました。
# 3834 件のデータを「0000020210_J230422」に保存しました。
# 3834 件のデータを「0000020210_J230431」に保存しました。
# 3834 件のデータを「0000020210_J230432」に保存しました。
# 15336 件のデータを「0000020210_J232101」に保存しました。
# 28754 件のデータを「0000020210_J2401」に保存しました。
# 23004 件のデータを「0000020210_J2402」に保存しました。
# 23004 件のデータを「0000020210_J2403」に保存しました。
# 34506 件のデータを「0000020210_J2501」に保存しました。
# 3834 件のデータを「0000020210_J250204」に保存しました。
# 72754 件のデータを「0000020210_J2503」に保存しました。
# 34506 件のデータを「0000020210_J250301」に保存しました。
# 3834 件のデータを「0000020210_J250302」に保存しました。
# 3834 件のデータを「0000020210_J250303」に保存しました。
# 72754 件のデータを「0000020210_J2506」に保存しました。
# 34506 件のデータを「0000020210_J250604」に保存しました。
# 1917 件のデータを「0000020210_J2545」に保存しました。
# 1917 件のデータを「0000020210_J2546」に保存しました。
# 28755 件のデータを「0000020210_J2641」に保存しました。
# 28755 件のデータを「0000020210_J2642」に保存しました。
# 23004 件のデータを「0000020210_J2701」に保存しました。
# 23004 件のデータを「0000020210_J2702」に保存しました。
# 23004 件のデータを「0000020210_J2703」に保存しました。
# 34506 件のデータを「0000020210_J2801」に保存しました。
# 3834 件のデータを「0000020210_J2804」に保存しました。
# 19170 件のデータを「0000020210_J2901」に保存しました。
# 7668 件のデータを「0000020210_J2902」に保存しました。
# 19170 件のデータを「0000020210_J2903」に保存しました。
# 19170 件のデータを「0000020210_J2904」に保存しました。
# 3834 件のデータを「0000020210_J2905」に保存しました。
# 3834 件のデータを「0000020210_J2906」に保存しました。
# 76596 件のデータを「0000020210_J4101」に保存しました。
# 21086 件のデータを「0000020210_J4102」に保存しました。
# 28754 件のデータを「0000020210_J4104」に保存しました。
# 28754 件のデータを「0000020210_J4106」に保存しました。
# 28754 件のデータを「0000020210_J4107」に保存しました。
# 26828 件のデータを「0000020210_J4108」に保存しました。
# 26828 件のデータを「0000020210_J4109」に保存しました。
# 57425 件のデータを「0000020211_K3101」に保存しました。
# 55508 件のデータを「0000020211_K4201」に保存しました。
